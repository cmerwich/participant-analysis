# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
ORG = 'cmerwich'
REPO = 'participant-analysis'
RELATIVE = 'test/tf'

#mod=f'{ORG}/{REPO}/{RELATIVE}

# %%
A = use('bhsa', version='2017', hoist=globals(), lgc=True, mod=('cmerwich/participant-analysis/test/tf,'
                                                                'etcbc/lingo/heads/tf'),)
# Out:
# TF app is up-to-date.
# Using annotation/app-bhsa commit d3cf8f0c2ab5d690a0fda14ea31c33da5c5c8483 (=latest)
#   in /Users/Christiaan/text-fabric-data/__apps__/bhsa.
# Using etcbc/bhsa/tf - 2017 in /Users/Christiaan/github
# Using etcbc/phono/tf - 2017 in /Users/Christiaan/github
# Using etcbc/parallels/tf - 2017 in /Users/Christiaan/github
# Using cmerwich/participant-analysis/test/tf - 2017 in /Users/Christiaan/github
# Using etcbc/lingo/heads/tf - 2017 in /Users/Christiaan/github
# ...

# %%
def show_text(results, highlights):
    A.displaySetup(extraFeatures='pgn_prps pgn_prde pgn_verb pgn_prs pdp typ rela ls function det st lex nametype gn nu') #ps gn nu
    A.show(results, condensed=False, highlights=highlights)

# %%
F.otype.maxNode
# Out:
# 1770729

# %%
C.levels.data
# Out:
# (('book', 10938.051282051281, 426585, 426623),
#  ('chapter', 459.18622174381056, 426624, 427552),
#  ('lex', 46.2021011588866, 1437403, 1446635),
#  ('verse', 18.37694395381898, 1414190, 1437402),
#  ('half_verse', 9.441876936697653, 606323, 651502),
#  ('sentence', 6.695609863288914, 1172209, 1235919),
#  ('sentence_atom', 6.615141270973544, 1235920, 1300405),
#  ('clause', 4.841988172665464, 427553, 515653),
#  ('clause_atom', 4.704849507549438, 515654, 606322),
#  ('phrase', 1.6848574373881755, 651503, 904689),
#  ('phrase_atom', 1.5945932812248849, 904690, 1172208),
#  ('subphrase', 1.4240578640230612, 1300406, 1414189),
#  ('mention', 1.1539645905200344, 1446636, 1770729),
#  ('word', 1, 1, 426584))

# %%
F.color.freqList()
# Out:
# (('skyblue', 195277),
#  ('springgreen', 69026),
#  ('tomato', 33112),
#  ('DarkGoldenrod', 13149),
#  ('yellow', 5887),
#  ('palegoldenrod', 4508),
#  ('royalblue', 3135))

# %%
F.mDet.freqList()
# Out:
# (('1', 186278), ('0', 67489))

# %%
highlights = {E.nlink.f(m)[0]: F.color.v(m) for m in F.otype.s('mention')}

# %%
def show_passage(book, chapter):
    chn = T.nodeFromSection((book, chapter))
    nodes = tuple(n for n in L.d(chn) if E.nlink.t(n))
    tup = (chn,) + nodes
    A.prettyTuple(tup, 1, highlights=highlights, withNodes=True)

# %%
pn = 651504
E.nlink.f(pn)
# Out:
# ()

# %%
mn = F.otype.s('mention')[0]
L.d(mn)
# Out:
# [651505, 904692, 1446725, 4]

# %%
E.nlink.f(mn)
# Out:
# (651505,)

# %%
show_passage('Genesis', 1)
# Out:
# <p><b>result</b> <i>1</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1">Genesis 1</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></div>
#         <a href="#" class="nd">1414190</a>
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
# ...
