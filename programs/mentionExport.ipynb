# %% [markdown]
# To fix/look at:
#
# * file/directory locations: annotate, standoff
# * file_list
# * mentions
# * start_index and end_index mentions

# %%
__author__ = 'erwich/sikkel/roorda'

# %%
import getopt
import os, sys
from sys import argv, exit, stderr

import collections 
import re
from shutil import rmtree
from glob import glob
from pprint import pprint

from tf.app import use

# %%
TAB = '\t'
NL = '\n'
VERSION = 'c'

# %%
def error(*args, **kwargs):
    print(*args, file=stderr, **kwargs)
    exit(1)

# %%
def Usage():
    stderr.write('usage: [your python version] createcoref book_name first_chapter [last_chapter]\n')
    exit(1)

# %%
REFERENCE = f'bh-reference-system/tf/{VERSION}' # Check my GitHub to download extra pgn features
OUTPUT_BASE = os.path.expanduser('~/Sites/brat/data/coref')
ANNOTATE = f'annotate'
STANDOFF = f'standoff'

# %%
A = use('bhsa', 
        version = VERSION,
        hoist=globals(),
        mod=('cmerwich/participant-analysis/test/tf:clone,'
             'cmerwich/bh-reference-system/tf,'
             'etcbc/lingo/heads/tf:clone'),
       )
# Out:
# 	connecting to online GitHub repo annotation/app-bhsa ... connected
# Using TF-app in /Users/Christiaan/text-fabric-data/annotation/app-bhsa/code:
# 	rv1.2=#5fdf1778d51d938bfe80b37b415e36618e50190c (latest release)
# 	connecting to online GitHub repo etcbc/bhsa ... connected
# Using data in /Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c:
# 	rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 (latest release)
# 	connecting to online GitHub repo etcbc/phono ... connected
# Using data in /Users/Christiaan/text-fabric-data/etcbc/phono/tf/c:
# 	r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 (latest release)
# 	connecting to online GitHub repo etcbc/parallels ... connected
# Using data in /Users/Christiaan/text-fabric-data/etcbc/parallels/tf/c:
# 	r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c (latest release)
# Using data in /Users/Christiaan/github/cmerwich/participant-analysis/test/tf/c:
# 	repo clone offline under ~/github (local github)
# 	connecting to online GitHub repo cmerwich/bh-reference-system ... connected
# Using data in /Users/Christiaan/text-fabric-data/cmerwich/bh-reference-system/tf/c:
# 	rv1.0 (latest release)
# Using data in /Users/Christiaan/github/etcbc/lingo/heads/tf/c:
# 	repo clone offline under ~/github (local github)
# <b>Documentation:</b> <a target="_blank" href="https://etcbc.github.io/bhsa" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Hebrew" title="('Hebrew characters and transcriptions',)">Character table</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="BHSA feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-bhsa" title="bhsa API documentation">bhsa API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.7.10</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b>: <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/book.tf">book</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/book@am.tf">book@ll</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/chapter.tf">chapter</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/code.tf">code</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/det.tf">det</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/domain" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/domain.tf">domain</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/freq_lex.tf">freq_lex</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/function.tf">function</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/g_cons.tf">g_cons</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/g_cons_utf8.tf">g_cons_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/g_lex.tf">g_lex</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/g_lex_utf8.tf">g_lex_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/g_word.tf">g_word</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/g_word_utf8.tf">g_word_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/gloss.tf">gloss</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/gn.tf">gn</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/label" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/label.tf">label</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/language" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/language.tf">language</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/lex" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/lex.tf">lex</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/lex_utf8" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/lex_utf8.tf">lex_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/ls" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/ls.tf">ls</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/nametype" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/nametype.tf">nametype</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/nme" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/nme.tf">nme</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/nu" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/nu.tf">nu</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/number" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/number.tf">number</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/pargr" title="/Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c/pargr.tf">par ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.lno,.catom.lno,.patom.lno {
#     border-left-style: none
# }
# .satom.rno,.catom.rno,.patom.rno {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %%
TF.load('g_prs', add=True)
# Out:
#   0.00s loading features ...
#    |     0.00s Not enough info for structure in otext, structure functionality will not work
#    |     0.16s B g_prs                from /Users/Christiaan/text-fabric-data/etcbc/bhsa/tf/c
#   0.18s All additional features loaded - for details use loadLog()

# %%
class Mention:
    def __init__(self, name, start=0, end=0, lex='', note='', file=0, suffix=False):
        self.name = name     # Identifier of the mention, e.g. T32
        self.start = start   # Start of the position in the txt file
        self.end = end       # End of the position in the txt file
        self.lex = lex       # Lexical information of the mention
        self.suffix = suffix # Boolean for existence of suffix on word
        self.note = note     # AnnotatorNotes generated by MakeMentions()

# %%
def OpenFiles(my_book_name, first_chapter, last_chapter):
    
    my_chapters = set(range(first_chapter, last_chapter+1))
    chapter_list = []
    # code review: pak book node and chapter nodes die je nodig hebt
    for book in F.otype.s('book'):
        book_name = T.bookName(book)

        for chn in L.d(book, 'chapter'):
            chapter = F.chapter.v(chn)
            if (
                (my_book_name and book_name not in my_book_name)
                or 
                (my_chapters and chapter not in my_chapters)
            ):
                error(f'The combination of {my_book_name} \
                      and {first_chapter}--{last_chapter+1} does not exist. \
                      Try again.')
            
            chapter_list.append(chn)
            
            filename = f'{book}_{chapter:>03}'
            filename_txt = f'{filename}.txt'
            filename_ann = f'{filename}.ann'
            filename_tsv = f'{filename}.tsv'
            
            txt_f = open(filename_txt, 'w')
            ann_f = open(filename_ann, 'w')
            tsv_f = open(filename_tsv, 'w')
            
    return txt_f, ann_f, tsv_f, chapter_list

# %%
def MakeIndex(word, txtPos, g_word):
   
    # MakeIndex(texts) # make index tabel for words from txt files, 
    # dict: key: node, value: tuple(begin index end index)
    # ook voor Mention.suffix een index maken, kijk naar ReplaceSuffix() voor hints. 
    
    start = txtPos 
    end = txtPos + len(g_word) - 1
    txtPos += len(g_word) + 1
    
    return (word, start, end)

# %%
def Replace(g_prs):
    char_set = set('+:@.,;AEIOU')
    if g_prs not in {'', '+'}:
        new_prs = 'A' if g_prs == '+A' else ''.join(char for char in g_prs if char not in char_set)
        return new_prs

# %%
def ReplaceSuffix(source_string, replace_what, replace_with):
    '''
    S.rpartition(sep) -> (head, sep, tail)

    Search for the _sep (separator) in S (string), starting at the end of S, and return
    the part before it, the separator itself, and the part after it.  If the
    separator is not found, return two empty strings and S.
    '''
    
    head, _sep, tail = source_string.rpartition(replace_what)
    return head + replace_with + tail, head

# %%
def ProcessSuffix(gcons_word, new_prs):        
    if new_prs:
        word_prs, head = ReplaceSuffix(gcons_word, new_prs, f'+{new_prs}')
        return word_prs
    else:
        return gcons_word

def ProcessSpace(gcons_word, trailer, sep):
    if trailer == '':
        return f'{gcons_word}-'
    else:
        return f'{gcons_word}{sep}

def EmitWord(index_dict, w, sep):
    words_list.append(w)
    gcons_word = F.g_cons.v(w)
    trailer = F.trailer.v(w)
    g_prs = F.g_prs.v(w)
    new_prs = Replace(g_prs)
    g_word = ProcessSuffix(gcons_word, new_prs)
    g_word = ProcessSpace(gcons_word, trailer, sep)
    index_dict[w] = MakeIndex(w, txtPos, g_word)
    #writeP(f'{g_word}', txt_f)
    #writeT(f'{txtPos}\t{txtPos + len(gcons_word)}\t{w}\t{gcons_word}\n', tsv_f)
    txtPos += len(g_word)
    
def WriteChapter(chapterNode, txt_f, tsv_f):
    (book, chapter, verse) = T.sectionFromNode(chapterNode, fillup=True)
    words_list = []
    
    txtPos = 0
    
    def writeT(text, fh):
        fh.write(text)
    
    def writeP(text, fh):
        nonlocal txtPos
        fh.write(text)
        txtPos += len(text)
          
    writeP(f'{filename}\n', txt_f)

    header = ['start_index', 'end_index', 'word_node', 'word']
    writeT('{}\n'.format('\t'.join(header)), tsv_f)

    for vn in L.d(chapterNode, 'verse'):
        verse = T.sectionFromNode(vn)[2]
        verse_words = L.d(vn, 'word')

        # write transcription and .tsv
        writeP(f'{verse} ', txt_f)
        
        for i in range(len(verse_words) -1):
            EmitWord(index_dict, verse_words[i], ' ')
        EmitWord(index_dict, verse_words[-1], '\n')
            
        writeP(f'{g_word}', txt_f) # ?

        writeT(f'{txtPos}\t{txtPos + len(gcons_word)}\t{w}\t{gcons_word}\n', tsv_f) # ?
            
        writeP('\n', txt_f) # ?
        
    return txt_f, words_list

# %% [raw]
# def process_suffix(gcons_word, trailer):
#     if gcons_word.endswith(new_prs) and trailer == '':
#         suff_word = ReplaceSuffix(gcons_word, new_prs, f'+{new_prs}-')
#         return suff_word
#     elif gcons_word.endswith(new_prs) and trailer != '':
#         suff_word = ReplaceSuffix(gcons_word, new_prs, f'+{new_prs} ')
#         return suff_word
#
# def process_hyphen():
#     pass
#
# def WriteChapter(chapterNode):
#     (book, chapter, verse) = T.sectionFromNode(chapterNode, fillup=True)
#     words_list = []
#
#     txtPos = 0
#
#     def writeT(text, fh):
#         fh.write(text)
#
#     def writeP(text, fh):
#         nonlocal txtPos
#         fh.write(text)
#         txtPos += len(text)
#
#     writeP(f'{filename}\n', txt_f)
#
#     header = ['start_index', 'end_index', 'word_node', 'word']
#
#     writeT('{}\n'.format('\t'.join(header)), tsv_f)
#
#     for vn in L.d(chapterNode, 'verse'):
#         verse = T.sectionFromNode(vn)[2]
#         verse_words = L.d(vn, 'word')
#
#         # write transcription and .tsv
#         writeP(f'{verse} ', txt_f)
#
#         for w in verse_words:
#             words_list.append(w)
#             gcons_word = F.g_cons.v(w)
#             trailer = F.trailer.v(w)
#             prs = F.prs.v(w)
#             g_prs = F.g_prs.v(w)
#             new_prs = Replace(g_prs)
#             if new_prs:
#                 if gcons_word.endswith(new_prs) and trailer == '':
#                     suff_word, head = ReplaceSuffix(gcons_word, new_prs, f'+{new_prs}-')
#
#                     writeP(f'{suff_word}', txt_f)
#                     writeT(f'{txtPos}\t{txtPos + len(gcons_word)}\t{w}\t{gcons_word}\n', tsv_f)
#
#                     MakeIndex(w, txtPos, suff_word)
#
#                 elif gcons_word.endswith(new_prs) and trailer != '':
#                     suff_word, head = ReplaceSuffix(gcons_word, new_prs, f'+{new_prs} ')
#
#                     writeP(f'{suff_word}', txt_f)
#                     writeT(f'{txtPos}\t{txtPos + len(gcons_word)}\t{w}\t{gcons_word}\n', tsv_f)
#
#                     MakeIndex(w, txtPos, suff_word)
#
#             if trailer == '':
#                 gcons_word_hyph = f'{gcons_word}-'
#                 writeP(f'{gcons_word_hyph}', txt_f)
#                 writeT(f'{txtPos}\t{txtPos + len(gcons_word)}\t{w}\t{gcons_word}\n', tsv_f)
#
#                 MakeIndex(w, txtPos, gcons_word_hyph)
#
#             else:
#                 gcons_word_sp = f'{gcons_word} '
#                 writeP(f'{gcons_word_sp}', txt_f)
#                 writeT(f'{txtPos}\t{txtPos + len(gcons_word)}\t{w}\t{gcons_word}\n', tsv_f)
#
#                 MakeIndex(w, txtPos, gcons_word_sp)
#
#         writeP('\n', txt_f)
#
#     return txt_f, words_list

# %%
def WriteText(txt_f, tsv_f, chapter_list):
    '''
    Write text, ann and tsv files from chapter int(nodes) in chapter_list.
    The chapter nodes are derived from my_book_name specified in CreateCoref()
    '''
    index_dict = {}
    for chn in chapter_list:
        text_f, words_list = WriteChapter(chn, txt_f, tsv_f)
    
    return text_f, chapter_list, words_list

# %%
def GetOffsets(texts):
    '''
    The offsets of the text files.
    Makes the cumulative sizes of the text files 
    for which the corresponding .ann files are generated.  
    '''
    
    lst = []
    offset = 0
    for f in texts:
        lst += [offset]
        offset += os.stat(f).st_size    # check file size in bytes 
    lst += [offset]
    return lst

# %%
def t(my_book_name, f, l):
    my_chapters = set(range(f, l+1))
    
    c_l = []
    
    for book in F.otype.s('book'):
        
        book_name = T.bookName(book)

        for chn in L.d(book, 'chapter'):
            chapter = F.chapter.v(chn)
            if (
                (my_book_name and book_name not in my_book_name)
                or 
                (my_chapters and chapter not in my_chapters)
            ):
                continue
            c_l.append(chn)
    
    return c_l

chapter_list = t('Psalms', 1, 1)            

def ParseMentions(chapter_nodes):
    Mention_list = []
    l = []
    for chn in chapter_list:
        mnodes = tuple(n for n in L.d(chn) if E.nlink.t(n))
        mention_nodes = [m for m in L.d(chn, 'mention') if F.otype.v(m)]
        for m in mention_nodes:
       
            for phrase in L.u(m, 'phrase'):
                phr_type = F.typ.v(phrase)
                words = L.d(phrase, 'word')
                first_word = words[0]
                last_word = words[-1]
                if phr_type == 'NP':
                    print('NP: ', words)
                else:
                    print(phr_type)
                


ParseMentions(chapter_list)

# %%
def P(my_book_name, f, l):
    Mentions = []
    one_w_lst = []
    two_w_lst = []
    more_w_lst = []
    my_chapters = set(range(f, l+1))
    pdp_choice = {'verb', 'subs', 'nmpr', 'prps', 'prde'}
    t = 0
    for book in F.otype.s('book'):
        book_name = T.bookName(book)
        for chn in L.d(book, 'chapter'):
            chapter = F.chapter.v(chn)
            if (
                (my_book_name and book_name not in my_book_name)
                or 
                (my_chapters and chapter not in my_chapters)
            ):
                continue
            for pa in L.d(chn, 'phrase_atom'):
                pa_typ = F.typ.v(pa)
                pa_words = L.d(pa, 'word')
                pa_text = T.text(pa, fmt='text-trans-plain')
                print(pa_text)
                for word in pa_words:
                    pdp = F.pdp.v(word)
                    st = F.st.v(word)
                    print('\t', pa_typ, F.g_cons.v(word), st, pdp, sep='\t')
P('Psalms', 1, 1)
# Out:
# >CRJ&H>JC
# 		NP	>CRJ	c	subs
# 		NP	H	NA	art
# 		NP	>JC	a	subs
# >CR05
# 		CP	>CR	NA	conj
# L>
# 		NegP	L>	NA	nega
# HLK
# 		VP	HLK	NA	verb
# B<YT RC<JM
# 		PP	B	NA	prep
# 		PP	<YT	c	subs
# 		PP	RC<JM	a	subs
# W
# 		CP	W	NA	conj
# BDRK XV>JM
# 		PP	B	NA	prep
# 		PP	DRK	c	subs
# 		PP	XV>JM	a	subs
# L>
# 		NegP	L>	NA	nega
# <MD
# 		VP	<MD	NA	verb
# W
# 		CP	W	NA	conj
# BMWCB LYJM
# 		PP	B	NA	prep
# 		PP	MWCB	c	subs
# 		PP	LYJM	a	subs
# L>
# 		NegP	L>	NA	nega
# JCB00
# 		VP	JCB	NA	verb
# KJ >M
# 		CP	KJ	NA	conj
# 		CP	>M	NA	conj
# BTWRT JHWH
# 		PP	B	NA	prep
# 		PP	TWRT	c	subs
# 		PP	JHWH	a	nmpr
# XPYW
# 		NP	XPYW	a	subs
# W
# 		CP	W	NA	conj
# BTWRTW
# 		PP	B	NA	prep
# 		PP	TWRTW	a	subs
# JHGH
# 		VP	JHGH	NA	verb
# JWMM WLJLH00
# 		AdvP	JWMM	NA	advb
# 		AdvP	W	NA	conj
# 		AdvP	LJLH	a	advb
# W
# 		CP	W	NA	conj
# HJH
# 		VP	HJH	NA	verb
# K<Y
# 		PP	K	NA	prep
# 		PP	<Y	a	subs
# CTWL
# 		VP	CTWL	a	verb
# <L&PLGJ MJM
# 		PP	<L	NA	prep
# 		PP	PLGJ	c	subs
# 		PP	MJM	a	subs
# >CR
# 		CP	>CR	NA	conj
# PRJW05
# 		NP	PRJW	a	subs
# JTN
# 		VP	JTN	NA	verb
# B<TW
# 		PP	B	NA	prep
# 		PP	<TW	a	subs
# W
# 		CP	W	NA	conj
# <LHW
# 		NP	<LHW	a	subs
# L>&
# 		NegP	L>	NA	nega
# JBWL
# 		VP	JBWL	NA	verb
# W
# 		CP	W	NA	conj
# KL
# 		NP	KL	c	subs
# >CR&
# 		CP	>CR	NA	conj
# J<FH
# 		VP	J<FH	NA	verb
# JYLJX00
# 		VP	JYLJX	NA	verb
# L>&
# 		NegP	L>	NA	nega
# KN
# 		AdvP	KN	NA	advb
# HRC<JM
# 		NP	H	NA	art
# 		NP	RC<JM	a	subs
# KJ >M&
# 		CP	KJ	NA	conj
# 		CP	>M	NA	conj
# KMY
# 		PP	K	NA	prep
# 		PP		NA	art
# 		PP	MY	a	subs
# >CR&
# 		CP	>CR	NA	conj
# TDPNW
# 		VP	TDPNW	NA	verb
# RWX00
# 		NP	RWX	a	subs
# <L&KN05
# 		PP	<L	NA	prep
# 		PP	KN	NA	advb
# L>&
# 		NegP	L>	NA	nega
# JQMW
# 		VP	JQMW	NA	verb
# RC<JM
# 		NP	RC<JM	a	subs
# BMCPV
# 		PP	B	NA	prep
# 		PP		NA	art
# 		PP	MCPV	a	subs
# W
# 		CP	W	NA	conj
# XV>JM
# 		NP	XV>JM	a	subs
# B<DT YDJQJM00
# 		PP	B	NA	prep
# 		PP	<DT	c	subs
# 		PP	YDJQJM	a	subs
# KJ&
# 		CP	KJ	NA	conj
# JWD<
# 		VP	JWD<	a	verb
# JHWH
# 		PrNP	JHWH	a	nmpr
# DRK YDJQJM
# 		NP	DRK	c	subs
# 		NP	YDJQJM	a	subs
# W
# 		CP	W	NA	conj
# DRK RC<JM
# 		NP	DRK	c	subs
# 		NP	RC<JM	a	subs
# T>BD00
# 		VP	T>BD	NA	verb

# %%
def ReturnHead(source_string, replace_what, replace_with):
    '''
    S.rpartition(sep) -> (head, sep, tail)

    Search for the _sep (separator) in S (string), starting at the end of S, and return
    the part before it, the separator itself, and the part after it.  If the
    separator is not found, return two empty strings and S.
    '''
    
    head, _sep, tail = source_string.rpartition(replace_what)
    return head

# %%
def ParseMentions(my_book_name, f, l):
    Mentions = []
    one_w_lst = []
    two_w_lst = []
    more_w_lst = []
    my_chapters = set(range(f, l+1))
    pdp_choice = {'verb', 'subs', 'nmpr', 'prps', 'prde'}
    t = 0
    for book in F.otype.s('book'):
        book_name = T.bookName(book)
        for chn in L.d(book, 'chapter'):
            chapter = F.chapter.v(chn)
            if (
                (my_book_name and book_name not in my_book_name)
                or 
                (my_chapters and chapter not in my_chapters)
            ):
                continue
            
            np_nodes = tuple(n for n in L.d(chn, 'phrase') if E.nlink.t(n))
            word_nodes = tuple(n for n in L.d(chn, 'word') if E.nlink.t(n))
            phr_nodes = tuple(n for n in L.d(chn, 'phrase') if L.d(n, 'mention'))
            
            i = 0
            for p in phr_nodes:
                words = L.d(p, 'word')
                pdp = F.pdp.v(words)
                typ = F.typ.v(p)
                #print(words, T.text(p), typ, sep='\t')
                mention_words = tuple(w for w in words if L.u(w, 'mention'))
                #prs = F.prs.v(L.d(p, 'word'))
                #prs = F.prs.v(mention_words[0])
                suf = F.mSuf.v(L.d(p, 'mention')[0])
                
                if len(mention_words) <= 1:
                    word_node = mention_words[0]
                    new_prs = Replace(F.g_prs.v(word_node))
                    gcons_word = F.g_cons.v(word_node)
                    
                    # if suffix
                    if new_prs:
                        i += 1
                        m = Mention(f'T{i}', word_node, word_node, new_prs, suffix = True)    
                        #print(new_prs, name, T.text(word, fmt='text-trans-plain'), sep='\t')
                        one_w_lst.append(word_node)
                        Mentions.append(m)
                    # if no suffix
                    else:
                        i += 1
                        m = Mention(f'T{i}', word_node, word_node, gcons_word, suffix = False)    
                        #print('no prs:', name, T.text(mention_words[0], fmt='text-trans-plain'), sep='\t')
                
                elif len(mention_words) <= 2:
                    m0 = mention_words[0]
                    m1 = mention_words[1]
                    boo, chap, ver = T.sectionFromNode(m0)
                    ch_v = f'{chap}:{ver}'
                    new_prs0 = Replace(F.g_prs.v(m0))
                    new_prs1 = Replace(F.g_prs.v(m1))
                    pdp0 = F.pdp.v(m0)
                    pdp1 = F.pdp.v(m1)
                    gcons_word0 = F.g_cons.v(m0)
                    gcons_word1 = F.g_cons.v(m1)
                    #head0 = ReturnHead(gcons_word0, new_prs0, new_prs0)
                    #head1 = ReturnHead(gcons_word1, new_prs1, new_prs1)
                    st0 = F.st.v(m0)
                    #print(ch_v, m0, st0, gcons_word0)
                    
                    ####################
                    
                    if (st0 == 'a' and not new_prs0) and not new_prs1:
                        i += 1
                        m = Mention(f'T{i}', m0, m0, gcons_word0, suffix = False)
                        m = Mention(f'T{i}', m1, m1, gcons_word1, suffix = False)
                          
                    elif (st0 == 'a' and new_prs0) and not new_prs1:
                        head0 = ReturnHead(gcons_word0, new_prs0, new_prs0)
                        i += 1
                        m = Mention(f'T{i}', m0, m0, head0, suffix = False)
                        m = Mention(f'T{i}', m0, m0, new_prs0, suffix = True)
                        m = Mention(f'T{i}', m1, m1, gcons_word1, suffix = False)
                        #print(ch_v, (head0, new_prs0), (gcons_word1), sep='\t')
                    #elif st0 == 'e' and not new_prs1:

                    elif st0 == 'c' and not new_prs1:
                        i += 1
                        m = Mention(f'T{i}', m0, m1, mention_words, suffix = False)
                    
                    elif st0 == 'NA' and not new_prs1:
                        i += 1
                        m = Mention(f'T{i}', m1, m1, gcons_word1, suffix = False)
                        
                    ####################
                    
                    elif (st0 == 'a' and not new_prs0) and new_prs1:
                        if pdp1 != 'prep':
                            i += 1
                            head1 = ReturnHead(gcons_word1, new_prs1, new_prs1)
                            m = Mention(f'T{i}', m0, m0, gcons_word0, suffix = False)
                            m = Mention(f'T{i}', m1, m1, head1, suffix = False)
                            m = Mention(f'T{i}', m1, m1, new_prs1, suffix = True)
                        else:
                            i += 1
                            head1 = ReturnHead(gcons_word1, new_prs1, new_prs1)
                            m = Mention(f'T{i}', m0, m0, gcons_word0, suffix = False)
                            m = Mention(f'T{i}', m1, m1, new_prs1, suffix = True)
                            #print(ch_v, (gcons_word0), pdp0, (head1, new_prs1), pdp1, sep='\t')
                    #elif st0 == 'e' and new_prs1:
                    
                    elif st0 == 'c' and new_prs1:
                        i += 1
                        # possibly like previous:  if pdp1 != 'prep':
                        head1 = ReturnHead(gcons_word1, new_prs1, new_prs1)
                        m = Mention(f'T{i}', m0, m1, f'{gcons_word0} {head1}', suffix = False)
                        m = Mention(f'T{i}', m1, m1, new_prs1, suffix = True)
                        #print(ch_v, (f'{gcons_word0} {head1}'), (gcons_word1, new_prs1), pdp1, sep='\t')
                    
                    elif (st0 == 'NA' and pdp0 in pdp_choice) and new_prs1:
                        i += 1
                        head1 = ReturnHead(gcons_word1, new_prs1, new_prs1)
                        m = Mention(f'T{i}', m0, m0, gcons_word0, suffix = False)
                        m = Mention(f'T{i}', m1, m1, head1, suffix = False)
                        m = Mention(f'T{i}', m1, m1, new_prs1, suffix = True)
                        #print(ch_v, (gcons_word0), pdp0, (head1, new_prs1), pdp1, sep='\t')
                    
                    ####################
                    
                    elif new_prs0 and new_prs1:
                        i += 1
                        t+=1
                        head0 = ReturnHead(gcons_word0, new_prs0, new_prs0)
                        head1 = ReturnHead(gcons_word1, new_prs1, new_prs1)
                        m = Mention(f'T{i}', m0, m0, head0, suffix = False)
                        m = Mention(f'T{i}', m0, m0, new_prs0, suffix = True)
                        m = Mention(f'T{i}', m1, m1, head1, suffix = False)
                        m = Mention(f'T{i}', m1, m1, new_prs1, suffix = True)
                        #print(ch_v, (head0, new_prs0), (head1, new_prs1), sep='\t')
                        
                    ####################
                    
                    two_w_lst.append(mention_words)    
                
                #len mention_words > 2
                else:
                    boo, chap, ver = T.sectionFromNode(mention_words[0])
                    ch_v = f'{chap}:{ver}'
                    for w in mention_words:
                        boo, chap, ver = T.sectionFromNode(w)
                        g_prs = F.g_prs.v(w)
                        new_prs = Replace(g_prs)
                        gcons_word = F.g_cons.v(w)
                        phr_atom = L.u(w, 'phrase_atom')[0]
                        rela = F.rela.v(phr_atom)
                            
                        if new_prs:
                            print(gcons_word)
                    more_w_lst.append(mention_words)
                    
                    print(ch_v, len(mention_words), 
                          T.text(mention_words, fmt='text-trans-plain'), rela, sep='\t')
                
            for npnode in np_nodes:
                wnodes = (L.d(npnode, 'word'))
                
                typ = F.typ.v(npnode)
                #print(npnode, wnodes, T.text(phrnode, fmt='text-trans-plain'), typ, sep='\t')
                
            for wnode in word_nodes:
                pdp = F.pdp.v(wnode)
                g_cons = F.g_cons.v(wnode) #T.text(wnode, fmt='text-trans-plain')
                
                #print(wnode, g_cons, pdp, sep='\t')
    
    print('1 w: ', len(one_w_lst))
    print('2 w: ', len(two_w_lst))
    print('more w: ', len(more_w_lst))
    print(t)
ParseMentions('Psalms', 1, 150)
# Out:
# 1:1	3	>CRJ&H>JC 	NA
# QDCJ
# 2:6	3	YJWN HR&QDCJ00 	Appo
# 3:1	3	MZMWR LDWD 	Spec
# BNW
# 3:1	3	PNJ05 >BCLWM BNW00 	Appo
# 4:1	3	MZMWR LDWD00 	Spec
# DGNM
# TJRWCM
# 4:8	3	DGNM WTJRWCM 	NA
# 5:1	3	MZMWR LDWD00 	Spec
# MLKJ
# 5:3	3	MLKJ W>LHJ 	NA
# 5:6	3	KL&P<LJ >WN00 	NA
# 5:7	4	>JC&DMJM WMRMH 	NA
# 6:1	3	MZMWR LDWD00 	Spec
# 6:9	3	KL&P<LJ >WN 	NA
# 7:1	3	CGJWN LDWD 	Spec
# 7:1	4	DBRJ&KWC BN&JMJNJ00 	Appo
# YDQJ
# TMJ
# 7:9	3	YDQJ TMJ <LJ00 	Spec
# 7:10	3	LBWT WKLJWT 	NA
# 7:18	3	CM&JHWH <LJWN00 	NA
# 8:1	3	MZMWR LDWD00 	Spec
# 8:2	3	KL&H>RY 	NA
# 8:3	3	PJ <WLLJM05 JNQJM 	NA
# 8:3	3	>WJB WMTNQM00 	NA
# CMJK
# >YB<TJK
# 8:4	3	CMJK M<FJ >YB<TJK 	Appo
# 8:4	3	JRX WKWKBJM 	NA
# 8:6	3	KBWD WHDR 	NA
# KLM
# 8:8	4	YNH W>LPJM KLM 	Spec
# 8:8	3	GM BHMWT FDJ00 	NA
# 8:9	3	DGJ HJM 	NA
# 8:10	3	KL&H>RY00 	NA
# 9:1	4	<LMWT LBN 	Spec
# 9:1	3	MZMWR LDWD00 	Spec
# MCPVJ
# DJNJ
# 9:5	3	MCPVJ WDJNJ 	NA
# 9:10	4	MFGB LDK 	Spec
# 9:10	3	<TWT YRH00 	Spec
# 9:15	3	C<RJ BT&YJWN 	NA
# 10:1	3	<TWT YRH00 	Spec
# 10:7	3	MRMWT WTK 	NA
# 10:7	3	<ML W>WN00 	NA
# 10:14	3	<ML WK<S05 	NA
# 10:16	4	MLK <WLM W<D 	NA
# 10:18	3	JTWM WDK 	NA
# 10:18	4	>NWC MN&H>RY00 	Spec
# 11:5	4	RC< W>HB XMS 	NA
# 11:6	4	PXJM >C WGPRJT 	NA
# 12:1	3	MZMWR LDWD00 	Spec
# 12:4	3	KL&FPTJ XLQWT 	NA
# 12:6	4	CD <NJJM >NQT >BJWNJM 	Para
# 13:1	3	MZMWR LDWD00 	Spec
# 14:4	3	KL&P<LJ >WN 	NA
# 15:1	3	MZMWR LDWD 	Spec
# 16:1	3	MKTM LDWD 	Spec
# NSKJHM
# 16:4	3	NSKJHM MDM 	Spec
# XLQJ
# KWSJ
# 16:5	5	JHWH MNT&XLQJ WKWSJ 	Appo
# 17:1	3	TPLH LDWD 	Spec
# TPLTJ
# 17:1	5	TPLTJ BL> FPTJ MRMH00 	Spec
# 17:8	3	>JCWN BT&<JN 	NA
# 18:1	4	<BD JHWH LDWD 	Appo
# 18:1	5	DBRJ HCJRH HZ>T 	NA
# >JBJW
# 18:1	5	KP KL&>JBJW JD C>WL00 	NA
# SL<J
# MYWDTJ
# MPLVJ
# 18:3	5	SL<J WMYWDTJ WMPLVJ 	NA
# MGNJ
# JC<J
# MFGBJ
# 18:3	5	MGNJ WQRN&JC<J MFGBJ00 	NA
# LJ
# 18:7	3	YR&LJ05 	Spec
# CW<TJ
# PNJW
# 18:7	3	CW<TJ LPNJW05 	Spec
# 18:12	4	XCKT&MJM <BJ CXQJM00 	NA
# 18:13	4	BRD WGXLJ&>C00 	NA
# 18:14	4	BRD WGXLJ&>C00 	NA
# >PK
# 18:16	3	NCMT RWX >PK00 	NA
# >JBJ
# 18:18	3	>JBJ <Z FN>J 	NA
# 18:43	3	<PR PNJ&RWX 	Spec
# MCJXW
# ZR<W
# 18:51	6	MCJXW LDWD WLZR<W 	Appo
# 19:1	3	MZMWR LDWD00 	Spec
# 19:5	3	KL&H>RY05 	NA
# 19:7	3	QYH HCMJM05 	NA
# 19:11	3	DBC NPT YWPJM00 	NA
# PJ
# LBJ
# 19:15	5	>MRJ&PJ WHGJWN LBJ 	NA
# YWRJ
# G>LJ
# 19:15	4	JHWH YWRJ WG>LJ00 	Appo
# 20:1	3	MZMWR LDWD00 	Spec
# 20:2	3	CM05 >LHJ J<QB00 	NA
# JMJNW
# 20:7	3	GBRWT JC< JMJNW00 	NA
# >LHJNW
# 20:8	3	CM&JHWH >LHJNW 	Appo
# 21:1	3	MZMWR LDWD00 	Spec
# 21:5	5	>RK JMJM <WLM W<D00 	Spec
# 21:6	3	HWD WHDR 	NA
# 22:1	3	>JLT HCXR 	NA
# 22:1	3	MZMWR LDWD00 	Spec
# JCW<TJ
# C>GTJ
# 22:2	3	JCW<TJ DBRJ C>GTJ00 	Spec
# 22:17	3	JDJ WRGLJ00 	NA
# 22:24	3	KL&ZR< J<QB 	NA
# 22:24	3	KL&ZR< JFR>L00 	NA
# 22:28	3	KL&>PSJ&>RY 	NA
# 22:28	3	KL&MCPXWT GWJM00 	NA
# 22:30	3	KL&DCNJ&>RY 	NA
# 23:1	3	MZMWR LDWD 	Spec
# CBVK
# MC<NTK
# 23:4	3	CBVK WMC<NTK 	NA
# 23:6	4	>K05 VWB WXSD 	NA
# 23:6	3	KL&JMJ XJJ 	NA
# MLW>H
# 24:1	4	H>RY WMLW>H 	NA
# 24:4	5	NQJ KPJM WBR&LBB 	NA
# 24:7	3	MLK HKBWD00 	NA
# 24:8	3	MLK HKBWD 	NA
# 24:8	3	JHWH <ZWZ GBWR 	Spec
# 24:8	3	JHWH GBWR MLXMH00 	Spec
# 24:9	3	MLK HKBWD00 	NA
# 24:10	4	ZH MLK HKBWD 	Appo
# 24:10	3	MLK HKBWD 	NA
# QWJK
# 25:3	3	GM KL&QWJK 	NA
# 25:5	3	KL&HJWM00 	NA
# 25:7	4	XV>WT N<WRJ05 WPC<J 	NA
# 25:10	3	KL&>RXWT JHWH 	NA
# 25:10	3	XSD W>MT 	NA
# BRJTW
# <DTJW
# 25:10	3	BRJTW W<DTJW00 	NA
# <NJJ
# <MLJ
# 25:18	3	<NJJ W<MLJ 	NA
# 25:21	3	TM&WJCR 	NA
# LBJ
# 26:2	3	KLJWTJ WLBJ00 	NA
# BJTK
# KBWDK
# 26:8	6	M<WN BJTK WMQWM MCKN KBWDK00 	NA
# >WRJ
# JC<J
# 27:1	3	>WRJ WJC<J 	NA
# 27:2	3	YRJ W>JBJ 	NA
# 27:4	3	KL&JMJ XJJ 	NA
# >BJ
# >MJ
# 27:10	3	>BJ W>MJ 	NA
# 27:12	5	<DJ&CQR WJPX XMS00 	NA
# 27:13	4	VWB&JHWH >RY XJJM00 	Spec
# 28:3	3	RC<JM P<LJ >WN 	NA
# P<LM
# M<LLJHM
# 28:4	3	P<LM R< M<LLJHM 	NA
# JDJW
# 28:5	4	P<LT JHWH M<FH JDJW 	NA
# <ZJ
# MGNJ
# 28:7	3	<ZJ WMGNJ 	NA
# MCJXW
# 28:8	3	M<WZ JCW<WT MCJXW 	NA
# 29:1	3	KBWD W<Z00 	NA
# 29:3	3	>L&HKBWD 	NA
# 29:5	3	>RZJ HLBNWN00 	NA
# 29:10	3	MLK L<WLM00 	Spec
# 30:1	5	MZMWR CJR&XNKT HBJT 	Spec
# DMJ
# 30:10	3	BY< BDMJ 	Spec
# 31:1	3	MZMWR LDWD00 	Spec
# SL<J
# MYWDTJ
# 31:4	3	SL<J WMYWDTJ 	NA
# 31:6	3	JHWH >L >MT00 	Appo
# <JNJ
# NPCJ
# BVNJ
# 31:10	4	<JNJ NPCJ WBVNJ00 	NA
# 31:16	3	JD&>WJBJ RDPJ00 	NA
# 32:1	5	>CRJ NFWJ&PC< KSWJ XV>H00 	Spec
# 32:3	3	KL&HJWM00 	NA
# 32:11	3	KL&JCRJ&LB00 	NA
# 33:5	3	YDQH WMCPV 	NA
# 33:7	3	MJ HJM 	NA
# 33:8	3	KL&H>RY 	NA
# 33:8	3	KL&JCBJ TBL00 	NA
# 33:12	5	>CRJ HGWJ H<M05 	Para
# 33:13	4	KL&BNJ H>DM00 	NA
# 33:14	4	KL&JCBJ H>RY00 	NA
# <ZRNW
# MGNNW
# 33:20	3	<ZRNW WMGNNW 	NA
# 34:9	3	>CRJ HGBR 	NA
# 34:21	3	>XT MHNH 	Spec
# 35:2	3	MGN WYNH 	NA
# 35:5	3	MY PNJ&RWX 	Spec
# 35:6	3	XCK WXLQLQWT 	NA
# 35:10	3	<NJ W>BJWN 	NA
# 35:12	3	R<H TXT VWBH 	Spec
# NPCJ
# 35:12	3	CKWL LNPCJ00 	Spec
# LJ
# 35:14	3	R<&>X LJ 	Spec
# 35:16	3	XNPJ L<GJ M<WG 	NA
# 35:23	3	>LHJ W>DNJ 	NA
# 35:26	3	BCT WKLMH 	NA
# 35:28	3	KL&HJWM 	NA
# 36:1	4	<BD&JHWH LDWD00 	Appo
# 36:4	3	>WN WMRMH 	NA
# 36:7	3	>DM&WBHMH 	NA
# 37:14	3	<NJ W>BJWN 	NA
# 37:16	4	M<V LYDJQ 	Spec
# 37:26	3	KL&HJWM 	NA
# 38:1	3	MZMWR LDWD 	Spec
# 38:7	3	KL&HJWM 	NA
# 38:12	3	>HBJ05 WR<J 	NA
# 38:13	3	KL&HJWM 	NA
# 39:1	3	MZMWR LDWD00 	Spec
# 39:6	3	KL&>DM NYB 	NA
# 40:3	5	BWR C>WN VJV HJWN 	Para
# >LHJNW
# 40:4	3	THLH L>LHJNW 	Spec
# 40:5	3	>CRJ HGBR 	NA
# 40:5	3	RHBJM FVJ KZB00 	NA
# NPL>TJK
# MXCBTJK
# >LJNW
# 40:6	4	NPL>TJK WMXCBTJK >LJNW 	Spec
# 40:7	3	ZBX WMNXH05 	NA
# 40:7	3	<WLH WXV>H 	NA
# >MWNTK
# TCW<TK
# 40:11	3	>MWNTK WTCW<TK 	NA
# XSDK
# >MTK
# 40:11	3	XSDK W>MTK 	NA
# XSDK
# >MTK
# 40:12	3	XSDK W>MTK 	NA
# <ZRTJ
# MPLVJ
# 40:18	3	<ZRTJ WMPLVJ 	NA
# 41:1	3	MZMWR LDWD00 	Spec
# CLWMJ
# 41:10	3	GM&>JC CLWMJ05 	NA
# 41:14	3	JHWH05 >LHJ JFR>L 	Appo
# 41:14	4	H<WLM H<WLM 	NA
# 42:1	4	MFKJL LBNJ&QRX00 	Spec
# 42:3	4	>LHJM L>L XJ 	Appo
# 42:4	3	KL&HJWM 	NA
# 42:5	3	QWL&RNH TWDH 	NA
# >WDNW
# PNJW
# 42:6	3	>WDNW JCW<WT PNJW00 	Sfxs
# 42:7	5	>RY JRDN XRMWNJM HR MY<R00 	Para
# MCBRJK
# GLJK
# 42:8	4	KL&MCBRJK WGLJK 	NA
# 42:9	4	TPLH L>L XJJ00 	Spec
# 42:11	3	KL&HJWM 	NA
# >WDNW
# 42:12	4	>WDNW JCW<T PNJ >LHJ00 	Sfxs
# 43:1	3	>JC&MRMH <WLH 	NA
# >WRK
# >MTK
# 43:3	3	>WRK W>MTK 	NA
# QDCK
# MCKNWTJK
# 43:3	3	HR&QDCK MCKNWTJK00 	NA
# GJLJ
# 43:4	3	>L FMXT GJLJ 	NA
# >WDNW
# 43:5	4	>WDNW JCW<T PNJ >LHJ00 	Sfxs
# JMJHM
# 44:2	3	JMJHM JMJ QDM00 	Spec
# JMJNK
# ZRW<K
# PNJK
# 44:4	6	JMJNK WZRW<K W>WR PNJK 	NA
# 44:9	3	KL&HJWM 	NA
# 44:14	3	L<G WQLS 	NA
# 44:16	3	KL&HJWM 	NA
# 44:17	3	QWL MXRP MGDP 	NA
# 44:17	3	PNJ >WJB MTNQM00 	NA
# 44:23	3	KL&HJWM 	NA
# <NJNW
# LXYNW
# 44:25	3	<NJNW WLXYNW00 	NA
# 45:2	3	<V05 SWPR MHJR00 	NA
# HWDK
# HDRK
# 45:4	3	HWDK WHDRK00 	NA
# 45:5	4	DBR&>MT <NWH&YDQ 	NA
# 45:6	4	LB >WJBJ HMLK00 	NA
# 45:7	3	<WLM W<D 	NA
# 45:9	4	MR&W>HLWT QYJ<WT 	NA
# <MK
# >BJK
# 45:11	4	<MK WBJT >BJK00 	NA
# 45:17	3	KL&H>RY00 	NA
# 45:18	3	KL&DR DR 	NA
# 46:2	3	MXSH W<Z 	NA
# 46:5	5	<JR&>LHJM QDC MCKNJ <LJWN00 	Appo
# 46:10	3	QYH H>RY 	NA
# 47:2	3	KL&H<MJM 	NA
# 47:3	3	KL&H>RY00 	NA
# NXLTNW
# 47:5	4	NXLTNW >T G>WN J<QB 	Appo
# 47:8	4	MLK KL&H>RY 	NA
# 47:10	3	<M >LHJ >BRHM 	NA
# >LHJNW
# QDCW
# 48:2	4	<JR >LHJNW HR&QDCW00 	Appo
# 48:3	4	MFWF KL&H>RY 	NA
# 48:3	7	HR&YJWN JRKTJ YPWN QRJT MLK RB00 	Spec
# >LHJNW
# 48:9	6	<JR&JHWH YB>WT B<JR >LHJNW 	Appo
# 48:15	3	<WLM W<D 	NA
# 49:2	3	KL&H<MJM 	NA
# 49:2	3	KL&JCBJ XLD00 	NA
# 49:3	3	GM&BNJ >DM 	NA
# 49:3	3	GM&BNJ&>JC 	NA
# 49:3	3	<CJR W>BJWN00 	NA
# 49:11	3	KSJL WB<R 	NA
# 50:1	3	MZMWR L>SP 	Spec
# 50:1	3	>L05 >LHJM JHWH 	Appo
# 50:2	3	YJWN MKLL&JPJ 	Spec
# 50:4	5	HCMJM <L H>RY 	Para
# 50:10	3	KL&XJTW&J<R 	NA
# 50:10	4	BHMWT BHRRJ&>LP00 	Spec
# 50:11	3	KL&<WP HRJM 	NA
# ML>H
# 50:12	3	TBL WML>H00 	NA
# 51:1	3	MZMWR LDWD00 	Spec
# 51:2	3	NTN HNBJ> 	Appo
# 51:10	3	FFWN WFMXH 	NA
# TCW<TJ
# 51:16	3	>LHJM >LHJ TCW<TJ 	Appo
# 51:19	4	LB&NCBR WNDKH 	NA
# 51:21	5	ZBXJ&YDQ <WLH WKLJL 	NA
# 52:1	3	MFKJL LDWD00 	Spec
# 52:2	3	DW>G H>DMJ 	Appo
# 52:3	3	KL&HJWM00 	NA
# 52:6	3	KL&DBRJ&BL< 	NA
# 52:10	3	<WLM W<D00 	NA
# 53:1	3	MFKJL LDWD00 	Spec
# 54:1	3	MFKJL LDWD00 	Spec
# 55:1	3	MFKJL LDWD00 	Spec
# 55:4	3	PNJ <QT RC< 	NA
# 55:6	3	JR>H WR<D 	NA
# 55:7	4	>BR KJWNH 	Spec
# 55:10	3	XMS WRJB 	NA
# 55:11	3	>WN W<ML 	NA
# 55:12	3	TK WMRMH00 	NA
# <RKJ
# >LWPJ
# MJD<J
# 55:14	5	>TH >NWC <RKJ >LWPJ MJD<J00 	Spec
# 55:18	5	<RB WBQR WYHRJM 	NA
# 55:24	4	>NCJ DMJM WMRMH 	NA
# 56:1	3	JWNT >LM RXQJM 	NA
# 56:2	3	KL&HJWM 	NA
# 56:3	3	KL&HJWM 	NA
# 56:6	3	KL&HJWM 	NA
# 56:14	3	>WR HXJJM00 	NA
# XSDW
# >MTW
# 57:4	3	XSDW W>MTW00 	NA
# 57:5	3	XNJT WXYJM 	NA
# 57:6	3	KL&H>RY 	NA
# 57:9	4	HNBL WKNWR 	NA
# 57:12	3	KL&H>RY 	NA
# 58:5	3	DMWT XMT&NXC 	NA
# 58:6	4	QWL MLXCJM XWBR XBRJM 	Appo
# 58:11	3	DM HRC<00 	NA
# PC<J
# XV>TJ
# 59:4	5	L>&PC<J WL>&XV>TJ 	NA
# 59:6	6	>TH JHWH&>LHJM05 YB>WT >LHJ JFR>L 	Appo
# 59:6	3	KL&HGWJM 	NA
# 59:6	3	KL&BGDJ >WN 	NA
# 59:14	3	>PSJ H>RY 	NA
# 60:1	3	MKTM LDWD 	Spec
# 60:2	3	>RM_NHRJM >RM YWBH 	NA
# 60:2	3	CNJM <FR >LP00 	NA
# 60:13	3	<ZRT MYR 	Spec
# 61:3	3	QYH H>RY05 	NA
# 61:4	5	MGDL&<Z MPNJ >WJB00 	Spec
# CMK
# 61:6	3	JRCT JR>J CMK00 	NA
# 61:8	3	XSD W>MT 	NA
# 62:1	3	MZMWR LDWD00 	Spec
# YWRJ
# JCW<TJ
# 62:3	3	YWRJ WJCW<TJ 	NA
# YWRJ
# JCW<TJ
# 62:7	3	YWRJ WJCW<TJ 	NA
# JC<J
# KBWDJ
# 62:8	3	JC<J WKBWDJ 	NA
# <ZJ
# MXSJ
# 62:8	3	YWR&<ZJ MXSJ 	Appo
# 63:1	3	MZMWR LDWD 	Spec
# 63:2	4	>RY&YJH <JP MJM00 	Spec
# <ZK
# KBWDK
# 63:3	3	<ZK WKBWDK00 	NA
# 63:10	3	TXTJWT H>RY00 	NA
# 63:12	3	PJ DWBRJ&CQR00 	NA
# 64:1	3	MZMWR LDWD00 	Spec
# 64:3	3	RGCT P<LJ >WN00 	NA
# XYM
# 64:4	3	XYM DBR MR00 	Spec
# 64:7	4	QRB >JC WLB 	NA
# 64:11	3	KL&JCRJ&LB00 	NA
# 65:1	3	MZMWR LDWD 	Spec
# BJTK
# HJKLK
# 65:5	4	VWB BJTK QDC HJKLK00 	Appo
# JC<NW
# 65:6	9	>LHJ JC<NW MBVX KL&QYWJ&>RY WJM RXQJM00 	Spec
# GLJHM
# 65:8	7	C>WN JMJM C>WN GLJHM WHMWN L>MJM00 	NA
# 65:9	4	MWY>J&BQR W<RB 	NA
# 66:1	3	KL&H>RY00 	NA
# 66:4	3	KL&H>RY05 	NA
# 66:12	4	>C MJM 	NA
# LJ
# 66:14	3	YR&LJ00 	Spec
# 66:16	3	KL&JR>J >LHJM 	NA
# TPLTJ
# XSDW
# 66:20	3	TPLTJ WXSDW 	NA
# 67:8	3	KL&>PSJ&>RY00 	NA
# 68:6	5	>BJ JTWMJM WDJN >LMNWT 	NA
# QDCW
# 68:6	4	>LHJM BM<WN QDCW00 	Spec
# 68:9	4	PNJ >LHJM >LHJ JFR>L00 	Appo
# 68:18	3	RBTJM >LPJ CN>N 	Spec
# 68:21	3	>L LMWC<WT 	Spec
# >LJ
# MLKJ
# 68:25	3	HLJKWT >LJ MLKJ 	Appo
# RGMTM
# 68:28	3	FRJ JHWDH RGMTM 	Spec
# 68:33	3	MMLKWT H>RY 	NA
# 68:34	3	CMJ CMJ&QDM 	NA
# QWLW
# 68:34	3	QWLW QWL <Z00 	Spec
# 68:36	3	<Z WT<YMWT 	NA
# 69:7	3	>DNJ JHWH YB>WT 	Appo
# NPCJ
# 69:11	3	YWM NPCJ 	Spec
# 69:13	3	NGJNWT CWTJ CKR00 	NA
# 69:15	3	FN>J M<MQJ&MJM00 	NA
# XRPTJ
# BCTJ
# KLMTJ
# 69:20	5	XRPTJ WBCTJ WKLMTJ 	NA
# 69:35	3	CMJM W>RY 	NA
# 69:35	3	JMJM WKL&	NA
# <ZRJ
# MPLVJ
# 70:6	3	<ZRJ WMPLVJ 	NA
# SL<J
# MYWDTJ
# 71:3	3	SL<J WMYWDTJ 	NA
# 71:4	3	KP M<WL XWMY00 	NA
# 71:8	3	KL&HJWM 	NA
# 71:13	3	XRPH WKLMH 	NA
# 71:15	3	KL&HJWM 	NA
# 71:16	3	GBRWT >DNJ JHWH 	NA
# 71:20	4	YRWT RBWT WR<WT 	NA
# 71:20	3	THMWT H>RY 	NA
# 71:24	3	KL&HJWM 	NA
# 72:5	3	CMC PNJ JRX 	Para
# 72:6	3	RBJBJM ZRZJP >RY00 	Spec
# 72:8	5	JM JM NHR >PSJ&>RY00 	Spec
# 72:10	4	MLKJ TRCJC W>JJM 	NA
# 72:10	4	MLKJ CB> WSB> 	NA
# 72:15	3	KL&HJWM 	NA
# 72:16	3	<FB H>RY00 	NA
# 72:18	4	JHWH >LHJM >LHJ JFR>L 	Appo
# 72:19	3	KL H>RY 	NA
# 72:20	4	TPLWT DWD BN&JCJ00 	Appo
# 73:1	3	MZMWR L>SP 	Spec
# 73:14	3	KL&HJWM 	NA
# C>RJ
# LBBJ
# 73:26	3	C>RJ WLBBJ 	NA
# LBBJ
# XLQJ
# 73:26	4	YWR&LBBJ WXLQJ 	NA
# 74:1	3	MFKJL L>SP 	Spec
# NXLTK
# 74:2	4	CBV NXLTK HR&YJWN 	Appo
# 74:8	3	KL&MW<DJ&>L 	NA
# JDK
# JMJNK
# 74:11	3	JDK WJMJNK 	NA
# 74:12	3	QRB H>RY00 	NA
# 74:15	3	M<JN WNXL 	NA
# 74:16	3	M>WR WCMC00 	NA
# 74:17	3	KL&GBWLWT >RY 	NA
# 74:17	3	QJY WXRP 	NA
# 74:21	3	<NJ W>BJWN 	NA
# 74:22	3	KL&HJWM00 	NA
# 75:1	3	MZMWR L>SP 	Spec
# JCBJH
# 75:4	4	>RY WKL&JCBJH 	NA
# 75:9	3	KL RC<J&>RY00 	NA
# 75:11	3	KL&QRNJ RC<JM 	NA
# 76:1	3	MZMWR L>SP 	Spec
# 76:4	7	RCPJ&QCT MGN WXRB WMLXMH 	NA
# 76:6	3	KL&>NCJ&XJL 	NA
# 76:7	3	RKB WSWS00 	NA
# 76:10	3	KL&<NWJ&>RY 	NA
# 77:6	5	JMJM MQDM CNWT <WLMJM00 	Para
# <MK
# 77:16	5	<MK BNJ&J<QB WJWSP 	Appo
# 77:21	3	JD&MCH >HRN00 	NA
# 78:1	3	MFKJL L>SP 	Spec
# 78:2	3	XJDWT MNJ&QDM00 	Spec
# <ZWZW
# NPL>WTJW
# 78:4	6	THLWT JHWH W<ZWZW WNPL>WTJW 	NA
# >BWTM
# 78:8	3	>BWTM DWR DWR 	Spec
# 78:9	5	BNJ&>PRJM NWCQJ RWMJ&QCT 	Spec
# <LJLWTJW
# NPL>WTJW
# 78:11	3	<LJLWTJW WNPL>WTJW 	NA
# 78:12	4	>RY MYRJM FDH&Y<N00 	Spec
# 78:14	3	KL&HLJLH 	NA
# 78:23	3	CXQJM MM<L 	Spec
# MXNHW
# MCKNTJW
# 78:28	3	QRB MXNHW MCKNTJW00 	Spec
# J>RJHM
# NZLJHM
# 78:44	3	J>RJHM WNZLJHM 	NA
# >PW
# 78:49	10	XRWN >PW <BRH WZ<M WYRH MCLXT ML>KJ R<JM00 	Spec
# 78:51	4	KL&BKWR BMYRJM 	Spec
# QDCW
# 78:54	4	GBWL QDCW HR&ZH 	Appo
# 78:60	3	MCKN CLW >HL 	Spec
# 78:68	5	CBV JHWDH >T&HR YJWN 	Appo
# <MW
# NXLTW
# 78:71	4	J<QB <MW JFR>L NXLTW00 	Appo
# 79:1	3	MZMWR L>SP 	Spec
# 79:2	3	<WP HCMJM 	NA
# 79:4	3	L<G WQLS 	NA
# CMK
# 79:9	3	DBR KBWD&CMK 	NA
# <BDJK
# 79:10	3	NQMT DM&<BDJK 	NA
# <MK
# MR<JTK
# 79:13	5	>NXNW <MK05 WY>N MR<JTK 	Appo
# 80:1	3	<DWT L>SP 	Spec
# 80:3	4	PNJ >PRJM05 BNJMN MNCH 	NA
# 80:5	3	JHWH >LHJM YB>WT 	Appo
# 80:13	3	KL&<BRJ DRK00 	NA
# 80:14	3	XZJR MJ<R 	Spec
# 80:20	3	JHWH >LHJM YB>WT 	Appo
# 81:3	4	KNWR N<JM <M&NBL00 	Spec
# XGNW
# 81:4	4	KSH JWM XGNW00 	Spec
# 81:5	3	XQ LJFR>L 	Spec
# 81:5	4	MCPV L>LHJ J<QB00 	Spec
# 82:1	3	MZMWR L>SP 	Spec
# 82:3	3	DL WJTWM 	NA
# 82:3	3	<NJ WRC 	NA
# 82:4	3	DL W>BJWN 	NA
# 82:5	3	KL&MWSDJ >RY00 	NA
# 82:7	3	>XD HFRJM 	NA
# 82:8	3	KL&HGWJM00 	NA
# 83:1	3	MZMWR L>SP00 	Spec
# 83:7	7	>HLJ >DWM WJCM<>LJM MW>B WHGRJM00 	NA
# 83:8	6	GBL <MWN <MLQ PLCT JCBJ YWR00 	Spec
# 83:10	5	MDJN SJSR> JBJN NXL QJCWN00 	Spec
# 83:14	3	QC PNJ&RWX00 	Spec
# 83:19	5	<LJWN <L&KL&H>RY00 	Spec
# LBJ
# BFRJ
# 84:3	3	LBJ WBFRJ 	NA
# MLKJ
# 84:4	5	JHWH YB>WT MLKJ W>LHJ00 	Appo
# 84:7	3	<MQ HBK> 	NA
# 84:9	3	JHWH >LHJM YB>WT 	Appo
# XYRJK
# 84:11	3	JWM BXYRJK 	Spec
# 84:12	3	CMC05 WMGN 	NA
# 84:12	3	XN WKBWD 	NA
# 85:9	3	H>L05 JHWH 	Appo
# 85:11	3	XSD&W>MT 	NA
# 85:11	3	YDQ WCLWM 	NA
# 86:1	3	TPLH LDWD 	Spec
# 86:3	3	KL&HJWM00 	NA
# 86:15	4	>L&RXWM WXNWN 	NA
# 86:15	3	>PJM XSD >MT00 	NA
# 86:17	3	>WT LVWBH 	Spec
# 87:2	3	KL MCKNWT J<QB00 	NA
# 87:3	3	<JR H>LHJM 	NA
# 87:4	3	PLCT YWR KWC 	Spec
# 87:5	3	>JC W>JC 	NA
# 88:1	4	MZMWR LBNJ QRX 	Spec
# 88:1	3	HJMN H>ZRXJ00 	Appo
# JCW<TJ
# 88:2	3	JHWH >LHJ JCW<TJ 	Appo
# 88:6	3	XLLJM05 CKBJ QBR 	Appo
# 88:7	4	BWR TXTJWT MXCKJM MYLWT00 	Spec
# 88:18	3	KL&HJWM 	NA
# 88:19	3	>HB WR< 	NA
# 89:1	5	MFKJL L>JTN H>ZRXJ00 	Appo
# 89:9	3	JHWH05 >LHJ YB>WT 	Appo
# 89:10	3	G>WT HJM 	NA
# ML>H
# 89:12	3	TBL WML>H 	NA
# 89:13	3	YPWN WJMJN 	NA
# 89:14	3	ZRW< <M&GBWRH 	Spec
# 89:15	3	YDQ WMCPV 	NA
# 89:15	3	XSD W>MT 	NA
# 89:16	3	>CRJ H<M 	NA
# 89:17	3	KL&HJWM 	NA
# >MWNTJ
# XSDJ
# 89:25	3	>MWNTJ WXSDJ 	NA
# >LJ
# JCW<TJ
# 89:27	4	>LJ WYWR JCW<TJ00 	NA
# 89:28	4	<LJWN LMLKJ&>RY00 	Spec
# 89:38	4	<D BCXQ 	Spec
# 89:42	3	KL&<BRJ DRK 	NA
# 89:48	3	KL&BNJ&>DM00 	NA
# XSDJK
# 89:50	3	XSDJK HR>CNJM05 	NA
# 89:51	3	KL&RBJM <MJM00 	NA
# 90:1	6	TPLH LMCH >JC&H>LHJM 	Appo
# 90:2	3	>RY WTBL 	NA
# 90:4	4	>CMWRH BLJLH00 	Spec
# 90:10	3	<ML W>WN 	NA
# >LHJNW
# 90:17	3	N<M >DNJ >LHJNW 	Appo
# MXSJ
# MYWDTJ
# 91:2	4	MXSJ WMYWDTJ >LHJ 	Appo
# 91:4	3	YNH WSXRH 	NA
# 91:13	3	KPJR WTNJN00 	NA
# 92:1	5	CJR LJWM HCBT00 	Spec
# 92:4	4	<FWR NBL HGJWN KNWR00 	Spec
# 92:8	3	KL&P<LJ >WN 	NA
# 92:10	3	KL&P<LJ >WN00 	NA
# 92:13	3	>RZ LBNWN 	Spec
# 94:2	3	CPV H>RY 	NA
# 94:4	3	KL&P<LJ >WN00 	NA
# 94:6	3	>LMNH WGR 	NA
# 94:8	4	B<RJM B<M 	Spec
# 94:12	3	>CRJ05 HGBR 	NA
# 94:15	3	KL&JCRJ&LB00 	NA
# QRBJ
# 94:19	3	RB FR<PJ QRBJ 	Spec
# 95:3	5	MLK GDWL <L&KL&>LHJM00 	Spec
# MR<JTW
# JDW
# 95:7	5	<M MR<JTW WY>N JDW 	NA
# 95:8	4	JWM MSH MDBR00 	Spec
# 95:10	3	<M T<J LBB 	Spec
# 96:1	3	KL&H>RY00 	NA
# 96:3	3	KL&H<MJM 	NA
# 96:5	4	KL&>LHJ H<MJM 	NA
# 96:6	3	HWD&WHDR 	NA
# 96:6	3	<Z WTP>RT 	NA
# 96:7	3	KBWD W<Z00 	NA
# 96:9	3	KL&H>RY00 	NA
# ML>W
# 96:11	4	HJM WML>W00 	NA
# 96:12	3	FDJ WKL&	NA
# 96:12	3	KL&<YJ&J<R00 	NA
# 97:2	3	<NN W<RPL 	NA
# 97:2	3	YDQ WMCPV 	NA
# 97:5	9	PNJ JHWH MLPNJ >DWN KL&H>RY00 	Appo
# 97:6	3	KL&H<MJM 	NA
# 97:7	3	KL&<BDJ PSL 	NA
# 97:9	5	<LJWN <L&KL&H>RY 	Spec
# JMJNW
# QDCW
# 98:1	4	JMJNW WZRW< QDCW00 	NA
# 98:2	3	<JNJ HGWJM 	NA
# XSDW
# >MWNTW
# 98:3	3	XSDW05 W>MWNTW 	NA
# 98:3	3	KL&>PSJ&>RY 	NA
# 98:4	3	KL&H>RY 	NA
# 98:5	3	KNWR QWL ZMRH00 	NA
# 98:6	3	XYYRWT QWL CWPR 	NA
# 98:6	4	PNJ05 HMLK JHWH00 	Appo
# ML>W
# 98:7	4	HJM WML>W 	NA
# BH
# 98:7	4	TBL WJCBJ BH00 	Spec
# 99:2	3	KL&H<MJM00 	NA
# CMK
# 99:3	4	CMK GDWL WNWR> 	NA
# 99:4	3	MCPV WYDQH 	NA
# <DTJW
# 99:7	3	<DTJW WXQ 	NA
# 100:1	3	MZMWR LTWDH 	Spec
# 100:1	3	KL&H>RY00 	NA
# <MW
# MR<JTW
# 100:3	4	>NXNW <MW Y>N MR<JTW00 	Spec
# 101:1	3	XSD&WMCPV 	NA
# 101:5	5	GBH&<JNJM WRXB LBB 	NA
# 101:8	3	KL&RC<J&>RY 	NA
# 101:8	3	KL&P<LJ >WN00 	NA
# 102:1	3	TPLH L<NJ 	Spec
# 102:9	3	KL&HJWM 	NA
# Z<MK
# QYPK
# 102:11	3	PNJ&Z<MK QYPK 	NA
# 102:16	4	KL&MLKJ H>RY 	NA
# 102:18	3	TPLT H<R<R 	NA
# 103:4	3	XSD WRXMJM00 	NA
# 103:15	3	YJY HFDH 	NA
# BRJTW
# PQDJW
# 103:18	4	CMRJ BRJTW ZKRJ PQDJW 	NA
# ML>KJW
# 103:20	3	ML>KJW GBRJ KX 	Spec
# YB>JW
# MCRTJW
# 103:21	3	KL&YB>JW MCRTJW 	Appo
# M<FJW
# MMCLTW
# 103:22	6	KL&M<FJW BKL&MQMWT MMCLTW 	Spec
# 104:1	3	HWD WHDR 	NA
# 104:5	3	<WLM W<D00 	NA
# 104:11	3	KL&XJTW FDJ 	NA
# 104:12	3	<WP&HCMJM 	NA
# 104:14	3	<BDT H>DM 	NA
# 104:18	3	HRJM HGBHJM 	NA
# 104:18	4	MXSH LCPNJM00 	Spec
# 104:20	3	KL&XJTW&J<R00 	NA
# 104:25	4	XJWT QVNWT <M&GDLWT00 	Spec
# 105:3	3	LB05 MBQCJ JHWH00 	NA
# MPTJW
# PJW
# 105:5	4	MPTJW WMCPVJ&PJW00 	NA
# <BDW
# 105:6	3	ZR< >BRHM <BDW 	Appo
# BXJRJW
# 105:6	3	BNJ J<QB BXJRJW00 	Appo
# 105:7	3	KL&H>RY 	NA
# 105:12	4	MTJ MSPR KM<V 	Spec
# 105:16	3	KL&MVH&LXM 	NA
# GPNM
# T>NTM
# 105:33	3	GPNM WT>NTM 	NA
# >RYM
# 105:35	4	KL&<FB B>RYM 	Spec
# >RYM
# 105:36	4	KL&BKWR B>RYM 	Spec
# >WNM
# 105:36	4	R>CJT LKL&>WNM00 	Spec
# >BWTJNW
# 106:7	3	>BWTJNW BMYRJM05 	Spec
# 106:7	3	JM JM&SWP00 	Spec
# 106:16	3	>HRN QDWC JHWH00 	Appo
# 106:31	3	DR DR <WLM00 	Spec
# BNJHM
# BNWTJHM
# 106:38	6	DM NQJ DM&BNJHM WBNWTJHM 	Spec
# LHM
# 106:44	3	YR LHM 	Spec
# CWBJHM
# 106:46	3	PNJ KL&CWBJHM00 	NA
# 106:48	3	JHWH >LHJ JFR>L 	Appo
# 106:48	4	H<WLM05 H<WLM 	NA
# 106:48	3	KL&H<M 	NA
# 107:3	5	>RYWT MZRX M<RB YPWN JM00 	Spec
# LHM
# 107:6	3	YR LHM 	Spec
# XSDW
# NPL>WTJW
# 107:8	6	XSDW WNPL>WTJW LBNJ >DM00 	Spec
# 107:10	3	XCK WYLMWT 	NA
# 107:10	4	>SJRJ <NJ WBRZL00 	NA
# LHM
# 107:13	3	YR LHM 	Spec
# XSDW
# NPL>WTJW
# 107:15	6	XSDW WNPL>WTJW LBNJ >DM00 	Spec
# PC<M
# <WNTJHM
# 107:17	3	DRK PC<M <WNTJHM 	NA
# LHM
# 107:19	3	YR LHM 	Spec
# XSDW
# NPL>WTJW
# 107:21	6	XSDW WNPL>WTJW LBNJ >DM00_| 	Spec
# NPL>WTJW
# 107:24	6	M<FJ JHWH WNPL>WTJW BMYWLH00_| 	Spec
# LHM
# 107:28	3	YR LHM 	Spec
# XSDW
# NPL>WTJW
# 107:31	6	XSDW WNPL>WTJW LBNJ >DM00 	Spec
# BH
# 107:34	3	R<T JCBJ BH00 	NA
# 107:39	3	<YR R<H JGWN00_| 	NA
# 108:1	3	MZMWR LDWD00 	Spec
# 108:3	4	HNBL WKNWR 	NA
# 108:6	3	KL&H>RY 	NA
# 108:13	3	<ZRT MYR 	Spec
# 109:2	5	PJ RC< WPJ&MRMH 	NA
# 109:16	7	>JC&<NJ W>BJWN WNK>H LBB 	NA
# >DNJ
# 110:1	4	N>M JHWH05 L>DNJ 	Spec
# RGLJK
# 110:1	3	HDM LRGLJK00 	Spec
# XJLK
# 110:3	4	JWM XJLK HDRJ&QDC 	Spec
# 110:6	4	R>C <L&>RY RBH00 	Spec
# 110:7	3	NXL DRK 	Spec
# 111:1	3	SWD JCRJM <DH00 	NA
# 111:3	3	HWD&WHDR 	NA
# 111:7	3	>MT WMCPV 	NA
# 112:2	4	GBWR B>RY 	Spec
# 112:3	3	HWN&W<CR 	NA
# 112:5	4	>JC XWNN WMLWH 	NA
# MBW>W
# 113:3	3	MZRX&CMC MBW>W 	Spec
# 113:6	4	CMJM >RY00 	NA
# <MW
# 113:8	3	NDJBJM NDJBJ <MW00 	Spec
# 113:9	3	>M&HBNJM 	NA
# 114:7	3	PNJ >LWH J<QB00 	NA
# 115:4	3	KSP WZHB 	NA
# 115:4	3	M<FH JDJ >DM00 	NA
# <ZRM
# MGNM
# 115:9	3	<ZRM WMGNM 	NA
# <ZRM
# MGNM
# 115:10	3	<ZRM WMGNM 	NA
# <ZRM
# MGNM
# 115:11	3	<ZRM WMGNM 	NA
# 115:13	7	JR>J JHWH HQVNJM <M&HGDLJM00 	Spec
# <LJKM
# <LJKM
# BNJKM
# 115:14	3	<LJKM <LJKM BNJKM00 	Spec
# 115:15	4	JHWH <FH CMJM >RY00 	Spec
# 115:16	3	CMJM LJHWH 	Spec
# 115:17	3	KL&JRDJ DWMH00 	NA
# 116:3	3	YRH WJGWN 	NA
# 116:9	3	>RYWT HXJJM00 	NA
# 116:11	3	KL&H>DM 	NA
# TGMWLWHJ
# 116:12	3	KL&TGMWLWHJ <LJ00 	Spec
# XSJDJW
# 116:15	4	HMWTH LXSJDJW00 	Spec
# <BDK
# >MTK
# 116:16	3	<BDK BN&>MTK 	Appo
# 116:19	3	XYRWT05 BJT JHWH 	NA
# 117:1	3	KL&H>MJM00 	NA
# <ZJ
# 118:14	3	<ZJ WZMRT 	NA
# 118:15	4	QWL05 RNH WJCW<H 	NA
# 118:20	4	HC<R LJHWH 	Spec
# 118:27	3	QRNWT HMZBX00 	NA
# 119:1	3	>CRJ TMJMJ&DRK 	NA
# PJK
# 119:13	3	KL MCPVJ&PJK00 	NA
# TWRTK
# 119:18	3	NPL>WT MTWRTK00 	Spec
# 119:22	3	XRPH WBWZ 	NA
# 119:66	4	VWB V<M WD<T 	NA
# 119:72	3	>LPJ ZHB KSP00 	NA
# 119:97	3	KL&HJWM 	NA
# 119:104	3	KL&>RX CQR00 	NA
# RGLJ
# 119:105	3	NR&LRGLJ 	Spec
# NTJBTJ
# 119:105	3	>WR LNTJBTJ00 	Spec
# STRJ
# MGNJ
# 119:114	3	STRJ WMGNJ 	NA
# 119:119	3	KL&RC<J&>RY 	NA
# 119:121	3	MCPV WYDQ 	NA
# JCW<TK
# YDQK
# 119:123	3	JCW<TK >MRT YDQK00 	NA
# 119:128	3	KL&PQWDJ KL 	NA
# 119:128	3	KL&>RX CQR 	NA
# CMK
# 119:132	3	MCPV >HBJ CMK00 	Spec
# <DTJK
# 119:138	4	YDQ <DTJK W>MWNH 	NA
# 119:142	3	YDQ L<WLM 	Spec
# 119:143	3	YR&WMYWQ 	NA
# 119:157	3	RDPJ WYRJ 	NA
# YDQK
# 119:160	3	KL&MCPV YDQK00 	NA
# 119:164	4	CB< BJWM 	Spec
# PQWDJK
# <DTJK
# 119:168	3	PQWDJK W<DTJK 	NA
# 120:1	3	CJR HM<LWT 	NA
# LJ
# 120:1	3	YRTH LJ 	Spec
# 121:1	4	CJR LM<LWT 	Spec
# 121:2	4	JHWH <FH CMJM >RY00 	Spec
# YLK
# JMJNK
# 121:5	4	YLK <L&JD JMJNK00 	Spec
# 122:1	3	CJR HM<LWT 	NA
# 122:4	3	CBVJM CBVJ&JH 	Spec
# 122:5	3	KS>WT LMCPV 	Spec
# 122:5	4	KS>WT LBJT DWJD00 	Spec
# >LHJNW
# 122:9	3	BJT&JHWH >LHJNW 	Appo
# 123:1	3	CJR HM<LWT 	NA
# 123:4	4	HL<G HC>NNJM 	Spec
# 123:4	5	HBWZ LG>JWNJM 	Spec
# 124:1	3	CJR HM<LWT 	NA
# 124:5	4	HMJM HZJDWNJM00 	NA
# 124:8	5	CM JHWH <FH CMJM >RY00 	Spec
# 125:1	3	CJR HM<LWT 	NA
# 125:3	3	CBV HRC< 	NA
# 125:3	3	GWRL HYDJQJM 	NA
# LBWTM
# 125:4	4	VWBJM JCRJM LBWTM00 	Spec
# 125:5	3	P<LJ H>WN 	NA
# 126:1	3	CJR HM<LWT 	NA
# 126:4	3	>PJQJM NGB00 	Spec
# 126:6	3	MCK&HZR< 	NA
# 127:1	3	CJR HM<LWT 	NA
# 127:2	3	LXM H<YBJM 	NA
# 127:3	3	PRJ HBVN00 	NA
# 127:4	3	XYJM JD&GBWR 	Spec
# 127:4	3	BNJ HN<WRJM00 	NA
# 127:5	3	>CRJ HGBR 	NA
# 128:1	3	CJR HM<LWT 	NA
# 128:1	4	>CRJ KL&JR> JHWH 	NA
# BJTK
# 128:3	3	GPN JRKTJ BJTK 	Spec
# XJJK
# 128:5	3	KL JMJ XJJK00 	NA
# BNJK
# 128:6	3	BNJM LBNJK 	Spec
# 129:1	3	CJR HM<LWT 	NA
# 129:5	3	KL FN>J YJWN00 	NA
# 130:1	3	CJR HM<LWT 	NA
# 131:1	3	CJR HM<LWT 	NA
# MMNJ
# 131:1	3	GDLWT NPL>WT MMNJ00 	Spec
# 131:2	3	GML <LJ 	Spec
# 132:1	3	CJR HM<LWT 	NA
# <ZK
# 132:8	3	>TH >RWN <ZK00 	NA
# <BDK
# 132:10	3	<BWR DWD <BDK 	Appo
# BRJTJ
# <DTJ
# 132:12	3	BRJTJ W<DTJ 	NA
# 133:1	3	CJR HM<LWT 	NA
# 133:2	6	CMN HVWB05 HR>C 	Spec
# 133:2	4	HZQN ZQN&>HRN 	Appo
# 133:3	4	XJJM <D&H<WLM00 	Spec
# 134:1	3	CJR HM<LWT 	NA
# 134:1	3	KL&<BDJ JHWH 	NA
# 134:3	3	CMJM W>RY00 	NA
# >LHJNW
# 135:2	6	BJT JHWH BXYRWT BJT >LHJNW00 	Appo
# 135:6	8	CMJM >RY JMJM KL&THWMWT00 	NA
# 135:7	3	QYH H>RY 	NA
# 135:9	3	>TWT WMPTJM 	NA
# <BDJW
# 135:9	3	PR<H KL&<BDJW00 	NA
# 135:11	11	SJXWN05 MLK H>MRJ <WG MLK HBCN KL MMLKWT KN<N00 	Para
# 135:15	3	<YBJ HGWJM 	NA
# 135:15	3	KSP WZHB 	NA
# 135:15	3	M<FH JDJ >DM00 	NA
# 135:20	3	BJT HLWJ 	NA
# 136:2	3	>LHJ H>LHJM 	NA
# 136:3	3	>DNJ H>DNJM 	NA
# 136:8	3	MMCLT JWM 	Spec
# 136:9	3	HJRX KWKBJM 	NA
# 136:9	3	MMCLWT LJLH 	Spec
# XJLW
# 136:15	3	PR<H WXJLW 	NA
# 136:19	4	SJXWN MLK H>MRJ 	Appo
# 136:20	4	<WG MLK HBCN 	Appo
# 136:26	3	>L HCMJM 	NA
# BH
# 137:7	3	HJSWD BH00 	Spec
# 138:4	3	KL&MLKJ&>RY 	NA
# 140:1	3	MZMWR LDWD00 	Spec
# JCW<TJ
# 140:8	4	JHWH >DNJ <Z JCW<TJ 	Appo
# 140:12	3	>JC&XMS R< 	NA
# 140:13	4	DJN <NJ MCPV >BJNJM00 	Spec
# 141:1	3	MZMWR LDWD 	Spec
# 141:9	3	MQCWT P<LJ >WN00 	NA
# 142:1	3	MFKJL LDWD 	Spec
# NPCJ
# 142:5	3	DWRC LNPCJ00 	Spec
# XLQJ
# 142:6	5	XLQJ B>RY HXJJM00 	Spec
# 143:1	3	MZMWR LDWD 	Spec
# 143:5	3	JMJM05 MQDM 	Spec
# NPCJ
# 143:12	3	KL&YRRJ NPCJ 	NA
# XSDJ
# MYWDTJ
# MFGBJ
# MPLVJ
# 144:2	6	XSDJ WMYWDTJ MFGBJ WMPLVJ 	NA
# 144:7	3	JD BNJ NKR00 	NA
# 144:11	3	JD BNJ&NKR 	NA
# 144:15	3	>CRJ H<M 	NA
# 144:15	3	>CRJ H<M 	NA
# 145:1	3	THLH LDWD 	Spec
# 145:1	3	>LWHJ HMLK 	Appo
# HWDK
# NPL>WTJK
# 145:5	6	HDR KBWD HWDK WDBRJ NPL>WTJK 	NA
# VWBK
# 145:7	3	ZKR RB&VWBK 	NA
# 145:12	3	BNJ H>DM 	NA
# GBWRTJW
# MLKWTW
# 145:12	5	GBWRTJW WKBWD HDR MLKWTW00 	NA
# 145:13	3	MLKWT KL&<LMJM 	NA
# 145:13	3	KL&DWR DWR00 	NA
# 145:20	3	KL&HRC<JM 	NA
# 146:4	4	JWM HHW> 	NA
# 146:6	3	CMJM W>RY 	NA
# 146:6	3	HJM KL&	NA
# 146:9	3	JTWM W>LMNH 	NA
# 147:10	3	GBWRT HSWS 	NA
# 147:10	3	CWQJ H>JC 	NA
# XSDW
# 147:11	3	HMJXLJM XSDW00 	Spec
# BNJK
# QRBK
# 147:13	3	BNJK BQRBK00 	Spec
# XQJW
# MCPVJW
# 147:19	3	XQJW WMCPVJW 	NA
# 148:3	3	CMC WJRX 	NA
# 148:3	3	KL&KWKBJ >WR00 	NA
# 148:4	6	CMJ HCMJM WHMJM 	NA
# 148:7	4	TNJNJM WKL&THMWT00 	NA
# 148:8	8	>C WBRD CLG WQJVWR RWX S<RH 	NA
# 148:9	5	HHRJM WKL&GB<WT 	NA
# 148:9	5	<Y PRJ WKL&>RZJM00 	NA
# 148:10	5	HXJH WKL&BHMH 	NA
# 148:10	4	RMF WYPWR KNP00 	NA
# 148:11	5	MLKJ&>RY WKL&L>MJM 	NA
# 148:11	5	FRJM WKL&CPVJ >RY00 	NA
# 148:12	4	BXWRJM WGM&BTWLWT 	NA
# 148:12	3	ZQNJM <M&N<RJM00 	Spec
# XSJDJW
# QRBW
# 148:14	6	KL&XSJDJW BNJ JFR>L <M&QRBW 	Appo
# 150:6	3	KL HNCMH 	NA
# 1 w:  3490
# 2 w:  1930
# more w:  786
# 9

# %%
def PlaceMentions(mentions, file_table):
    '''
    Relocates the mentions and to the corresponding ann file. 
    '''
    
    i = 0
    for m in mentions:
        i += 1
        file_table[m.file].write(f'T{str(i)}{TAB}Mention {str(m.start)} {str(m.end)}{TAB}{m.lex}{NL}')
        #(f'{m.name}{TAB}Mention {str(m.start)} {str(m.end)}{TAB}{m.lex}{NL}')

# %%
def WriteCoref(mention_list, file_table):
    '''
    Writes a coref class with mentions to .ann file object.
    '''
    
    file_table.write(f'*{TAB}Coreference')
    for m in mention_list:
        file_table.write(f' {m}')
    file_table.write('\n')

# %%
def PlaceCorefs(corefs, file_table):
    '''
    Creates a 'table' with an empty list of mentions 
    for each *.ann file to be written.
    
    Relocates the mentions to the ann file 
    in which the Mention.name occurs. 
    'table[i]' is a list with Mention.names.
    '''
    
    for c in corefs:
        table = []
        for i in range(len(file_table)):
            table.append([])   
        for m in c:
            table[m.file].append(m.name)
        for i in range(len(table)):
            if len(table[i]) > 1:
                WriteCoref(table[i], file_table[i])

# %%
def CloseAnns(ann_file_table): 
    '''
    Close all ann file objects.
    '''
    
    for file in ann_file_table:
        file.close()

# %%
def CreateCoref(my_book_name, first_chapter, last_chapter):
    txt_f, ann_f, tsv_f, chapter_list = OpenFiles(my_book_name, first_chapter, last_chapter)
    words_list = WriteText(txt_f, tsv_f, chapter_list)
    
    index_dict = MakeIndex(txt_f, words_list) # make index tabel for words from txt files, 
    # dict: key: node, value: tuple(begin index end index)
    # ook voor Mention.suffix een index maken, kijk naar ReplaceSuffix() voor hints. 
    
    Mentions = ParseMentions(chapter_nodes) # lijst van mention objecten
    
    # zoals in ctt: - als scheidingsteken tussen woorden, spatie tussen woordgroepen
    # + als scheidingsteken tussen suffix en subs
    # txt files die zo gemaakt worden door WriteTxt() indexeren voor m.start en m.end, 
    # en niet de tf text string zoals nu
    # +suffix, g_cons en g_prs gebruiken --> consonant string, matchen achterkant woord  
    
    corefs = ResolveCoref(mentions)
    
    PlaceMentions(mentions, ann_file) #ann_file_table weghalen, niet nodig 
    PlaceCorefs(corefs, ann_file)
    CloseAnn(ann_file)
    
# 3 uitvoer files: .txt, .ann, .tsv

# %%
def main(argv):
    try:
        opts, args = getopt.getopt(argv, 'v', [])
    except getopt.GetoptError:
        Usage()
    print(len(args), len(argv))
    if len(args) == 2:
        last_chapter = int(args[1])
    elif len(args) == 3:
        last_chapter = int(args[2])
    else:
        Usage()   
    
    first_chapter = int(args[1])
    book_name = args[0]
    
    CreateCoref(book_name, first_chapter, last_chapter)

if __name__ == "__main__":
    main(argv[1:])

# %%
def replace_suffix(source_string, replace_what, replace_with):
    head, _sep, tail = source_string.rpartition(replace_what)
    return head + replace_with + tail, head

def replace(g_prs):
    char_set = set('+:@.,;AEIOU')
    if g_prs not in {'', '+'}:
        new_prs = 'A' if g_prs == '+A' else ''.join(char for char in g_prs if char not in char_set)
        return new_prs

def print_text(book, chapter):
    l=[]
    
    chn = T.nodeFromSection((book, chapter))
    c = 0
    for vn in L.d(chn, 'verse'):
        verse_words = L.d(vn, 'word')
        vt = T.text(L.d(vn,'word'), fmt='text-trans-plain')
        #print(vt)
        
        for w in verse_words:
            gcons_word = F.g_cons.v(w)
            trailer = F.trailer.v(w)
            prs = F.prs.v(w)
            g_prs = F.g_prs.v(w)
            new_prs = replace(g_prs)
            if new_prs:
                #print(gcons_word, new_prs)
                
                if gcons_word.endswith(new_prs) and trailer == '':
                    word, head = replace_suffix(gcons_word, new_prs, f'+{new_prs}-')
                    print(word, head)
                elif gcons_word.endswith(new_prs) and trailer != '':
                    word, head = replace_suffix(gcons_word, new_prs, f'+{new_prs} ')
                    print(word, head)
            if trailer == '':
                nw = f'{gcons_word}-' #trailer_dict[trailer]
                #print(nw)
            else:
                nw = f'{gcons_word} '
                #print(nw)
                
print_text('Psalms', 119)

# %%
trailer_dict = {' ': ' ',
    '': '-',
    '&': '-',
    '00 ': ' *',
    '05 ': ' ',
    '00_S ': ' *',
    '00_P ': ' *',
    '_S ': ' *',
    '00_| ': ' *',
    '00_|_P ': ' *',
    '00_|_S ': ' *',
    }
trailer_dict

    
'''f1(b, f, l):
    for c in range(f, l+1):
        do with chapter
        f2(b, c):'''
