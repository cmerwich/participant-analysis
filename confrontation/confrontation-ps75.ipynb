# %%
import os
from retrieve_iaa import retrieve_ann
from utils import MakeTable

# %%
path_manual = os.path.expanduser('~/Sites/brat/data/coref/Psalms/annotate/Psalms_075.ann')
path_mimi = os.path.expanduser('~/github/cmerwich/participant-analysis/iaa-ann-vs-mimi/Psalms_075.ann')

# %%
ps075_df = MakeTable('~/github/cmerwich/participant-analysis/iaa-ann-vs-mimi/Psalms_075.iaa')
ps075_df
# Out:
#    ann_A ann_B   L   M   R   D       d
# 0     C1    C2   0   2   0   0  0.0000
# 1     C2    C5   5   1   1   6  0.8571
# 2     C3    C7   2   0   2   4  1.0000
# 3     C4    C6   2   2   1   3  0.6000
# 4     C5    C4  16   4   0  16  0.8000
# 5     C6    C8   1   1   1   2  0.6667
# 6     C7    C1   5   0   4   9  1.0000
# 7     C8    C3   5   0   2   7  1.0000
# 8     C9    C9   0   3   1   1  0.2500
# 9    C10   C10   0   2   0   0  0.0000
# 10     S     S   3  14  24  27  0.6585

# %%
retrieve_ann(path_manual, path_mimi)
# Out:
# ann_A	ann_B	L	M	R	D	d
#
# ------------------------------------------------------------
# C1	C2	0	2	0	0	0.0
# ------------------------------------------------------------
# A	['HWDJNW', 'HWDJNW']
#
# B	['HWDJNW', 'HWDJNW']
#
# ------------------------------------------------------------
# C2	C5	5	1	1	6	0.8571
# ------------------------------------------------------------
# A	['NMGJM', '>RY', 'KL&JCBJ', 'H', '<MWDJ', 'H']
#
# B	['NMGJM', '>RY W-KL JCBJ']
#
# A diff	[('>RY', 1), ('KL&JCBJ', 2), ('H', 3), ('<MWDJ', 4), ('H', 5)]
#
# B diff	[('>RY W-KL JCBJ', 1)]
#
# ------------------------------------------------------------
# C3	C7	2	0	2	4	1.0
# ------------------------------------------------------------
# A	['HWLLJM', 'THLW']
#
# B	['JCPJL', 'JRJM']
#
# A diff	[('HWLLJM', 0), ('THLW', 1)]
#
# B diff	[('JCPJL', 0), ('JRJM', 1)]
#
# ------------------------------------------------------------
# C4	C6	2	2	1	3	0.6
# ------------------------------------------------------------
# A	['TRJMW', 'QRNK', 'M', 'TDBRW']
#
# B	['TRJMW', 'TRJMW', 'TDBRW']
#
# A diff	[('QRNK', 1), ('M', 2)]
#
# B diff	[('TRJMW', 1)]
#
# ------------------------------------------------------------
# C5	C4	16	4	0	16	0.8
# ------------------------------------------------------------
# A	['K', '>LHJM', 'CM', 'K', 'NPL>WTJ', 'K', '>QX', '>NJ', '>CPV', '>NKJ', 'TKNTJ', '>MRTJ', '>LHJM', 'CPV', 'JCPJL', 'JRJM', 'JD&JHWH', 'JMYW', '>LHJ J<QB', '>GD<']
#
# B	['>NJ', '>CPV', '>NKJ', 'TKNTJ']
#
# A diff	[('K', 0), ('>LHJM', 1), ('CM', 2), ('K', 3), ('NPL>WTJ', 4), ('K', 5), ('>QX', 6), ('>MRTJ', 11), ('>LHJM', 12), ('CPV', 13), ('JCPJL', 14), ('JRJM', 15), ('JD&JHWH', 16), ('JMYW', 17), ('>LHJ J<QB', 18), ('>GD<', 19)]
#
# B diff	[]
#
# ------------------------------------------------------------
# C6	C8	1	1	1	2	0.6667
# ------------------------------------------------------------
# A	['KWS', 'XMR']
#
# B	['JJN', 'XMR']
#
# A diff	[('KWS', 0)]
#
# B diff	[('JJN', 0)]
#
# ------------------------------------------------------------
# C7	C1	5	0	4	9	1.0
# ------------------------------------------------------------
# A	['JJN', 'JGR', 'ZH', 'CMRJ', 'H']
#
# B	['+K', '>LHJM', '+K', '+K']
#
# A diff	[('JJN', 0), ('JGR', 1), ('ZH', 2), ('CMRJ', 3), ('H', 4)]
#
# B diff	[('+K', 0), ('>LHJM', 1), ('+K', 2), ('+K', 3)]
#
# ------------------------------------------------------------
# C8	C3	5	0	2	7	1.0
# ------------------------------------------------------------
# A	['RC<JM', 'TRJMW', 'JCTW', 'KL RC<J&>RY', 'KL&QRNJ RC<JM']
#
# B	['SPRW', 'NPL>WTJ']
#
# A diff	[('RC<JM', 0), ('TRJMW', 1), ('JCTW', 2), ('KL RC<J&>RY', 3), ('KL&QRNJ RC<JM', 4)]
#
# B diff	[('SPRW', 0), ('NPL>WTJ', 1)]
#
# ------------------------------------------------------------
# C9	C9	0	3	1	1	0.25
# ------------------------------------------------------------
# A	['>NJ', '>GJD', '>ZMRH']
#
# B	['>NJ', '>GJD', '>ZMRH', '>GD<']
#
# A diff	[]
#
# B diff	[('>GD<', 3)]
#
# ------------------------------------------------------------
# C10	C10	0	2	0	0	0.0
# ------------------------------------------------------------
# A	['TRWMMNH', 'QRNWT YDJQ']
#
# B	['TRWMMNH', 'QRNWT YDJQ']
#
# ------------------------------------------------------------
# S	S	3	14	24	27	0.6585
# ------------------------------------------------------------
# A	['MNYX', 'TCXT', 'ZMWR', '>SP', 'CJR', 'SPRW', 'MW<D', 'QRN', 'MRWM', 'YW>R <TQ', 'MWY>', 'M<RB', 'MDBR HRJM', 'ZH', 'ZH', 'ML> MSK', '<LM']
#
# B	['-MNYX', 'TCXT', 'MZMWR', '>SP', 'CJR', 'CM', '>QX', 'MW<D', '+H', '<MWDJ', '+H', '>MRTJ', '-HWLLJM', 'THLW', '-RC<JM', 'QRN', '-MRWM', 'QRN', '+KM', 'YW>R <TQ', 'MWY>', 'M<RB', 'MDBR HRJM', '>LHJM', 'CPV', 'ZH', 'ZH', 'KWS', 'JD JHWH', 'JGR', 'ZH', 'CMRJ', '+H', 'JMYW', 'JCTW', '<LM', '>LHJ J<QB', 'KL QRNJ RC<JM']
#
# A diff	[('MNYX', 0), ('ZMWR', 3), ('SPRW', 7), ('MRWM', 10), ('ML> MSK', 18)]
#
# B diff	[('-MNYX', 0), ('MZMWR', 3), ('CM', 7), ('>QX', 8), ('+H', 10), ('<MWDJ', 11), ('+H', 12), ('>MRTJ', 13), ('-HWLLJM', 14), ('THLW', 15), ('-RC<JM', 16), ('-MRWM', 18), ('QRN', 20), ('+KM', 21), ('>LHJM', 26), ('CPV', 27), ('KWS', 30), ('JD JHWH', 31), ('JGR', 32), ('ZH', 33), ('CMRJ', 34), ('+H', 35), ('JMYW', 36), ('JCTW', 37), ('>LHJ J<QB', 39), ('KL QRNJ RC<JM', 40)]
