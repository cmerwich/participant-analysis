# %% [markdown]
# <img align="right" src="images/tf-small.png" width="90"/>
# <img align="right" src="images/etcbc.png" width="100"/>
#
# # Psalm 75 as Testing Ground
#
# This notebook aims to analyse Psalm 75 - as test case - with the coreference data that has been produced by the coreference annotation method and MiMi. The data is brought into discussion with exegetical commentaries on Psalm 75. I refer to my dissertation for an in-depth discussion.
#
#
# ## Why Psalm 75
#
# Psalm 75 has been chosen as case study since it presents the reader with a number of challenges. Psalm 75 starts with a we-group that praises God. God's deeds are recounted. At the moment the earth and her inhabitants are on the brink of 'melting away' an 'I' is going to judge with righteousness. People who are wicked and who boast ('the infatuated') are told not to do so. God the judge gives a foaming cup of wine to the aforementioned bad people. An 'I' person wants to make music for God and the psalm closes with the message that the 'horns' of the bad people will be chopped off and those of the righteous are going to be raised. The psalm is both intriguing as mysterious. It is hard to distinguish speech from God and human speech; the identification of other entities such as the 'wicked' and 'infatuated' leaves the reader with questions. The resolving of pronouns to named entities is therefore also challenging for the reader. The content of the psalm is harsh for those on the wicked side, which raises the question to whom is the psalm addressed and who is its messenger? Lastly, it is puzzling to what situation the psalm is referring to in which judgement is needed. Who has done injustice?
#
# Not all - probably very little - of these questions can decisively be answered by the commentators. Both the problems that they encounter, what they report themselves and the problems that arise from the analysis of their methods and results have  been used for the development of a method and algorithm for participant analysis. These methods have been presented in the annotation directories [annotation](https://github.com/cmerwich/participant-analysis/tree/master/annotation), [tf_conversion](https://github.com/cmerwich/participant-analysis/tree/master/tf_conversion); and the [MiMi](https://github.com/cmerwich/participant-analysis/tree/master/mimi) directory.
#
# Psalm 75 functions as a way to uncover methodological problems in the commentaries' participant analyses and at the same time as a test case for the dissertations' methods.

# %% [markdown]
# ## 1. Import Modules

# %%
# %load_ext autoreload
# %autoreload 2

import os
from IPython.display import display, HTML
import pandas as pd
from retrieve_iaa import retrieve_ann
from export_utils import MakeTable, ExportToLatex

# %%
from annotation_aid import compute_text, show_text
# Out:
# To increase the rate,see https://annotation.github.io/text-fabric/advanced/repo.html/
# <b title="latest release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/2017</span>
# <b title="local release">data:</b> <span title="rv1.0 offline under ~/text-fabric-data">~/text-fabric-data/cmerwich/bh-reference-system/tf/2017</span>
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: v

# %%
from analyse import (ParseAnnotations, 
                     MakePandasTables, 
                     PrintThisTable, 
                     PrintSurvey, 
                     PrintPatternsAndNotes, 
                     PrintCorefID,
                     PrintPossibleCorrections
                    )
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/2017</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/cmerwich/participant-analysis/coreference/tf/2017</span>
# <b title="local release">data:</b> <span title="rv1.0 offline under ~/text-fabric-data">~/text-fabric-data/cmerwich/bh-reference-system/tf/2017</span>
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: v

# %%
from search import (GetAnnotations,
                    FindWho,
                    FindFirst,
                    FindMention,
                    FindClassMention
                    )
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/2017</span>
# <b title="local release">data:</b> <span title="rv1.4.0=#317988a75f7ed0660c26e2bc0e2f54a98b1d6355 offline under ~/text-fabric-data">~/text-fabric-data/cmerwich/participant-analysis/coreference/tf/2017</span>
# <b title="local release">data:</b> <span title="rv1.0 offline under ~/text-fabric-data">~/text-fabric-data/cmerwich/bh-reference-system/tf/2017</span>
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: v

# %%
from mimi_visualise import (PrintCoref,
                            PrintMentions
                            )
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/c</span>
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: v
#   0.00s loading features ...
#   0.14s All additional features loaded - for details use loadLog()

# %%
# Output location for tables
OUTPUT = os.path.expanduser('~/Documents/PhD/1-dissertation/DISSERTATIONlatex/Tables/')

# %%
# Set any Hebrew Bible Book
MY_BOOK = 'Psalms'

# Indicate a range of chapters
FROM_CHAPTER = 75
TO_CHAPTER = 75

# %% [markdown]
# ## 2. The Text of Psalm 75

# %%
# Run
(results, highlights) = compute_text(MY_BOOK, FROM_CHAPTER, TO_CHAPTER)
show_text(results, highlights)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=1&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75">Psalms 75</a></div><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">chapter:427265</span> <span class="txtu hbo"><span class="section">Psalms 75</span></span></div></div></div>
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=1&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:1">Psalms 75:1</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430522</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220517</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493845</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NmCl</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844050</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>det</span><span class="function xft" ><span class="f">function=</span>PreC</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323021</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1L" title="Show this on SHEBANQ"><span class="txtu hbo">לַ</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>to</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323022</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1H" title="Show this on SHEBANQ"></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>the</span><span class="pdp xft" ><span class="f">pdp=</span>art</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323023</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1NYXv" title="Show this on SHEBANQ"><span class="txtu hbo">מְנַצֵּ֥חַ </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>prevail</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span><span class="vs xft" ><span class="f">vs=</span>piel</span></div></div></div></div></div></div></div></div><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220518</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493846</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xYq0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844051</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Nega</span><span class="gloss xft" ><span class="f">gloss=</span>not</span><span class="typ xft" ><span class="f">typ=</span>NegP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323024</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1ALi" title="Show this on SHEBANQ"><span class="txtu hbo">אַל־</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>not</span><span class="pdp xft" ><span class="f">pdp=</span>nega</span></div>< ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=2&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:2">Psalms 75:2</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430523</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220521</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493849</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>ZQt0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844055</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="gloss xft" ><span class="f">gloss=</span>praise</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: springgreen;" ><div class="lbl c0 trm hl"  style="background-color: springgreen;" ><span class="nd">323030</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1JDHv" title="Show this on SHEBANQ"><span class="txtu hbo">הֹ֘ודִ֤ינוּ </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>praise</span><span class="nu xft" ><span class="f">nu=</span>pl</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span><span class="pgn_verb xft" ><span class="f">pgn_verb=</span>P1Cpl</span><span class="vs xft" ><span class="f">vs=</span>hif</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844056</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>det</span><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="gloss xft" ><span class="f">gloss=</span>to</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: DarkGoldenrod;" ><div class="lbl c0 trm hl"  style="background-color: DarkGoldenrod;" ><span class="nd">323031</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1L" title="Show this on SHEBANQ"><span class="txtu hbo">לְּךָ֨׀ </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>to</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span><span class="pgn_prs xft" ><span class="f">pgn_prs=</span>P2Msg</span></div></div></div></div></div></div><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493850</span></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>god(s)</span><span class="typ xft" ><span class="f">typ=</span>Voct</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  hl"  style="background-color: skyblue;" ><div class="lbl c1  hl"  style="background-color: skyblue;" ><span class="nd">phrase:844057</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>Voct</span><span class="gloss xft" ><span class="f">gloss=</span>god(s)</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323032</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1ALHJMn" titl ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=3&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:3">Psalms 75:3</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430524</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220525</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493854</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xYq0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844064</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323039</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּ֭י </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844065</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="gloss xft" ><span class="f">gloss=</span>take</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: springgreen;" ><div class="lbl c0 trm hl"  style="background-color: springgreen;" ><span class="nd">323040</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1LQXv" title="Show this on SHEBANQ"><span class="txtu hbo">אֶקַּ֣ח </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>take</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span><span class="pgn_verb xft" ><span class="f">pgn_verb=</span>P1Csg</span><span class="vs xft" ><span class="f">vs=</span>qal</span></div></div></div></div><div class="contnr c1  rtl  hl"  style="background-color: skyblue;" ><div class="lbl c1  hl"  style="background-color: skyblue;" ><span class="nd">phrase:844066</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>Objc</span><span class="gloss xft" ><span class="f">gloss=</span>appointment</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323041</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1MWODn" title="Show this on SHEBANQ"><span class="txtu hbo">מֹועֵ֑ד </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>appointment</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div></div></div><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sen ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=4&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:4">Psalms 75:4</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430525</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220527</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493856</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Ptcp</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844070</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreC</span><span class="gloss xft" ><span class="f">gloss=</span>faint</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: springgreen;" ><div class="lbl c0 trm hl"  style="background-color: springgreen;" ><span class="nd">323045</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1MWGv" title="Show this on SHEBANQ"><span class="txtu hbo">נְֽמֹגִ֗ים </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>faint</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>pl</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span><span class="pgn_verb xft" ><span class="f">pgn_verb=</span>UMpl</span><span class="st xft" ><span class="f">st=</span>a</span><span class="vs xft" ><span class="f">vs=</span>nif</span></div></div></div></div><div class="contnr c1  rtl  hl"  style="background-color: skyblue;" ><div class="lbl c1  hl"  style="background-color: skyblue;" ><span class="nd">phrase:844071</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>Subj</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323046</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1ARYn" title="Show this on SHEBANQ"><span class="txtu hbo">אֶ֥רֶץ </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>earth</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323047</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>and</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323048</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1KLn" title="Show this on SHEBANQ"><span class="txtu hbo">כָל־</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>whole</span><span class="gn xft" ><span class="f">gn=</span>m</span><span ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=5&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:5">Psalms 75:5</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430526</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl l " ><div class="lbl c2  " ><span class="nd">sentence:1220530</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493859</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>ZQt0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844076</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="gloss xft" ><span class="f">gloss=</span>say</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: springgreen;" ><div class="lbl c0 trm hl"  style="background-color: springgreen;" ><span class="nd">323054</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1AMRv" title="Show this on SHEBANQ"><span class="txtu hbo">אָמַ֣רְתִּי </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>say</span><span class="ls xft" ><span class="f">ls=</span>quot</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span><span class="pgn_verb xft" ><span class="f">pgn_verb=</span>P1Csg</span><span class="vs xft" ><span class="f">vs=</span>qal</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844077</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>det</span><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323055</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1L" title="Show this on SHEBANQ"><span class="txtu hbo">לַֽ֭</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>to</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323056</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1H" title="Show this on SHEBANQ"></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>the</span><span class="pdp xft" ><span class="f">pdp=</span>art</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323057</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1HLLiiv" title="Show this on SHEBANQ"><span class="txtu hbo">הֹולְלִים </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>be infatuated</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>pl</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span><span class="vs xft" ><span class="f">vs=</span>qal</span></div></div></div></div></div></div></div ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=6&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:6">Psalms 75:6</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430527</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220533</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493863</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xYq0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844085</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Nega</span><span class="gloss xft" ><span class="f">gloss=</span>not</span><span class="typ xft" ><span class="f">typ=</span>NegP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323067</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1ALi" title="Show this on SHEBANQ"><span class="txtu hbo">אַל־</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>not</span><span class="pdp xft" ><span class="f">pdp=</span>nega</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844086</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="gloss xft" ><span class="f">gloss=</span>be high</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: springgreen;" ><div class="lbl c0 trm hl"  style="background-color: springgreen;" ><span class="nd">323068</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1RWMv" title="Show this on SHEBANQ"><span class="txtu hbo">תָּרִ֣ימוּ </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>be high</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>pl</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span><span class="pgn_verb xft" ><span class="f">pgn_verb=</span>P2Mpl</span><span class="vs xft" ><span class="f">vs=</span>hif</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844087</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>det</span><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323069</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1L" title="Show this on SHEBANQ"><span class="txtu hbo">לַ</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>to</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323070</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1H" title="Show this on SHEBANQ"></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>the</span><span class="pdp xft" ><span class="f">pdp=</span>art< ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=7&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:7">Psalms 75:7</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430528</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220534</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493865</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NmCl</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844091</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323077</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּ֤י </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844092</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Nega</span><span class="gloss xft" ><span class="f">gloss=</span>not</span><span class="typ xft" ><span class="f">typ=</span>NegP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323078</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1LA" title="Show this on SHEBANQ"><span class="txtu hbo">לֹ֣א </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>not</span><span class="pdp xft" ><span class="f">pdp=</span>nega</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844093</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>PreC</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323079</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1MN" title="Show this on SHEBANQ"><span class="txtu hbo">מִ֭</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>from</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323080</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1MWYAn" title="Show this on SHEBANQ"><span class="txtu hbo">מֹּוצָא </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>issue</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323081</span> <a class=" tx ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=8&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:8">Psalms 75:8</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430529</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220535</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493867</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NmCl</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844097</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323089</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּֽי־</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div><div class="contnr c1  rtl  hl"  style="background-color: skyblue;" ><div class="lbl c1  hl"  style="background-color: skyblue;" ><span class="nd">phrase:844098</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>Subj</span><span class="gloss xft" ><span class="f">gloss=</span>god(s)</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323090</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1ALHJMn" title="Show this on SHEBANQ"><span class="txtu hbo">אֱלֹהִ֥ים </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>god(s)</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>pl</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div><div class="contnr c1  rtl  hl"  style="background-color: skyblue;" ><div class="lbl c1  hl"  style="background-color: skyblue;" ><span class="nd">phrase:844099</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>PreC</span><span class="gloss xft" ><span class="f">gloss=</span>judge</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323091</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1CPVv" title="Show this on SHEBANQ"><span class="txtu hbo">שֹׁפֵ֑ט </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>judge</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span><span class="vs x ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=9&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:9">Psalms 75:9</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430530</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220536</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493870</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NmCl</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844105</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323097</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּ֤י </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>that</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div><div class="contnr c1  rtl  hl"  style="background-color: skyblue;" ><div class="lbl c1  hl"  style="background-color: skyblue;" ><span class="nd">phrase:844106</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>Subj</span><span class="gloss xft" ><span class="f">gloss=</span>cup</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323098</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1KWSn" title="Show this on SHEBANQ"><span class="txtu hbo">כֹ֪וס </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>cup</span><span class="gn xft" ><span class="f">gn=</span>f</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844107</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>det</span><span class="function xft" ><span class="f">function=</span>PreC</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323099</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְּֽ</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>in</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323100</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1JDn" title="Show this on SHEBANQ"><span class="txtu hbo">יַד־</span></a></div><div class='features'><span class="gloss xft" ><span class=" ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=10&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:10">Psalms 75:10</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430531</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220537</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493876</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WXYq</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844119</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="gloss xft" ><span class="f">gloss=</span>and</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323118</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ֭</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>and</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844120</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>det</span><span class="function xft" ><span class="f">function=</span>Subj</span><span class="gloss xft" ><span class="f">gloss=</span>i</span><span class="typ xft" ><span class="f">typ=</span>PPrP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: palegoldenrod;" ><div class="lbl c0 trm hl"  style="background-color: palegoldenrod;" ><span class="nd">323119</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1ANJ" title="Show this on SHEBANQ"><span class="txtu hbo">אֲנִי </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>i</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>prps</span><span class="pgn_prps xft" ><span class="f">pgn_prps=</span>P1Csg</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844121</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="gloss xft" ><span class="f">gloss=</span>report</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: springgreen;" ><div class="lbl c0 trm hl"  style="background-color: springgreen;" ><span class="nd">323120</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1NGDv" title="Show this on SHEBANQ"><span class="txtu hbo">אַגִּ֣יד </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>report</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span><span class="pgn_verb xft" ><span class="f">pgn_verb=</span>P1Csg</span><span class="vs xft" ><span class="f">vs=</span>hif</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844122</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f" ...
# <div class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=75&amp;verse=11&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 75:11">Psalms 75:11</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:1430532</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1220539</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:493878</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WxY0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:844125</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="gloss xft" ><span class="f">gloss=</span>and</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">323127</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>and</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div><div class="contnr c1  rtl  hl"  style="background-color: skyblue;" ><div class="lbl c1  hl"  style="background-color: skyblue;" ><span class="nd">phrase:844126</span></div><div class='features'><span class="det xft" ><span class="f">det=</span>und</span><span class="function xft" ><span class="f">function=</span>Objc</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323128</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1KLn" title="Show this on SHEBANQ"><span class="txtu hbo">כָל־</span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>whole</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="ls xft" ><span class="f">ls=</span>nmdi</span><span class="nu xft" ><span class="f">nu=</span>sg</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323129</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1QRNn" title="Show this on SHEBANQ"><span class="txtu hbo">קַרְנֵ֣י </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>horn</span><span class="gn xft" ><span class="f">gn=</span>f</span><span class="nu xft" ><span class="f">nu=</span>du</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  hl"  style="background-color: skyblue;" ><div class="lbl c0 trm hl"  style="background-color: skyblue;" ><span class="nd">323130</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&amp;id=1RCOn" title="Show this on SHEBANQ"><span class="txtu hbo">רְשָׁעִ֣ים </span></a></div><div class='features'><span class="gloss xft" ><span class="f">gloss=</span>guilty</span><span class="gn xft" ><span class="f">gn=</span>m</span><span class="nu xft" ><s ...

# %% [markdown]
# ## 3. Coreference Annotations
#
# The coreference annotations produced for Psalm 75 are an identification of the entities it contains and is essentially an interpretation of its discourse.
#
# The function `AssignIdentity()`in `analyse.py` has been described in [analyseParticipants.ipynb](https://github.com/cmerwich/participant-analysis/blob/master/tf_conversion/analyseParticipants.ipynb). The functionality of `AssignIdentity()` has been integrated in a number of entity search functions with which entities in the entire Psalms corpus can be analysed. The entity search functions are meant to facilitate in-depth discussion between the data and the findings of the commentaries.
#
# To reiterate how `AssignIdentity()` works, the annotation in a coreference class with the most high ranked mention type - PrNP, NP, PtcP, VP, PPrP or DPrP - is used to identify the entire class. Some of the functions below indicate this identification with 'Who/what'. An additional way to facilitate analysis is to determine which mention initiates the coreference class. `AssignIdentity()` also does this. Some of the functions below indicate the mention and its type that starts the coreference chain with 'first' and 'type'.
#
# Working with the search functions for the analysis of entities in the Psalms brings at least three assumptions to the fore. The *first assumption* is that the identification of a class, i.e. entity, in a psalm's discourse is meaningful, and can thus be used to search in the psalms corpus for similar entities. These entities and the coreference context they appear in can be used to interpret the entity under study.
#
# The *second assumption* is that the way the entity is introduced in the psalm's discourse is meaningful, and can thus be used to search in the psalms corpus for entities that are *introduced* in a similar way. These entities and the coreference context they appear in can be used to interpret the entity under study.
#
# The *third assumption* is that from the study of classes that are similar - in identity and/or in which mention type introduces the chain - to the classes that occur in Ps 75 the meaning of the entire psalm may be interpreted.
#
# Coreference annotations could be considered as a well informed interpretation of participants or entities, in our case those in Ps 75. Some of the mentioned interpretations of participants in Ps 75 can perhaps be further analysed by applying the search functions on the annotations and identified entities. The application of these search functions have two goals. Firstly, we move from the text of Ps 75 to the Psalms corpus in general and see what other coreference information can be used to further support the identifications that were made within the text. Secondly, this search of entities in context may also contribute to an enhanced understanding of the meaning of the used entities, and thus enhance our understanding of Ps 75 in general. Before we do some searches, the annotations are parsed, descriptive statistics are generated, we check for possible errors and visualise the annotations.

# %% [markdown]
# ### 3.1 Parse Annotations for Psalm 75

# %%
mentions75, corefs75, suffix_errors75, reconsider_rpt75 = ParseAnnotations(MY_BOOK, FROM_CHAPTER, TO_CHAPTER)

# %% [markdown]
# ### 3.2 Descriptive Statistics of Coreference Annotations

# %%
overall_df75, pos_df75, \
pronoun_df75, pronoun_pos_class_df75, \
pronoun_pos_sing_df75 = MakePandasTables(corefs75, mentions75)

# %%
PrintThisTable(overall_df75)
# Out:
#             total
# mentions       67
# singletons     19
# classes        10

# %%
PrintThisTable(pos_df75)
# Out:
#                 VP  NP  Sffx  PPrP  DPrP  PrNP  total_type
# in class        22  15     7     3     1     0          48
# singleton        1  15     0     0     2     1          19
# total           23  30     7     3     3     1          67
# % total         34  45    10     4     4     1         100
# first in chain   4   4     1     1     0     0          10
# % chain         40  40    10    10     0     0         100

# %%
PrintThisTable(pronoun_df75)
# Out:
#            p1upl  p1usg  p2mpl  p2msg  p3fpl  p3fsg  p3mpl  p3msg  p3upl  \
# in class       2     10      5      3      1      3      2      4      1
# singleton      0      0      0      1      0      0      0      0      0
# total          2     10      5      4      1      3      2      4      1
# % total        6     30     15     12      3      9      6     12      3
#
#            umpl  total_pgn
# in class      1         32
# singleton     0          1
# total         1         33
# % total       3        100

# %%
PrintThisTable(pronoun_pos_class_df75)
# Out:
#          p1upl  p1usg  p2mpl  p2msg  p3fpl  p3fsg  p3mpl  p3msg  p3upl  umpl  \
# VP           2      7      4      0      1      0      2      4      1     1
# Sffx         0      0      1      3      0      3      0      0      0     0
# PPrP         0      3      0      0      0      0      0      0      0     0
# total        2     10      5      3      1      3      2      4      1     1
# % total      6     31     16      9      3      9      6     12      3     3
#
#          total_pgn
# VP              22
# Sffx             7
# PPrP             3
# total           32
# % total        100

# %% [markdown]
# ### 3.3 Check for Possible Errors

# %%
PrintPossibleCorrections(suffix_errors75, reconsider_rpt75)
# Out:
# There are 0 annotation errors for the specified corpus
#
# There are 0 reconstructed phrase type errors for the specified corpus

# %% [markdown]
# ### 3.4 Overview Print Functions for Annotations

# %%
#PrintSurvey(corefs75)
#PrintPatternsAndNotes(corefs75, suffix_errors75)
#PrintCorefID(corefs)

# %% [markdown]
# ### 3.5 Visualise Annotations

# %%
GetAnnotations(corefs75, suffix_errors75)
# Out:
# C75:1 Who/what: HWDJNW / first: HWDJNW, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 2	T6	VP	p1upl	HWDJNW     	praise
# 2	T9	VP	p1upl	HWDJNW     	praise
#
#
# C75:4 Who/what: >LHJM / first: K, type: Sffx
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 2	T7	Sffx	p2msg	K
# 2	T8	NP		>LHJM     	god(s)
# 2	T10	Sffx	p2msg	K
# 2	T13	Sffx	p2msg	K
# 3	T15	VP	p1usg	>QX     	take
# 3	T17	PPrP	p1usg	>NJ     	i
# 3	T18	VP	p1usg	>CPV     	judge
# 4	T22	PPrP	p1usg	>NKJ     	i
# 4	T23	VP	p1usg	TKNTJ     	estimate
# 5	T25	VP	p1usg	>MRTJ     	say
# 8	T40	NP		>LHJM     	god(s)
# 8	T41	NP		CPV     	judge
# 8	T43	VP	p3msg	JCPJL     	be low
# 8	T45	VP	p3msg	JRJM     	be high
# 9	T47	NP		JD&JHWH     	hand
# 9	T51	VP	p3msg	JGR     	run
# 10	T62	NP		>LHJ J<QB     	god(s)
# 11	T64	VP	p1usg	>GD<     	cut off
#
#
# C75:9 Who/what: NPL>WTJ / first: SPRW, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 2	T12	VP	p3upl	SPRW     	count
# 2	T14	NP		NPL>WTJ     	be miraculous
#
#
# C75:2 Who/what: >RY WKL&JCBJ / first: NMGJM, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 4	T19	VP	umpl	NMGJM     	faint
# 4	T67	NP		>RY WKL&JCBJ     	earth
# 4	T21	Sffx	p3fsg	H
# 4	T24	Sffx	p3fsg	H
#
#
# C75:3 Who/what: HWLLJM / first: HWLLJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 5	T26	NP		HWLLJM     	be infatuated
# 5	T27	VP	p2mpl	THLW     	be infatuated
#
#
# C75:6 Who/what: RC<JM / first: RC<JM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 5	T28	NP		RC<JM     	guilty
# 5	T29	VP	p2mpl	TRJMW     	be high
# 6	T31	VP	p2mpl	TRJMW     	be high
# 6	T33	Sffx	p2mpl	KM
# 6	T35	VP	p2mpl	TDBRW     	speak
# 9	T20	VP	p3mpl	JMYW     	drain
# 9	T56	VP	p3mpl	JCTW     	drink
# 9	T57	NP		KL RC<J&>RY     	whole
#
#
# C75:10 Who/what: QRN / first: QRN, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 5	T30	NP		QRN     	horn
# 6	T34	NP		QRN     	horn
# 11	T63	NP		KL&QRNJ RC<JM     	whole
#
#
# C75:5 Who/what: JJN / first: JJN, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 9	T48	NP		JJN     	wine
# 9	T49	VP	p3msg	XMR     	cover
# 9	T52	DPrP		ZH     	this
# 9	T54	Sffx	p3fsg	H
#
#
# C75:7 Who/what: >GJD / first: >NJ, type: PPrP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 10	T58	PPrP	p1usg	>NJ     	i
# 10	T59	VP	p1usg	>GJD     	report
# 10	T61	VP	p1usg	>ZMRH     	sing
#
#
# C75:8 Who/what: QRNWT YDJQ / first: TRWMMNH, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 11	T65	VP	p3fpl	TRWMMNH     	be high
# 11	T66	NP		QRNWT YDJQ     	horn
#
#
# C0 Who/what: Singletons / ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 1	T1	NP		MNYX     	prevail
# 1	T2	VP	p2msg	TCXT     	destroy
# 1	T3	NP		MZMWR     	psalm
# 1	T4	PrNP		>SP     	Asaph
# 1	T5	NP		CJR     	song
# 2	T11	NP		CM     	name
# 3	T16	NP		MW<D     	appointment
# 4	T68	NP		<MWDJ     	pillar
# 6	T32	NP		MRWM     	high place
# 6	T36	NP		YW>R <TQ     	neck
# 7	T37	NP		MWY>     	issue
# 7	T38	NP		M<RB     	sunset
# 7	T39	NP		MDBR HRJM     	desert
# 8	T42	DPrP		ZH     	this
# 8	T44	DPrP		ZH     	this
# 9	T46	NP		KWS     	cup
# 9	T50	NP		ML> MSK     	full
# 9	T53	NP		CMRJ     	dregs
# 10	T60	NP		<LM     	eternity

# %% [markdown]
# ### 3.6 Search
#
# All search functions below, except `FindMention()`, print the results in a similar way. On the first line the class identifier is printed, together with an identification, what mention initiates the coreference chain, the mention type of the first mention in chain and the number of the class in the entire annotated corpus. The functions then print 6 columns, per row one mention, with coreference and mention information that is relevant for participant analysis: the verse in which the mention occurs, mention type, pgn of the mention, the annotation of the mention itself, a gloss translation, and the mention note if it was stored on the mention.
# `FindMention()` prints an oversight in 7 columns, per row one class in which the mention occurs or the singleton: chapter:verse, class/singleton, mention type, pgn of the mention, the annotations itself, its gloss, and note.
#
# Walking through the annotated entities in order of the visualisation above, we start with HWDJNW. Before we do that however, all coreference annotations in the entire Psalms corpus are parsed to enable better searching.

# %% [markdown]
# #### Parse All Psalms Annotations to Enable Proper Searching

# %%
mentions, corefs, suffix_errors, reconsider_rpt = ParseAnnotations('Psalms', 1, 150)

# %% [markdown]
# ### C75:1 Who/what: HWDJNW / first: HWDJNW, type: VP

# %%
FindWho(corefs, suffix_errors, ['HWDJNW'])
# Out:
# C75:1 Who: HWDJNW, first: HWDJNW, type: VP, corpus class: 993
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1upl	HWDJNW     	praise
# 2	VP	p1upl	HWDJNW     	praise
# Pattern:  ['VP p1upl', 'VP p1upl']
#
#
# Results:  1
# ['C75:1']

# %%
FindMention(corefs, suffix_errors, 'HWDJNW')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 75:2	C75:1	VP	p1upl	HWDJNW		praise
# 75:2	C75:1	VP	p1upl	HWDJNW		praise
#
#
# Results:  2
# ['C75:1', 'C75:1']

# %% [markdown]
# ### C75:4 Who/what: >LHJM / first: K, type: PPrP

# %%
FindWho(corefs, suffix_errors, ['>LHJM'])
# Out:
# C43:3 Who: >LHJM, first: CPV, type: VP, corpus class: 539
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2msg	CPV     	judge
# 1	NP		>LHJM     	god(s)
# 1	VP	p2msg	RJBH     	contend
# 1	VP	p2msg	TPLV     	escape
# 2	PPrP	p2msg	>TH     	you
# 2	NP		>LHJ M<WZ     	god(s)	Nested mention: (God of (my (stronghold))).
# 2	VP	p2msg	ZNXT     	reject
# 3	VP	p2msg	CLX     	send
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 4	NP		MZBX >LHJM     	altar	Nested mention: (altar of (God)).
# 4	NP		>L FMXT GJL     	god	Nested mention: (God of (joy (my (rejoicing)))).
# 4	Sffx	p2msg	K
# 4	NP		>LHJM     	god(s)
# 4	NP		>LH     	god(s)
# 5	NP		>LHJM     	god(s)
# 5	Sffx	p3msg	W
# 5	NP		>LH     	god(s)
# Pattern:  ['VP p2msg', 'NP', 'VP p2msg', 'VP p2msg', 'PPrP p2msg', 'NP', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'NP', 'NP', 'Sfx p2msg', 'NP', 'NP', 'NP', 'Sfx p3msg', 'NP']
#
#
# C45:4 Who: >LHJM, first: BRK, type: VP, corpus class: 564
#
# verse	type	pgn	ann		gloss	note
# 3	VP	p3msg	BRK     	bless
# 3	NP		>LHJM     	god(s)
# Pattern:  ['VP p3msg', 'NP']
#
#
# C45:7 Who: >LHJM, first: K, type: Sffx, corpus class: 567
#
# verse	type	pgn	ann		gloss	note
# 7	Sffx	p2msg	K
# 7	NP		>LHJM     	god(s)
# 7	Sffx	p2msg	K
# 8	VP	p3msg	MCX     	smear
# 8	NP		>LHJM     	god(s)
# 8	NP		>LHJ     	god(s)
# Pattern:  ['Sfx p2msg', 'NP', 'Sfx p2msg', 'VP p3msg', 'NP', 'NP']
#
#
# C48:11 Who: >LHJM, first: ZH, type: DPrP, corpus class: 601
#
# verse	type	pgn	ann		gloss	note
# 15	DPrP		ZH     	this
# 15	NP		>LHJM     	god(s)
# 15	NP		>LHJ     	god(s)
# 15	PPrP	p3msg	HW>     	he
# 15	VP	p3msg	JNHG     	drive
# Pattern:  ['DPrP', 'NP', 'NP', 'PPrP p3msg', 'VP p3msg']
#
#
# C49:15 Who: >LHJM, first: >LHJM, type: NP, corpus class: 610
#
# verse	type	pgn	ann		gloss	note
# 8	NP		>LHJM     	god(s)
# 16	NP		>LHJM     	god(s)
# 16	VP	p3msg	JPDH     	buy off
# 16	VP	p3msg	JQX     	take
# Pattern:  ['NP', 'NP', 'VP p3msg', 'VP p3msg']
#
#
# C53:10 Who: >LHJM, first: >LHJM, type: NP, corpus class: 663
#
# verse	type	pgn	ann		gloss	note
# 2	NP		>LHJM     	god(s)
# 3	NP		>LHJM     	god(s)
# 3	VP	p3msg	HCQJP     	look
# 3	NP		>LHJM     	god(s)
# 5	Sffx	p1usg	J
# 5	NP		>LHJM     	god(s)
# 6	NP		>LHJM     	god(s)
# 6	VP	p3msg	PZR     	scatter
# 6	NP		>LHJM     	god(s)
# 6	VP	p3msg	M>S     	retract
# 7	NP		>LHJM     	god(s)
# 7	Sffx	p3msg	W
# Pattern:  ['NP', 'NP', 'VP p3msg', 'NP', 'Sfx p1usg', 'NP', 'NP', 'VP p3msg', 'NP', 'VP p3msg', 'NP', 'Sfx p3msg']
#
#
# C58:12 Who: >LHJM, first: >LHJM, type: NP, corpus class: 739
#
# verse	type	pgn	ann		gloss	note
# 12	NP		>LHJM     	god(s)
# 12	VP	umpl	CPVJM     	judge
# Pattern:  ['NP', 'VP umpl']
#
#
# C60:3 Who: >LHJM, first: >LHJM, type: NP, corpus class: 755
#
# verse	type	pgn	ann		gloss	note
# 3	NP		>LHJM     	god(s)
# 3	VP	p2msg	ZNXT     	reject
# 3	VP	p2msg	PRYT     	break
# 3	VP	p2msg	>NPT     	be angry
# 3	VP	p2msg	TCWBB     	return
# 4	VP	p2msg	HR<CTH     	quake
# 4	VP	p2msg	PYMT     	split
# 4	VP	p2msg	RPH     	heal
# 4	VP	p3fsg	MVH     	totter
# 5	VP	p2msg	HR>JTH     	see
# 5	Sffx	p2msg	K
# 5	VP	p2msg	HCQJT     	give drink
# 6	VP	p2msg	NTTH     	give
# 6	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 7	VP	p2msg	HWCJ<H     	help
# 7	Sffx	p2msg	K
# 7	VP	p2msg	<N     	answer
# 8	NP		>LHJM     	god(s)
# 8	VP	p3msg	DBR     	speak
# 8	Sffx	p3msg	W
# 8	VP	p1usg	><LZH     	rejoice
# 8	VP	p1usg	>XLQH     	divide
# 8	VP	p1usg	>MDD     	measure
# 9	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 10	VP	p1usg	>CLJK     	throw
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 12	PPrP	p2msg	>TH     	you
# 12	NP		>LHJM     	god(s)
# 12	VP	p2msg	ZNXT     	reject
# 12	VP	p2msg	TY>     	go out
# 12	NP		>LHJM     	god(s)
# 13	VP	p2msg	HBH     	give
# 14	NP		>LHJM     	god(s)
# 14	PPrP	p3msg	HW>     	he
# 14	VP	p3msg	JBWS     	tread down
# Pattern:  ['NP', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p3fsg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'NP', 'VP p3msg', 'Sfx p3msg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p2msg', 'NP', 'VP p2msg', 'VP p2msg', 'NP', 'VP p2msg', 'NP', 'PPrP p3msg', 'VP p3msg']
#
#
# C61:3 Who: >LHJM, first: CM<H, type: VP, corpus class: 764
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p2msg	CM<H     	hear
# 2	NP		>LHJM     	god(s)
# 2	VP	p2msg	HQCJBH     	give attention
# 3	Sffx	p2msg	K
# 3	VP	p2msg	TNX     	lead
# 4	VP	p2msg	HJJT     	be
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 6	PPrP	p2msg	>TH     	you
# 6	NP		>LHJM     	god(s)
# 6	VP	p2msg	CM<T     	hear
# 6	VP	p2msg	NTT     	give
# 6	Sffx	p2msg	K
# 7	VP	p2msg	TWSJP     	add
# 8	NP		PNJ >LHJM     	face	Nested mention: (face of (God)).
# 8	VP	p2msg	MN     	count
# 9	Sffx	p2msg	K
# Pattern:  ['VP p2msg', 'NP', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PPrP p2msg', 'NP', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'NP', 'VP p2msg', 'Sfx p2msg']
#
#
# C62:1 Who: >LHJM, first: >LHJM, type: NP, corpus class: 769
#
# verse	type	pgn	ann		gloss	note
# 2	NP		>LHJM     	god(s)
# 2	Sffx	p3msg	W
# 2	NP		JCW<T     	salvation
# 3	PPrP	p3msg	HW>     	he
# 3	NP		YWR     	rock
# 3	NP		JCW<T     	salvation
# 3	NP		MFGB     	secure height
# 6	NP		>LHJM     	god(s)
# 6	Sffx	p3msg	W
# 7	PPrP	p3msg	HW>     	he
# 7	NP		YWR     	rock
# 7	NP		JCW<T     	salvation
# 7	NP		MFGB     	secure height
# 8	NP		>LHJM     	god(s)
# 8	NP		JC<     	help
# 8	NP		KBWD     	weight
# Pattern:  ['NP', 'Sfx p3msg', 'NP', 'PPrP p3msg', 'NP', 'NP', 'NP', 'NP', 'Sfx p3msg', 'PPrP p3msg', 'NP', 'NP', 'NP', 'NP', 'NP', 'NP']
#
#
# C63:2 Who: >LHJM, first: >LHJM, type: NP, corpus class: 781
#
# verse	type	pgn	ann		gloss	note
# 2	NP		>LHJM     	god(s)
# 2	NP		>L     	god
# 2	PPrP	p2msg	>TH     	you
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 4	Sffx	p2msg	K
# 4	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 8	VP	p2msg	HJJT     	be
# 8	Sffx	p2msg	K
# 9	Sffx	p2msg	K
# 9	Sffx	p2msg	K
# 12	NP		>LHJM     	god(s)
# 12	Sffx	p3msg	W
# Pattern:  ['NP', 'NP', 'PPrP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'NP', 'Sfx p3msg']
#
#
# C65:8 Who: >LHJM, first: K, type: Sffx, corpus class: 802
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	NP		>LHJM     	god(s)
# 2	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 4	PPrP	p2msg	>TH     	you
# 4	VP	p2msg	TKPR     	cover
# 5	VP	p2msg	TBXR     	examine
# 5	VP	p2msg	QRB     	approach
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 6	VP	p2msg	T<N     	answer
# 6	NP		>LHJ JC<     	god(s)	Nested mention: (God of (our (help)).
# 7	VP	umsg	MKJN     	be firm
# 7	Sffx	p3msg	W
# 7	VP	umsg	N>ZR     	put on
# 8	VP	umsg	MCBJX     	be calm
# 9	Sffx	p2msg	K
# 10	VP	p2msg	PQDT     	miss
# 10	VP	p2msg	TCQQ     	be narrow
# 10	VP	p2msg	<CRN     	become rich
# 10	VP	p2msg	TKJN     	be firm
# 10	VP	p2msg	TKJN     	be firm
# 11	VP	p2msg	RWH     	drink
# 11	VP	p2msg	NXT     	descend
# 11	VP	p2msg	TMGGN     	faint
# 11	VP	p2msg	BRK     	bless
# 12	VP	p2msg	<VRT     	surround
# 12	Sffx	p2msg	K
# 12	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'NP', 'Sfx p2msg', 'Sfx p2msg', 'PPrP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'NP', 'VP umsg', 'Sfx p3msg', 'VP umsg', 'VP umsg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg']
#
#
# C67:5 Who: >LHJM, first: >LHJM, type: NP, corpus class: 831
#
# verse	type	pgn	ann		gloss	note
# 2	NP		>LHJM     	god(s)
# 2	VP	p3msg	JXN     	favour
# 2	VP	p3msg	JBRK     	bless
# 2	VP	p3msg	J>R     	be light
# 2	Sffx	p3msg	W
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 4	Sffx	p2msg	K
# 4	NP		>LHJM     	god(s)
# 4	Sffx	p2msg	K
# 5	VP	p2msg	TCPV     	judge
# 5	VP	p2msg	TNX     	lead
# 6	Sffx	p2msg	K
# 6	NP		>LHJM     	god(s)
# 6	Sffx	p2msg	K
# 7	VP	p3msg	JBRK     	bless
# 7	NP		>LHJM     	god(s)
# 7	NP		>LHJ     	god(s)
# 8	VP	p3msg	JBRK     	bless
# 8	NP		>LHJM     	god(s)
# 8	Sffx	p3msg	W
# Pattern:  ['NP', 'VP p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p3msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'NP', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'NP', 'Sfx p2msg', 'VP p3msg', 'NP', 'NP', 'VP p3msg', 'NP', 'Sfx p3msg']
#
#
# C75:4 Who: >LHJM, first: K, type: Sffx, corpus class: 994
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	NP		>LHJM     	god(s)
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	VP	p1usg	>QX     	take
# 3	PPrP	p1usg	>NJ     	i
# 3	VP	p1usg	>CPV     	judge
# 4	PPrP	p1usg	>NKJ     	i
# 4	VP	p1usg	TKNTJ     	estimate
# 5	VP	p1usg	>MRTJ     	say
# 8	NP		>LHJM     	god(s)
# 8	NP		CPV     	judge
# 8	VP	p3msg	JCPJL     	be low
# 8	VP	p3msg	JRJM     	be high
# 9	NP		JD&JHWH     	hand
# 9	VP	p3msg	JGR     	run
# 10	NP		>LHJ J<QB     	god(s)
# 11	VP	p1usg	>GD<     	cut off
# Pattern:  ['Sfx p2msg', 'NP', 'Sfx p2msg', 'Sfx p2msg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'NP', 'NP', 'VP p3msg', 'VP p3msg', 'NP', 'VP p3msg', 'NP', 'VP p1usg']
#
#
# C81:2 Who: >LHJM, first: >LHJM, type: NP, corpus class: 1105
#
# verse	type	pgn	ann		gloss	note
# 2	NP		>LHJM     	god(s)
# 2	NP		<WZ     	protection	In apposition with "God".
# 2	NP		>LHJ J<QB     	god(s)	Nested mention: (God of (Jacob)).
# 5	NP		>LHJ J<QB     	god(s)	Nested mention: (God of (Jacob)).
# 6	VP	p3msg	FM     	put
# 6	VP	uuu	Y>TW     	go out	Infc with PreS. Predicate subject could refer to God or Joseph.
# Pattern:  ['NP', 'NP', 'NP', 'NP', 'VP p3msg', 'VP uuu']
#
#
# C82:4 Who: >LHJM, first: >LHJM, type: NP, corpus class: 1117
#
# verse	type	pgn	ann		gloss	note
# 1	NP		>LHJM     	god(s)
# 1	VP	umsg	NYB     	stand
# 1	VP	p3msg	JCPV     	judge
# 6	PPrP	p1usg	>NJ     	i
# 6	VP	p1usg	>MRTJ     	say
# 8	VP	p2msg	QWMH     	arise
# 8	NP		>LHJM     	god(s)
# 8	VP	p2msg	CPVH     	judge
# 8	PPrP	p2msg	>TH     	you
# 8	VP	p2msg	TNXL     	take possession
# Pattern:  ['NP', 'VP umsg', 'VP p3msg', 'PPrP p1usg', 'VP p1usg', 'VP p2msg', 'NP', 'VP p2msg', 'PPrP p2msg', 'VP p2msg']
#
#
# C82:3 Who: >LHJM, first: >LHJM, type: NP, corpus class: 1120
#
# verse	type	pgn	ann		gloss	note
# 6	NP		>LHJM     	god(s)
# 6	Sffx	p3mpl	M
# 6	NP		BNJ <LJWN     	son
# 6	NP		KL     	whole
# 6	Sffx	p2mpl	KM
# 7	VP	p2mpl	TMWTWN     	die
# 7	VP	p2mpl	TPLW     	fall
# Pattern:  ['NP', 'Sfx p3mpl', 'NP', 'NP', 'Sfx p2mpl', 'VP p2mpl', 'VP p2mpl']
#
#
# Results:  17
# ['C43:3',
#  'C45:4',
#  'C45:7',
#  'C48:11',
#  'C49:15',
#  'C53:10',
#  'C58:12',
#  'C60:3',
#  'C61:3',
#  'C62:1',
#  'C63:2',
#  'C65:8',
#  'C67:5',
#  'C75:4',
#  'C81:2',
#  'C82:4',
#  'C82:3']

# %% [markdown]
# #### Suffix K

# %%
# A great number of the K suffixes refer to God
FindFirst(corefs, suffix_errors, 'Sffx', ['K']) # 'PPrP', >NJ'
# Out:
# C20:1 Who: K, first: K, type: Sffx, corpus class: 215
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 4	Sffx	p2msg	K
# 4	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 6	Sffx	p2msg	K    			Is the 2Msg the same as the 1Cpl in this verse?
# Pattern:  ['Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg']
#
#
# C25:5 Who: JHWH, first: K, type: Sffx, corpus class: 272
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	PrNP		JHWH     	YHWH
# 2	NP		>LH     	god(s)
# 2	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 4	Sffx	p2msg	K
# 4	PrNP		JHWH     	YHWH
# 4	VP	p2msg	HWDJ<     	know
# 4	Sffx	p2msg	K
# 4	VP	p2msg	LMD     	learn
# 5	VP	p2msg	HDRJK     	tread
# 5	Sffx	p2msg	K
# 5	VP	p2msg	LMD     	learn
# 5	PPrP	p2msg	>TH     	you
# 5	NP		>LHJ JC<     	god(s)
# 5	Sffx	p2msg	K
# 6	VP	p2msg	ZKR     	remember
# 6	Sffx	p2msg	K
# 6	PrNP		JHWH     	YHWH
# 6	Sffx	p2msg	K
# 7	VP	p2msg	TZKR     	remember
# 7	Sffx	p2msg	K
# 7	VP	p2msg	ZKR     	remember
# 7	PPrP	p2msg	>TH     	you
# 7	Sffx	p2msg	K
# 7	PrNP		JHWH     	YHWH
# 8	PrNP		JHWH     	YHWH
# 8	VP	p3msg	JWRH     	teach
# 9	VP	p3msg	JDRK     	tread
# 9	VP	p3msg	JLMD     	learn
# 9	Sffx	p3msg	W
# 10	Sffx	p3msg	W
# 10	Sffx	p3msg	W
# 11	Sffx	p2msg	K
# 11	PrNP		JHWH     	YHWH
# 11	VP	p2msg	SLXT     	forgive
# 12	VP	p3msg	JWRN     	teach
# 12	VP	p3msg	JBXR     	examine
# 14	NP		SWD JHWH     	confidential talk	Nested mention: (confidence of (YHWH)).
# 14	Sffx	p3msg	W
# 14	Sffx	p3msg	W
# 14	VP	uuu	HWDJ<     	know	Infc with PreO.
# 15	PrNP		JHWH     	YHWH
# 15	PPrP	p3msg	HW>     	he
# 15	VP	p3msg	JWYJ>     	go out
# 16	VP	p2msg	PNH     	turn
# 16	VP	p2msg	XN     	favour
# 17	VP	p2msg	HWYJ>     	go out
# 18	VP	p2msg	R>H     	see
# 18	VP	p2msg	F>     	lift
# 19	VP	p2msg	R>H     	see
# 20	VP	p2msg	CMRH     	keep
# 20	VP	p2msg	HYJL     	deliver
# 20	Sffx	p2msg	K
# 21	Sffx	p2msg	K
# 22	VP	p2msg	PDH     	buy off
# 22	NP		>LHJM     	god(s)
# Pattern:  ['Sfx p2msg', 'PrNP ', 'NP ', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PrNP ', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'PPrP p2msg', 'NP ', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'PPrP p2msg', 'Sfx p2msg', 'PrNP ', 'PrNP ', 'VP p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p2msg', 'PrNP ', 'VP p2msg', 'VP p3msg', 'VP p3msg', 'NP ', 'Sfx p3msg', 'Sfx p3msg', 'VP uuu', 'PrNP ', 'PPrP p3msg', 'VP p3msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'NP ']
#
#
# C28:3 Who: JHWH, first: K, type: Sffx, corpus class: 312
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	PrNP		JHWH     	YHWH
# 1	NP		YWR     	rock
# 1	VP	p2msg	TXRC     	be deaf
# 1	VP	p2msg	TXCH     	be silent
# 2	VP	p2msg	CM<     	hear
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	VP	p2msg	TMCK     	draw
# 4	VP	p2msg	TN     	give
# 4	VP	p2msg	TN     	give
# 4	VP	p2msg	HCB     	return
# 5	Sffx	p3msg	W
# 5	VP	p3msg	JHRS     	tear down
# 5	VP	p3msg	JBN     	build
# 6	VP	umsg	BRWK     	bless
# 6	PrNP		JHWH     	YHWH
# 6	VP	p3msg	CM<     	hear
# 7	PrNP		JHWH     	YHWH
# 7	NP		<Z     	protection
# 7	NP		MGN     	shield
# 7	Sffx	p3msg	W
# 7	Sffx	p3msg	W
# 8	PrNP		JHWH     	YHWH
# 8	Sffx	p3msg	W
# 8	PPrP	p3msg	HW>     	he
# 9	VP	p2msg	HWCJ<H     	help
# 9	Sffx	p2msg	K
# 9	VP	p2msg	BRK     	bless
# 9	Sffx	p2msg	K
# 9	VP	p2msg	R<     	pasture
# 9	VP	p2msg	NF>     	lift
# Pattern:  ['Sfx p2msg', 'PrNP ', 'NP ', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'VP umsg', 'PrNP ', 'VP p3msg', 'PrNP ', 'NP ', 'NP ', 'Sfx p3msg', 'Sfx p3msg', 'PrNP ', 'Sfx p3msg', 'PPrP p3msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg']
#
#
# C30:1 Who: JHWH, first: K, type: Sffx, corpus class: 328
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	PrNP		JHWH     	YHWH
# 2	VP	p2msg	DLJT     	draw water
# 2	VP	p2msg	FMXT     	rejoice
# 3	PrNP		JHWH     	YHWH
# 3	NP		>LH     	god(s)	In apposition with "YHWH".
# 3	Sffx	p2msg	K
# 3	VP	p2msg	TRP>     	heal
# 4	PrNP		JHWH     	YHWH
# 4	VP	p2msg	H<LJT     	ascend
# 4	VP	p2msg	XJJT     	be alive
# 5	PrNP		JHWH     	YHWH
# 5	Sffx	p3msg	W
# 5	Sffx	p3msg	W
# 6	Sffx	p3msg	W
# 6	Sffx	p3msg	W
# 8	PrNP		JHWH     	YHWH
# 8	Sffx	p2msg	K
# 8	VP	p2msg	H<MDTH     	stand
# 8	VP	p2msg	HSTRT     	hide
# 8	Sffx	p2msg	K
# 9	Sffx	p2msg	K
# 9	PrNP		JHWH     	YHWH
# 9	PrNP		>DNJ     	Lord
# 10	Sffx	p2msg	K
# 10	Sffx	p2msg	K
# 11	VP	p2msg	CM<     	hear
# 11	PrNP		JHWH     	YHWH
# 11	VP	p2msg	XN     	favour
# 11	PrNP		JHWH     	YHWH
# 11	VP	p2msg	HJH     	be
# 12	VP	p2msg	HPKT     	turn
# 12	VP	p2msg	PTXT     	open
# 12	VP	p2msg	T>ZR     	put on
# 13	Sffx	p2msg	K
# 13	PrNP		JHWH     	YHWH
# 13	NP		>LH     	god(s)	In apposition with "YHWH".
# 13	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'PrNP ', 'VP p2msg', 'VP p2msg', 'PrNP ', 'NP ', 'Sfx p2msg', 'VP p2msg', 'PrNP ', 'VP p2msg', 'VP p2msg', 'PrNP ', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'PrNP ', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PrNP ', 'PrNP ', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'PrNP ', 'VP p2msg', 'PrNP ', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'PrNP ', 'NP ', 'Sfx p2msg']
#
#
# C31:1 Who: JHWH, first: K, type: Sffx, corpus class: 334
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	PrNP		JHWH     	YHWH
# 2	Sffx	p2msg	K
# 2	VP	p2msg	PLV     	escape
# 3	VP	p2msg	HVH     	extend
# 3	Sffx	p2msg	K
# 3	VP	p2msg	HYJL     	deliver
# 3	VP	p2msg	HJH     	be
# 3	VP	uuu	HWCJ<     	help	Infc with PreO.
# 4	NP		SL<     	rock
# 4	NP		MYWDT     	fortification
# 4	PPrP	p2msg	>TH     	you
# 4	Sffx	p2msg	K
# 4	VP	p2msg	TNX     	lead
# 4	VP	p2msg	TNHL     	lead
# 5	VP	p2msg	TWYJ>     	go out
# 5	PPrP	p2msg	>TH     	you
# 5	NP		M<WZ     	fort
# 6	Sffx	p2msg	K
# 6	VP	p2msg	PDJTH     	buy off
# 6	PrNP		JHWH     	YHWH
# 6	NP		>L >M     	god	In apposition with "YHWH".
# 7	PrNP		JHWH     	YHWH
# 8	Sffx	p2msg	K
# 8	VP	p2msg	R>JT     	see
# 8	VP	p2msg	JD<T     	know
# 9	VP	p2msg	HSGRT     	close
# 9	VP	p2msg	H<MDT     	stand
# 10	VP	p2msg	XN     	favour
# 10	PrNP		JHWH     	YHWH
# 15	Sffx	p2msg	K
# 15	PrNP		JHWH     	YHWH
# 15	NP		>LH     	god(s)
# 15	PPrP	p2msg	>TH     	you
# 16	Sffx	p2msg	K
# 16	VP	p2msg	HYJL     	deliver
# 17	VP	p2msg	H>JRH     	be light
# 17	Sffx	p2msg	K
# 17	Sffx	p2msg	K
# 17	VP	p2msg	HWCJ<     	help
# 17	Sffx	p2msg	K
# 18	PrNP		JHWH     	YHWH
# 18	Sffx	p2msg	K
# 20	Sffx	p2msg	K
# 20	VP	p2msg	YPNT     	hide
# 20	Sffx	p2msg	K
# 20	VP	p2msg	P<LT     	make
# 20	Sffx	p2msg	K
# 21	VP	p2msg	TSTJR     	hide
# 21	Sffx	p2msg	K
# 21	VP	p2msg	TYPN     	hide
# 22	VP	umsg	BRWK     	bless
# 22	PrNP		JHWH     	YHWH
# 22	VP	p3msg	HPLJ>     	be miraculous
# 22	Sffx	p3msg	W
# 23	Sffx	p2msg	K
# 23	VP	p2msg	CM<T     	hear
# 23	Sffx	p2msg	K
# 24	PrNP		JHWH     	YHWH
# 24	Sffx	p3msg	W
# 24	VP	umsg	NYR     	watch
# 24	PrNP		JHWH     	YHWH
# 25	PrNP		JHWH     	YHWH
# Pattern:  ['Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP uuu', 'NP ', 'NP ', 'PPrP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'PPrP p2msg', 'NP ', 'Sfx p2msg', 'VP p2msg', 'PrNP ', 'NP ', 'PrNP ', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'PrNP ', 'Sfx p2msg', 'PrNP ', 'NP ', 'PPrP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP umsg', 'PrNP ', 'VP p3msg', 'Sfx p3msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'PrNP ', 'Sfx p3msg', 'VP umsg', 'PrNP ', 'PrNP ']
#
#
# C40:8 Who: K, first: K, type: Sffx, corpus class: 507
#
# verse	type	pgn	ann		gloss	note
# 12	Sffx	p2msg	K
# 12	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'Sfx p2msg']
#
#
# C42:7 Who: JHWH, first: K, type: Sffx, corpus class: 529
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	NP		>LHJM     	god(s)
# 3	NP		>LHJM     	god(s)
# 3	NP		>L XJ     	god	In apposition with"God".
# 3	NP		NJ >LHJM     	face	Nested mention: (face of (God)) = before God, therefore corefering with God earlier in verse.
# 4	NP		>LHJ     	god(s)
# 6	NP		>LHJM     	god(s)
# 6	Sffx	p3msg	W
# 6	Sffx	p3msg	W
# 7	NP		>LH     	god(s)
# 7	Sffx	p2msg	K
# 8	Sffx	p2msg	K
# 8	Sffx	p2msg	K
# 8	Sffx	p2msg	K
# 9	VP	p3msg	JYWH     	command
# 9	PrNP		JHWH     	YHWH
# 9	Sffx	p3msg	W
# 9	NP		>L XJ     	god
# 10	NP		>L     	god
# 10	NP		SL<     	rock
# 10	VP	p2msg	CKXT     	forget
# 11	NP		>LHJ     	god(s)
# 12	NP		>LHJM     	god(s)
# 12	Sffx	p3msg	W
# 12	NP		>LH     	god(s)
# Pattern:  ['Sfx p2msg', 'NP ', 'NP ', 'NP ', 'NP ', 'NP ', 'NP ', 'Sfx p3msg', 'Sfx p3msg', 'NP ', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p3msg', 'PrNP ', 'Sfx p3msg', 'NP ', 'NP ', 'NP ', 'VP p2msg', 'NP ', 'NP ', 'Sfx p3msg', 'NP ']
#
#
# C45:7 Who: >LHJM, first: K, type: Sffx, corpus class: 566
#
# verse	type	pgn	ann		gloss	note
# 7	Sffx	p2msg	K
# 7	NP		>LHJM     	god(s)
# 7	Sffx	p2msg	K
# 8	VP	p3msg	MCX     	smear
# 8	NP		>LHJM     	god(s)
# 8	NP		>LHJ     	god(s)
# Pattern:  ['Sfx p2msg', 'NP ', 'Sfx p2msg', 'VP p3msg', 'NP ', 'NP ']
#
#
# C49:18 Who: TJVJB, first: K, type: Sffx, corpus class: 621
#
# verse	type	pgn	ann		gloss	note
# 19	Sffx	p2msg	K
# 19	VP	p2msg	TJVJB     	be good
# 19	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'VP p2msg', 'Sfx p2msg']
#
#
# C53:8 Who: HBCTH, first: K, type: Sffx, corpus class: 669
#
# verse	type	pgn	ann		gloss	note
# 6	Sffx	p2msg	K    			Who is 2Msg?
# 6	VP	p2msg	HBCTH     	be ashamed
# Pattern:  ['Sfx p2msg', 'VP p2msg']
#
#
# C65:8 Who: >LHJM, first: K, type: Sffx, corpus class: 801
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	NP		>LHJM     	god(s)
# 2	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 4	PPrP	p2msg	>TH     	you
# 4	VP	p2msg	TKPR     	cover
# 5	VP	p2msg	TBXR     	examine
# 5	VP	p2msg	QRB     	approach
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 6	VP	p2msg	T<N     	answer
# 6	NP		>LHJ JC<     	god(s)	Nested mention: (God of (our (help)).
# 7	VP	umsg	MKJN     	be firm
# 7	Sffx	p3msg	W
# 7	VP	umsg	N>ZR     	put on
# 8	VP	umsg	MCBJX     	be calm
# 9	Sffx	p2msg	K
# 10	VP	p2msg	PQDT     	miss
# 10	VP	p2msg	TCQQ     	be narrow
# 10	VP	p2msg	<CRN     	become rich
# 10	VP	p2msg	TKJN     	be firm
# 10	VP	p2msg	TKJN     	be firm
# 11	VP	p2msg	RWH     	drink
# 11	VP	p2msg	NXT     	descend
# 11	VP	p2msg	TMGGN     	faint
# 11	VP	p2msg	BRK     	bless
# 12	VP	p2msg	<VRT     	surround
# 12	Sffx	p2msg	K
# 12	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'NP ', 'Sfx p2msg', 'Sfx p2msg', 'PPrP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'NP ', 'VP umsg', 'Sfx p3msg', 'VP umsg', 'VP umsg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg']
#
#
# C71:1 Who: JHWH, first: K, type: Sffx, corpus class: 919
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	PrNP		JHWH     	YHWH
# 2	Sffx	p2msg	K
# 2	VP	p2msg	TYJL     	deliver
# 2	VP	p2msg	TPLV     	escape
# 2	VP	p2msg	HVH     	extend
# 2	Sffx	p2msg	K
# 2	VP	p2msg	HWCJ<     	help
# 3	VP	p2msg	HJH     	be
# 3	VP	p2msg	YWJT     	command
# 3	NP		SL<     	rock
# 3	NP		MYWDT     	fortification
# 3	PPrP	p2msg	>TH     	you
# Pattern:  ['Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'NP ', 'NP ', 'PPrP p2msg']
#
#
# C75:4 Who: >LHJM, first: K, type: Sffx, corpus class: 993
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	NP		>LHJM     	god(s)
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	VP	p1usg	>QX     	take
# 3	PPrP	p1usg	>NJ     	i
# 3	VP	p1usg	>CPV     	judge
# 4	PPrP	p1usg	>NKJ     	i
# 4	VP	p1usg	TKNTJ     	estimate
# 5	VP	p1usg	>MRTJ     	say
# 8	NP		>LHJM     	god(s)
# 8	NP		CPV     	judge
# 8	VP	p3msg	JCPJL     	be low
# 8	VP	p3msg	JRJM     	be high
# 9	NP		JD&JHWH     	hand
# 9	VP	p3msg	JGR     	run
# 10	NP		>LHJ J<QB     	god(s)
# 11	VP	p1usg	>GD<     	cut off
# Pattern:  ['Sfx p2msg', 'NP ', 'Sfx p2msg', 'Sfx p2msg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'NP ', 'NP ', 'VP p3msg', 'VP p3msg', 'NP ', 'VP p3msg', 'NP ', 'VP p1usg']
#
#
# C81:11 Who: JFR>L, first: K, type: Sffx, corpus class: 1111
#
# verse	type	pgn	ann		gloss	note
# 8	Sffx	p2msg	K    			Who is 2Msg?
# 8	Sffx	p2msg	K
# 8	Sffx	p2msg	K
# 9	VP	p2msg	CM<     	hear
# 9	NP		<M     	people
# 9	Sffx	p2msg	K
# 9	PrNP		JFR>L     	Israel
# 9	VP	p2msg	TCM<     	hear
# 10	Sffx	p2msg	K
# 10	VP	p2msg	TCTXWH     	bow down
# 11	Sffx	p2msg	K
# 11	Sffx	p2msg	K
# 11	VP	p2msg	HRXB     	be wide
# 11	Sffx	p2msg	K
# 12	VP	p3msg	CM<     	hear
# 12	NP		<M     	people
# 12	PrNP		JFR>L     	Israel
# 12	VP	p3msg	>BH     	want
# 13	Sffx	p3msg	HW
# 13	Sffx	p3mpl	M
# 13	VP	p3mpl	JLKW     	walk
# 13	Sffx	p3mpl	HM
# 14	NP		<M     	people
# 14	VP	umsg	CM<     	hear
# 14	PrNP		JFR>L     	Israel
# 14	VP	p3mpl	JHLKW     	walk
# 15	Sffx	p3mpl	HM
# 15	Sffx	p3mpl	HM
# 17	Sffx	p3msg	HW
# 17	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'NP ', 'Sfx p2msg', 'PrNP ', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p3msg', 'NP ', 'PrNP ', 'VP p3msg', 'Sfx p3msg', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'NP ', 'VP umsg', 'PrNP ', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3msg', 'Sfx p2msg']
#
#
# C83:11 Who: JHWH, first: K, type: Sffx, corpus class: 1130
#
# verse	type	pgn	ann		gloss	note
# 19	Sffx	p2msg	K
# 19	PrNP		JHWH     	YHWH
# 19	Sffx	p2msg	K
# 19	NP		<LJWN     	upper
# Pattern:  ['Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'NP ']
#
#
# C84:1 Who: JHWH YB>WT, first: K, type: Sffx, corpus class: 1131
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	PrNP		JHWH YB>WT     	YHWH	Nested mention: (YHWH of (hosts)).
# 3	NP		>L&XJ     	god
# 4	Sffx	p2msg	K
# 4	PrNP		JHWH YB>WT     	YHWH	Nested mention: (YHWH of (hosts)).
# Pattern:  ['Sfx p2msg', 'PrNP ', 'NP ', 'Sfx p2msg', 'PrNP ']
#
#
# C89:3 Who: TKN, first: K, type: Sffx, corpus class: 1183
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 3	VP	p2msg	TKN     	be firm
# 3	Sffx	p2msg	K
# 4	VP	p1usg	KRTJ     	cut
# 4	Sffx	p1usg	J
# 4	VP	p1usg	NCB<TJ     	swear
# 4	Sffx	p1usg	J
# 5	VP	p1usg	>KJN     	be firm
# 5	VP	p1usg	BNJTJ     	build
# Pattern:  ['Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg']
#
#
# C89:36 Who: JHWH, first: K, type: Sffx, corpus class: 1189
#
# verse	type	pgn	ann		gloss	note
# 6	Sffx	p2msg	K
# 6	PrNP		JHWH     	YHWH
# 6	Sffx	p2msg	K
# 7	PrNP		JHWH     	YHWH
# 7	PrNP		JHWH     	YHWH
# 8	NP		>L     	god
# 8	VP	umsg	N<RY     	tremble
# 8	VP	umsg	NWR>     	fear
# 8	Sffx	p3msg	W
# 9	PrNP		JHWH     	YHWH
# 9	NP		>LHJ YB>WT     	god(s)	In apposition with "YHWH". Nested mention: (God of (hosts)).
# 9	Sffx	p2msg	K
# 9	PrNP		JH     	the Lord
# 9	Sffx	p2msg	K
# 9	Sffx	p2msg	K
# 10	PPrP	p2msg	>TH     	you
# 10	VP	umsg	MWCL     	rule
# 10	PPrP	p2msg	>TH     	you
# 10	VP	p2msg	TCBX     	be calm
# 11	PPrP	p2msg	>TH     	you
# 11	VP	p2msg	DK>T     	oppress
# 11	Sffx	p2msg	K
# 11	VP	p2msg	PZRT     	scatter
# 11	Sffx	p2msg	K
# 12	Sffx	p2msg	K
# 12	Sffx	p2msg	K
# 12	PPrP	p2msg	>TH     	you
# 12	VP	p2msg	JSDT     	found
# 13	PPrP	p2msg	>TH     	you
# 13	VP	p2msg	BR>T     	create
# 13	Sffx	p2msg	K
# 14	Sffx	p2msg	K
# 14	Sffx	p2msg	K
# 14	Sffx	p2msg	K
# 15	Sffx	p2msg	K
# 15	Sffx	p2msg	K
# 16	PrNP		JHWH     	YHWH
# 16	Sffx	p2msg	K
# 17	Sffx	p2msg	K
# 17	Sffx	p2msg	K
# 18	PPrP	p2msg	>TH     	you
# 18	Sffx	p2msg	K
# 19	PrNP		JHWH     	YHWH
# 19	NP		QDWC JFR>L     	holy	Nested mention: (holy one of (Israel)).
# 20	VP	p2msg	DBRT     	speak
# 20	Sffx	p2msg	K
# 20	VP	p2msg	T>MR     	say
# 20	VP	p1usg	CWJTJ     	place
# 20	VP	p1usg	HRJMWTJ     	be high
# 21	VP	p1usg	MY>TJ     	find
# 21	Sffx	p1usg	J
# 21	Sffx	p1usg	J
# 21	VP	p1usg	MCXTJ     	smear
# 22	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# 24	VP	p1usg	KTWTJ     	crush
# 24	VP	p1usg	>GWP     	hurt
# 25	Sffx	p1usg	J
# 25	Sffx	p1usg	J
# 25	Sffx	p1usg	J
# 26	VP	p1usg	FMTJ     	put
# 27	Sffx	p1usg	NJ
# 27	NP		>B     	father
# 27	PPrP	p2msg	>TH     	you
# 27	NP		>L     	god
# 27	NP		YWR JCW<T     	rock
# 28	PPrP	p1usg	>NJ     	i
# 28	VP	p1usg	>TN     	give
# 29	VP	p1usg	>CMWR     	keep
# 29	Sffx	p1usg	J
# 29	Sffx	p1usg	J
# 30	VP	p1usg	FMTJ     	put
# 31	Sffx	p1usg	J
# 31	Sffx	p1usg	J
# 32	Sffx	p1usg	J
# 32	Sffx	p1usg	J
# 33	VP	p1usg	PQDTJ     	miss
# 34	Sffx	p1usg	J
# 34	VP	p1usg	>PJR     	destroy
# 34	VP	p1usg	>CQR     	do falsely
# 34	Sffx	p1usg	J
# 35	VP	p1usg	>XLL     	defile
# 35	Sffx	p1usg	J
# 35	Sffx	p1usg	J
# 35	VP	p1usg	>CNH     	change
# 36	VP	p1usg	NCB<TJ     	swear
# 36	Sffx	p1usg	J
# 36	VP	p1usg	>KZB     	lie
# 37	Sffx	p1usg	J
# 39	PPrP	p2msg	>TH     	you
# 39	VP	p2msg	ZNXT     	reject
# 39	VP	p2msg	TM>S     	retract
# 39	VP	p2msg	HT<BRT     	be angry
# 39	Sffx	p2msg	K
# 40	VP	p2msg	N>RTH     	abandon
# 40	Sffx	p2msg	K
# 40	VP	p2msg	XLLT     	defile
# 41	VP	p2msg	PRYT     	break
# 41	VP	p2msg	FMT     	put
# 43	VP	p2msg	HRJMWT     	be high
# 43	VP	p2msg	HFMXT     	rejoice
# 44	VP	p2msg	TCJB     	return
# 44	VP	p2msg	HQJMT     	arise
# 45	VP	p2msg	HCBT     	cease
# 45	VP	p2msg	MGRTH     	hurl
# 46	VP	p2msg	HQYRT     	be short
# 46	VP	p2msg	H<VJT     	cover
# 47	PrNP		JHWH     	YHWH
# 47	VP	p2msg	TSTR     	hide
# 47	Sffx	p2msg	K
# 48	VP	p2msg	ZKR     	remember
# 48	VP	p2msg	BR>T     	create
# 50	Sffx	p2msg	K
# 50	PrNP		>DNJ     	Lord
# 50	VP	p2msg	NCB<T     	swear
# 50	Sffx	p2msg	K
# 51	VP	p2msg	ZKR     	remember
# 51	PrNP		>DNJ     	Lord
# 51	Sffx	p2msg	K
# 52	Sffx	p2msg	K
# 52	PrNP		JHWH     	YHWH
# 52	Sffx	p2msg	K
# 53	VP	umsg	BRWK     	bless
# 53	PrNP		JHWH     	YHWH
# Pattern:  ['Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'PrNP ', 'PrNP ', 'NP ', 'VP umsg', 'VP umsg', 'Sfx p3msg', 'PrNP ', 'NP ', 'Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'Sfx p2msg', 'PPrP p2msg', 'VP umsg', 'PPrP p2msg', 'VP p2msg', 'PPrP p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PPrP p2msg', 'VP p2msg', 'PPrP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PPrP p2msg', 'Sfx p2msg', 'PrNP ', 'NP ', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'NP ', 'PPrP p2msg', 'NP ', 'NP ', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'PPrP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'PrNP ', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'PrNP ', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'PrNP ', 'Sfx p2msg', 'Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'VP umsg', 'PrNP ']
#
#
# C91:7 Who: TXSH, first: K, type: Sffx, corpus class: 1235
#
# verse	type	pgn	ann		gloss	note
# 3	Sffx	p2msg	K    			Who is 2msg?
# 4	Sffx	p2msg	K
# 4	VP	p2msg	TXSH     	seek refuge
# 5	VP	p2msg	TJR>     	fear
# 7	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 8	Sffx	p2msg	K
# 8	VP	p2msg	TBJV     	look at
# 8	VP	p2msg	TR>H     	see
# 9	VP	p2msg	FMT     	put
# 9	Sffx	p2msg	K
# 10	Sffx	p2msg	K
# 10	Sffx	p2msg	K
# 11	Sffx	p2msg	K
# 11	Sffx	p2msg	K
# 11	Sffx	p2msg	K
# 12	Sffx	p2msg	K
# 12	Sffx	p2msg	K
# 13	VP	p2msg	TDRK     	tread
# 13	VP	p2msg	TRMS     	trample
# 14	VP	p3msg	XCQ     	love	2Msg of previous verses (v.13 e.g.) is 3Msg here.
# 14	Sffx	p3msg	HW
# 14	Sffx	p3msg	HW
# 14	VP	p3msg	JD<     	know
# 15	VP	p3msg	JQR>     	call
# 15	Sffx	p3msg	HW
# 15	Sffx	p3msg	W
# 15	Sffx	p3msg	HW
# 15	Sffx	p3msg	HW
# 16	Sffx	p3msg	HW
# 16	Sffx	p3msg	HW
# Pattern:  ['Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'VP p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg']
#
#
# C92:4 Who: JHWH, first: K, type: Sffx, corpus class: 1246
#
# verse	type	pgn	ann		gloss	note
# 6	Sffx	p2msg	K
# 6	PrNP		JHWH     	YHWH
# 6	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'PrNP ', 'Sfx p2msg']
#
#
# C101:1 Who: JHWH, first: K, type: Sffx, corpus class: 1336
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	PrNP		JHWH     	YHWH
# 2	VP	p2msg	TBW>     	come
# Pattern:  ['Sfx p2msg', 'PrNP ', 'VP p2msg']
#
#
# C115:2 Who: K, first: K, type: Sffx, corpus class: 1581
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	Sffx	p2msg	K
# Pattern:  ['Sfx p2msg', 'Sfx p2msg']
#
#
# C121:3 Who: Y>TK, first: K, type: Sffx, corpus class: 1705
#
# verse	type	pgn	ann		gloss	note
# 3	Sffx	p2msg	K
# 3	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 8	VP	uuu	Y>TK     	go out	Infc with PreS.
# 8	VP	uuu	BW>K     	come	Infc with PreS.
# Pattern:  ['Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP uuu', 'VP uuu']
#
#
# C122:3 Who: JRWCLM, first: K, type: Sffx, corpus class: 1710
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	PrNP		JRWCLM     	Jerusalem
# 3	PrNP		JRWCLM     	Jerusalem
# 3	CP		HBNWJH     	the
# Pattern:  ['Sfx p2msg', 'PrNP ', 'PrNP ', 'CP ']
#
#
# C123:2 Who: JHWH, first: K, type: Sffx, corpus class: 1717
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	VP	umsg	JCBJ     	sit
# 2	PrNP		JHWH     	YHWH
# 2	NP		>LHJ     	god(s)	In apposition with "YHWH".
# 2	VP	p3msg	JXN     	favour
# 3	VP	p2msg	XN     	favour
# 3	PrNP		JHWH     	YHWH
# 3	VP	p2msg	XN     	favour
# Pattern:  ['Sfx p2msg', 'VP umsg', 'PrNP ', 'NP ', 'VP p3msg', 'VP p2msg', 'PrNP ', 'VP p2msg']
#
#
# C130:1 Who: JHWH, first: K, type: Sffx, corpus class: 1767
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	PrNP		JHWH     	YHWH
# 2	PrNP		>DNJ     	Lord
# 2	VP	p2msg	CM<H     	hear
# 2	Sffx	p2msg	K
# 3	VP	p2msg	TCMR     	keep
# 3	PrNP		JH     	the Lord
# 3	PrNP		>DNJ     	Lord
# 4	Sffx	p2msg	K
# 4	VP	p2msg	TWR>     	fear
# 5	PrNP		JHWH     	YHWH
# 5	Sffx	p3msg	W
# 6	PrNP		>DNJ     	Lord
# 7	PrNP		JHWH     	YHWH
# 7	PrNP		JHWH     	YHWH
# 7	Sffx	p3msg	W
# 8	PPrP	p3msg	HW>     	he
# 8	VP	p3msg	JPDH     	buy off
# Pattern:  ['Sfx p2msg', 'PrNP ', 'PrNP ', 'VP p2msg', 'Sfx p2msg', 'VP p2msg', 'PrNP ', 'PrNP ', 'Sfx p2msg', 'VP p2msg', 'PrNP ', 'Sfx p3msg', 'PrNP ', 'PrNP ', 'PrNP ', 'Sfx p3msg', 'PPrP p3msg', 'VP p3msg']
#
#
# C137:4 Who: JRWCLM, first: K, type: Sffx, corpus class: 1835
#
# verse	type	pgn	ann		gloss	note
# 5	Sffx	p2msg	K
# 5	PrNP		JRWCLM     	Jerusalem
# 6	Sffx	 	KJ    		remember	!CORRUPT ANN
# 6	PrNP		JRWCLM     	Jerusalem
# 7	Sffx	p3fsg	H
# Pattern:  ['Sfx p2msg', 'PrNP ', 'Sfx', 'PrNP ', 'Sfx p3fsg']
#
#
# C138:2 Who: JHWH, first: K, type: Sffx, corpus class: 1845
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	NP		>LHJM     	god(s)
# 1	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 2	VP	p2msg	HGDLT     	be strong
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	VP	p2msg	T<N     	answer
# 3	VP	p2msg	TRHB     	storm against
# 4	Sffx	p2msg	K
# 4	PrNP		JHWH     	YHWH
# 4	Sffx	p2msg	K
# 6	PrNP		JHWH     	YHWH
# 6	VP	p3msg	JR>H     	see
# 6	VP	p3msg	JJD<     	know
# 7	VP	p2msg	TXJ     	be alive
# 7	VP	p2msg	TCLX     	send
# 7	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 8	PrNP		JHWH     	YHWH
# 8	VP	p3msg	JGMR     	end
# Pattern:  ['Sfx p2msg', 'NP ', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'PrNP ', 'VP p3msg', 'VP p3msg', 'VP p2msg', 'VP p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PrNP ', 'VP p3msg']
#
#
# C145:16 Who: JHWH, first: K, type: Sffx, corpus class: 1933
#
# verse	type	pgn	ann		gloss	note
# 1	Sffx	p2msg	K
# 1	NP		>LWH     	god(s)
# 1	NP		MLK     	king	In apposition with "God".
# 1	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	PrNP		JHWH     	YHWH
# 3	Sffx	p3msg	W
# 4	Sffx	p2msg	K
# 4	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 5	Sffx	p2msg	K
# 6	Sffx	p2msg	K
# 6	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 7	Sffx	p2msg	K
# 8	PrNP		JHWH     	YHWH
# 9	PrNP		JHWH     	YHWH
# 9	Sffx	p3msg	W
# 9	Sffx	p3msg	W
# 10	Sffx	p2msg	K
# 10	PrNP		JHWH     	YHWH
# 10	Sffx	p2msg	K
# 10	Sffx	p2msg	K
# 10	Sffx	 	KH    		bless	!CORRUPT ANN
# 11	Sffx	p2msg	K
# 11	Sffx	p2msg	K
# 12	Sffx	p3msg	W
# 12	Sffx	p3msg	W
# 13	Sffx	p2msg	K
# 13	Sffx	p2msg	K
# 14	VP	umsg	SWMK     	support
# 14	PrNP		JHWH     	YHWH
# 14	VP	umsg	ZWQP     	raise up
# 15	Sffx	p2msg	K
# 15	PPrP	p2msg	>TH     	you
# 15	VP	umsg	NWTN     	give
# 16	VP	umsg	PWTX     	open
# 16	Sffx	p2msg	K
# 16	VP	umsg	MFBJ<     	be sated
# 17	PrNP		JHWH     	YHWH
# 17	Sffx	p3msg	W
# 17	Sffx	p3msg	W
# 18	PrNP		JHWH     	YHWH
# 18	Sffx	p3msg	W
# 18	Sffx	p3msg	HW
# 19	Sffx	p3msg	W
# 19	VP	p3msg	J<FH     	make
# 19	VP	p3msg	JCM<     	hear
# 19	VP	p3msg	JWCJ<     	help
# 20	VP	umsg	CWMR     	keep
# 20	PrNP		JHWH     	YHWH
# 20	Sffx	p3msg	W
# 20	VP	p3msg	JCMJD     	destroy
# 21	Sffx	p3msg	W
# Pattern:  ['Sfx p2msg', 'NP ', 'NP ', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PrNP ', 'Sfx p3msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p2msg', 'PrNP ', 'PrNP ', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p2msg', 'PrNP ', 'Sfx p2msg', 'Sfx p2msg', 'Sfx', 'Sfx p2msg', 'Sfx p2msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p2msg', 'Sfx p2msg', 'VP umsg', 'PrNP ', 'VP umsg', 'Sfx p2msg', 'PPrP p2msg', 'VP umsg', 'VP umsg', 'Sfx p2msg', 'VP umsg', 'PrNP ', 'Sfx p3msg', 'Sfx p3msg', 'PrNP ', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'VP p3msg', 'VP umsg', 'PrNP ', 'Sfx p3msg', 'VP p3msg', 'Sfx p3msg']
#
#
# C146:10 Who: YJWN, first: K, type: Sffx, corpus class: 1959
#
# verse	type	pgn	ann		gloss	note
# 10	Sffx	p2msg	K
# 10	PrNP		YJWN     	Zion
# Pattern:  ['Sfx p2msg', 'PrNP ']
#
#
# Results:  30
# ['C20:1',
#  'C25:5',
#  'C28:3',
#  'C30:1',
#  'C31:1',
#  'C40:8',
#  'C42:7',
#  'C45:7',
#  'C49:18',
#  'C53:8',
#  'C65:8',
#  'C71:1',
#  'C75:4',
#  'C81:11',
#  'C83:11',
#  'C84:1',
#  'C89:3',
#  'C89:36',
#  'C91:7',
#  'C92:4',
#  'C101:1',
#  'C115:2',
#  'C121:3',
#  'C122:3',
#  'C123:2',
#  'C130:1',
#  'C137:4',
#  'C138:2',
#  'C145:16',
#  'C146:10']

# %% [markdown]
# #### A Search in Psalm 107

# %%
mentions107, corefs107, suffix_errors107, reconsider_rpt107 = ParseAnnotations('Psalms', 107, 107)

# %%
GetAnnotations(corefs107, suffix_errors107)
# Out:
# C107:1 Who/what: JHWH / first: JHWH, type: PrNP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 1	T2	PrNP		JHWH     	YHWH
# 1	T3	VP	p3msg	VWB     	be good
# 1	T6	Sffx	p3msg	W
# 2	T9	VP	p3msg	G>L     	redeem
# 3	T13	VP	p3msg	QBY     	collect
# 6	T29	PrNP		JHWH     	YHWH
# 6	T34	VP	p3msg	JYJL     	deliver
# 7	T36	VP	p3msg	JDRJK     	tread
# 8	T42	PrNP		JHWH     	YHWH
# 8	T44	Sffx	p3msg	W
# 8	T46	Sffx	p3msg	W
# 9	T48	VP	p3msg	HFBJ<     	be sated
# 9	T51	VP	p3msg	ML>     	be full
# 12	T62	VP	p3msg	JKN<     	be humble
# 13	T69	PrNP		JHWH     	YHWH
# 13	T74	VP	p3msg	JWCJ<     	help
# 14	T76	VP	p3msg	JWYJ>     	go out
# 14	T82	VP	p3msg	JNTQ     	pull off
# 15	T84	PrNP		JHWH     	YHWH
# 15	T86	Sffx	p3msg	W
# 15	T88	Sffx	p3msg	W
# 16	T90	VP	p3msg	CBR     	break
# 16	T93	VP	p3msg	GD<     	cut off
# 19	T107	PrNP		JHWH     	YHWH
# 19	T112	VP	p3msg	JWCJ<     	help
# 20	T114	VP	p3msg	JCLX     	send
# 20	T116	Sffx	p3msg	W
# 20	T117	VP	p3msg	JRP>     	heal
# 20	T119	VP	p3msg	JMLV     	escape
# 21	T123	PrNP		JHWH     	YHWH
# 21	T125	Sffx	p3msg	W
# 21	T127	Sffx	p3msg	W
# 22	T133	Sffx	p3msg	W
# 24	T145	Sffx	p3msg	W
# 25	T147	VP	p3msg	J>MR     	say
# 25	T148	VP	p3msg	J<MD     	stand
# 28	T168	PrNP		JHWH     	YHWH
# 28	T173	VP	p3msg	JWYJ>     	go out
# 29	T175	VP	p3msg	JQM     	arise
# 30	T183	VP	p3msg	JNX     	lead
# 31	T188	PrNP		JHWH     	YHWH
# 31	T190	Sffx	p3msg	W
# 31	T192	Sffx	p3msg	W
# 32	T195	Sffx	p3msg	HW
# 32	T199	Sffx	p3msg	HW
# 33	T200	VP	p3msg	JFM     	put
# 35	T209	VP	p3msg	JFM     	put
# 36	T214	VP	p3msg	JWCB     	sit
# 38	T224	VP	p3msg	JBRK     	bless
# 38	T229	VP	p3msg	JM<JV     	be little
# 39	T230	VP	p3mpl	JM<VW     	be little
# 39	T231	VP	p3mpl	JCXW     	bow down
# 40	T234	VP	umsg	CPK     	pour
# 40	T237	VP	p3msg	JT<     	err
# 41	T240	VP	p3msg	JFGB     	be high
# 41	T243	VP	p3msg	JFM     	put
#
#
# C107:5 Who/what: XSD / first: XSD, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 1	T5	NP		XSD     	loyalty
# 8	T43	NP		XSD     	loyalty
# 15	T85	NP		XSD     	loyalty
# 21	T124	NP		XSD     	loyalty
# 31	T189	NP		XSD     	loyalty
#
#
# C107:2 Who/what: G>WLJ JHWH / first: J>MRW, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 2	T7	VP	p3mpl	J>MRW     	say
# 2	T8	NP		G>WLJ JHWH     	redeem	Nested mention: (redeemed of (YHWH)).
# 2	T10	Sffx	p3mpl	M
# 3	T14	Sffx	p3mpl	M
# 4	T19	VP	p3upl	T<W     	err
# 4	T23	VP	p3upl	MY>W     	find
# 5	T25	Sffx	p3mpl	M
# 5	T26	Sffx	p3mpl	HM
# 6	T28	VP	p3mpl	JY<QW     	cry
# 6	T31	Sffx	p3mpl	HM
# 6	T33	Sffx	p3mpl	HM
# 6	T35	Sffx	p3mpl	M
# 7	T37	Sffx	p3mpl	M
# 8	T41	VP	p3mpl	JWDW     	praise
#
#
# C107:4 Who/what: <JR MWCB / first: <JR MWCB, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 4	T22	NP		<JR MWCB     	town
# 7	T40	NP		<JR MWCB     	town
#
#
# C107:3 Who/what: NPC / first: NPC, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 5	T24	NP		NPC     	soul
# 5	T27	VP	p3fsg	TT<VP     	faint
#
#
# C107:8 Who/what: YR / first: YR, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 6	T30	NP		YR     	narrow
# 13	T70	NP		YR     	narrow
#
#
# C107:9 Who/what: MYWQWTJ / first: MYWQWTJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 6	T32	NP		MYWQWTJ     	stress
# 13	T72	NP		MYQWTJ     	stress
#
#
# C107:10 Who/what: NPL>WTJ / first: NPL>WTJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 8	T45	NP		NPL>WTJ     	be miraculous
# 15	T87	NP		NPL>WTJ     	be miraculous
# 21	T126	NP		NPL>WTJ     	be miraculous
# 31	T191	NP		NPL>WTJ     	be miraculous
#
#
# C107:11 Who/what: BNJ >DM / first: BNJ >DM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 8	T47	NP		BNJ >DM     	son
# 15	T89	NP		BNJ >DM     	son
# 21	T128	NP		BNJ >DM     	son
# 31	T193	NP		BNJ >DM     	son
#
#
# C107:6 Who/what: >SJRJ <NJ / first: JCBJ, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 10	T53	VP	umpl	JCBJ     	sit
# 10	T56	NP		>SJRJ <NJ     	prisoner
# 11	T58	VP	p3upl	HMRW     	rebel
# 11	T61	VP	p3upl	N>YW     	contemn
# 12	T65	Sffx	p3mpl	M
# 12	T66	VP	p3upl	KCLW     	stumble
# 13	T68	VP	p3mpl	JZ<QW     	cry
# 13	T71	Sffx	p3mpl	HM
# 13	T73	Sffx	p3mpl	HM
# 13	T75	Sffx	p3mpl	M
# 14	T77	Sffx	p3mpl	M
# 14	T81	Sffx	p3mpl	HM
# 15	T83	VP	p3mpl	JWDW     	praise
#
#
# C107:7 Who/what: >MRJ&>L / first: >MRJ&>L, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 11	T59	NP		>MRJ&>L     	word	Nested mention: (word of (God)).
# 11	T60	NP		<YT <LJWN     	counsel	Nested mention: (counsel of (the Most High)).
#
#
# C107:12 Who/what: >WLJM / first: >WLJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 17	T94	NP		>WLJM     	foolish
# 17	T96	Sffx	p3mpl	M
# 17	T98	Sffx	p3mpl	HM
# 17	T99	VP	p3mpl	JT<NW     	be lowly
# 18	T103	Sffx	p3mpl	M
# 18	T104	VP	p3mpl	JGJ<W     	touch
# 19	T106	VP	p3mpl	JZ<QW     	cry
# 19	T109	Sffx	p3mpl	HM
# 19	T111	Sffx	p3mpl	HM
# 19	T113	Sffx	p3mpl	M
# 20	T118	Sffx	p3mpl	M
# 20	T121	Sffx	p3mpl	M
# 21	T122	VP	p3mpl	JWDW     	praise
# 22	T129	VP	p3mpl	JZBXW     	slaughter
# 22	T131	VP	p3mpl	JSPRW     	count
#
#
# C107:13 Who/what: NPC / first: TT<B, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 18	T101	VP	p3fsg	TT<B     	be abhorrent
# 18	T102	NP		NPC     	soul
#
#
# C107:14 Who/what: M<FJ / first: M<FJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 22	T132	NP		M<FJ     	deed
# 24	T143	NP		M<FJ JHWH     	deed	Nested mention: (deeds of (YHWH)).
#
#
# C107:15 Who/what: JWRDJ / first: JWRDJ, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 23	T135	VP	umpl	JWRDJ     	descend
# 23	T138	VP	umpl	<FJ     	make
# 24	T141	PPrP	p3mpl	HMH     	they
# 24	T142	VP	p3upl	R>W     	see
# 26	T153	VP	p3mpl	J<LW     	ascend
# 26	T155	VP	p3mpl	JRDW     	descend
# 26	T158	Sffx	p3mpl	M
# 27	T161	VP	p3mpl	JXWGW     	jump
# 27	T162	VP	p3mpl	JNW<W     	quiver
# 27	T165	Sffx	p3mpl	M
# 28	T167	VP	p3mpl	JY<QW     	cry
# 28	T170	Sffx	p3mpl	HM
# 28	T172	Sffx	p3mpl	HM
# 28	T174	Sffx	p3mpl	M
# 30	T181	VP	p3mpl	JFMXW     	rejoice
# 30	T184	Sffx	p3mpl	M
# 30	T186	Sffx	p3mpl	M
# 31	T187	VP	p3mpl	JWDW     	praise
# 32	T194	VP	p3mpl	JRMMW     	be high
# 32	T198	VP	p3mpl	JHLLW     	praise
#
#
# C107:20 Who/what: JM / first: JM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 23	T136	NP		JM     	sea
# 25	T152	Sffx	p3msg	W    		    	To who/what refers 3Msg?
#
#
# C107:16 Who/what: RWX S<RH / first: RWX S<RH, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 25	T149	NP		RWX S<RH     	wind
# 25	T150	VP	p3fsg	TRWMM     	be high
#
#
# C107:21 Who/what: GLJ / first: GLJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 25	T151	NP		GLJ     	wave
# 29	T179	NP		GLJ     	wave
# 30	T182	VP	p3mpl	JCTQW     	be silent
#
#
# C107:17 Who/what: NPC / first: NPC, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 26	T157	NP		NPC     	soul
# 26	T160	VP	p3fsg	TTMWGG     	faint
#
#
# C107:18 Who/what: KL&XKMT / first: KL&XKMT, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 27	T164	NP		KL&XKMT     	whole
# 27	T166	VP	p3fsg	TTBL<     	confuse
#
#
# C107:19 Who/what: JXCW / first: JXCW, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 29	T178	VP	p3mpl	JXCW     	be silent
# 29	T180	Sffx	p3mpl	HM
# C107:23 Who/what: MDBR / first: MDBR, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 33	T202	NP		MDBR     	desert
# 35	T210	NP		MDBR     	desert
#
#
# C107:24 Who/what: MY>J MJM / first: MY>J MJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 33	T203	NP		MY>J MJM     	issue
# 35	T213	NP		MY>J MJM     	issue
#
#
# C107:22 Who/what: >RY PRJ / first: >RY PRJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 34	T205	NP		>RY PRJ     	earth
# 34	T208	Sffx	p3fsg	H    		    	"Earth" and "her" corefer, "earth" is often female.
#
#
# C107:25 Who/what: R<BJM / first: R<BJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 36	T215	NP		R<BJM     	hungry
# 36	T216	VP	p3mpl	JKWNNW     	be firm
# 37	T218	VP	p3mpl	JZR<W     	sow
# 37	T220	VP	p3mpl	JV<W     	plant
# 37	T222	VP	p3mpl	J<FW     	make
# 38	T225	Sffx	p3mpl	M
# 38	T226	VP	p3mpl	JRBW     	be many
# 38	T228	Sffx	p3mpl	M
#
#
# C107:26 Who/what: NDJBJM / first: NDJBJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 40	T236	NP		NDJBJM     	willing
# 40	T257	Sffx	p3mpl	M
#
#
# C107:27 Who/what: JCRJM / first: JR>W, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 42	T246	VP	p3mpl	JR>W     	see
# 42	T247	NP		JCRJM     	right
# 42	T248	VP	p3mpl	JFMXW     	rejoice
#
#
# C107:28 Who/what: KL&<WLH / first: KL&<WLH, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 42	T249	NP		KL&<WLH     	whole
# 42	T250	VP	p3fsg	QPYH     	draw together
# 42	T252	Sffx	p3fsg	H
#
#
# C107:29 Who/what: JCMR / first: JCMR, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 43	T253	VP	p3msg	JCMR     	keep
# 43	T255	VP	p3mpl	JTBWNNW     	understand
#
#
# C0 Who/what: Singletons / ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 1	T1	VP	p2mpl	HDW     	praise
# 1	T4	NP		<WLM     	eternity
# 2	T11	NP		JD&YR     	hand
# 3	T12	prep		M>RYWT     	from
# 3	T15	NP		MZRX     	sunrise
# 3	T16	NP		M<RB     	sunset
# 3	T17	NP		YPWN     	north
# 3	T18	NP		JM     	sea
# 4	T20	NP		MDBR     	desert
# 4	T21	NP		JCJMWN DRK     	wilderness
# 7	T38	NP		DRK JCRH     	way
# 9	T49	NP		NPC CQQH     	soul
# 9	T50	NP		NPC R<BH     	soul
# 9	T52	NP		VWB     	good
# 10	T54	NP		XCK     	darkness
# 10	T55	NP		YLMWT     	darkness
# 10	T57	NP		BRZL     	iron
# 12	T63	NP		<ML     	labour
# 12	T64	NP		LB     	heart
# 12	T67	NP		<ZR     	help
# 14	T78	NP		XCK     	darkness
# 14	T79	NP		YLMWT     	darkness
# 14	T80	NP		MWSRWTJ     	band
# 16	T91	NP		DLTWT NXCT     	door
# 16	T92	NP		BRJXJ BRZL     	bar
# 17	T95	NP		DRK PC<     	way
# 17	T97	NP		<WNTJ     	sin
# 18	T100	NP		KL&>KL     	whole
# 18	T105	NP		C<RJ MWT     	gate
# 19	T108	NP		YR     	narrow
# 19	T110	NP		MYQWTJ     	stress
# 20	T115	NP		DBR     	word
# 20	T120	NP		CXJTWT     	pit
# 22	T130	NP		ZBXJ TWDH     	sacrifice
# 22	T134	NP		RNH     	cry of joy
# 23	T137	NP		>NJWT     	ship
# 23	T139	NP		ML>KH     	work
# 23	T140	NP		MJM RBJM     	water
# 24	T144	NP		NPL>WTJ     	be miraculous
# 24	T146	NP		MYWLH     	depth
# 26	T154	NP		CMJM     	heavens
# 26	T156	NP		THWMWT     	primeval ocean
# 26	T159	NP		R<H     	evil
# 27	T163	NP		CKWR     	drunk
# 28	T169	NP		YR     	narrow
# 28	T171	NP		MYWQTJ     	stress
# 29	T176	NP		S<RH     	storm
# 29	T177	NP		DMMH     	calm
# 30	T185	NP		MXWZ XPY     	shipyard
# 32	T196	NP		QHL&<M     	assembly
# 32	T197	NP		MWCB ZQNJM     	seat
# 33	T201	NP		NHRWT     	stream
# 33	T204	NP		YM>WN     	thirsty ground
# 34	T206	NP		MLXH     	salt country
# 34	T207	NP		R<T JCBJ     	evil
# 35	T211	NP		>GM&MJM     	reedy pool
# 35	T212	NP		>RY YJH     	earth
# 36	T217	NP		<JR MWCB     	town
# 37	T219	NP		FDWT     	open field
# 37	T221	NP		KRMJM     	vineyard
# 37	T223	NP		PRJ TBW>H     	fruit
# 38	T227	NP		BHMT     	cattle
# 39	T232	NP		<YR R<H     	restraint
# 39	T233	NP		JGWN     	grief
# 40	T235	NP		BWZ     	contempt
# 40	T238	NP		THW     	emptiness
# 40	T239	NP		DRK     	way
# 41	T241	NP		>BJWN     	poor
# 41	T242	NP		<WNJ     	poverty
# 41	T244	NP		Y>N     	cattle
# 41	T245	NP		MCPXWT     	clan
# 42	T251	NP		PJ     	mouth
# 43	T254	DPrP		>LH     	these
# 43	T256	NP		XSDJ JHWH     	loyalty	Nested mention: (loyalties of (YHWH)).

# %% [markdown]
# #### A Search in Psalm 78

# %%
mentions78, corefs78, suffix_errors78, reconsider_rpt78 = ParseAnnotations('Psalms', 78, 78)

# %%
GetAnnotations(corefs78, suffix_errors78)
# Out:
# C78:1 Who/what: >ZJNH / first: >ZJNH, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 1	T3	VP	p2msg	>ZJNH     	listen
# 1	T4	Sffx	p1usg	J
# 1	T7	Sffx	p1usg	J
# 1	T12	Sffx	p1usg	J
# 2	T13	VP	p1usg	>PTXH     	open
# 2	T15	Sffx	p1usg	J
# 2	T17	VP	p1usg	>BJ<H     	bubble
#
#
# C78:2 Who/what: <M / first: <M, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 1	T5	NP		<M     	people
# 1	T8	VP	p2mpl	HVW     	extend
# 1	T9	Sffx	p2mpl	KM
#
#
# C78:4 Who/what: XJDWT / first: XJDWT, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 2	T18	NP		XJDWT     	riddle
# 3	T517	Sffx	p3mpl	M
#
#
# C78:3 Who/what: CM<NW / first: CM<NW, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 3	T20	VP	p1upl	CM<NW     	hear	Who is 1Cpl?
# 3	T21	VP	p1upl	ND<     	know
# 3	T23	Sffx	p1upl	NW
# 3	T25	Sffx	p1upl	NW
# 4	T26	VP	p1upl	NKXD     	hide
# 4	T30	VP	umpl	MSPRJM     	count
# 5	T45	Sffx	p1upl	NW
#
#
# C78:21 Who/what: >BWTJ / first: >BWTJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 3	T22	NP		>BWTJ     	father	Whose fathers? Seems to be one specific group: the rebellious generation.
# 3	T24	VP	p3upl	SPRW     	count
# 4	T28	Sffx	p3mpl	HM
# 5	T44	NP		>BWTJ     	father
# 5	T46	VP	uuu	HWDJ<M     	know	Infc with PreS.
# 5	T47	Sffx	p3mpl	HM
# 8	T67	NP		>BWT     	father	Whose fathers? Seems to be one specific group: the rebellious generation.
# 12	T95	NP		>BWT     	father	Whose fathers? Seems to be one specific group: the rebellious generation.
# 13	T103	Sffx	p3mpl	M
# 14	T108	Sffx	p3mpl	M
# 17	T124	VP	p3mpl	JWSJPW     	add
# 18	T130	VP	p3mpl	JNSW     	try
# 18	T132	Sffx	p3mpl	M
# 18	T136	Sffx	p3mpl	M
# 19	T138	VP	p3mpl	JDBRW     	speak
# 19	T140	VP	p3upl	>MRW     	say
# 24	T179	Sffx	p3mpl	HM
# 24	T184	Sffx	p3mpl	MW
# 25	T190	Sffx	p3mpl	HM
# 27	T200	Sffx	p3mpl	HM
# 29	T210	VP	p3mpl	J>KLW     	eat
# 29	T211	VP	p3mpl	JFB<W     	be sated
# 29	T212	Sffx	p3mpl	M
# 29	T215	Sffx	p3mpl	HM
# 30	T216	VP	p3upl	ZRW     	turn aside
# 30	T218	Sffx	p3mpl	M
# 30	T220	Sffx	p3mpl	M
# 30	T221	Sffx	p3mpl	HM
# 31	T225	Sffx	p3mpl	HM
# 31	T227	Sffx	p3mpl	HM
# 32	T232	VP	p3upl	XV>W     	miss
# 32	T233	VP	p3upl	H>MJNW     	be firm
# 33	T238	Sffx	p3mpl	M
# 33	T240	Sffx	p3mpl	M
# 34	T242	Sffx	p3mpl	M
# 34	T245	VP	p3upl	DRCW     	inquire
# 34	T246	VP	p3upl	CBW     	return
# 34	T247	VP	p3upl	CXRW     	look for
# 35	T248	VP	p3mpl	JZKRW     	remember
# 35	T250	Sffx	p3mpl	M
# 35	T253	Sffx	p3mpl	M
# 36	T256	VP	p3mpl	JPTW     	seduce
# 36	T257	Sffx	p3mpl	HM
# 36	T259	Sffx	p3mpl	M
# 36	T262	VP	p3mpl	JKZBW     	lie
# 37	T263	Sffx	p3mpl	M
# 37	T267	VP	p3upl	N>MNW     	be firm
# 39	T283	PPrP	p3mpl	HMH     	they
# 40	T288	VP	p3mpl	JMRW     	rebel
# 40	T290	VP	p3mpl	J<YJBW     	hurt
# 41	T293	VP	p3mpl	JCWBW     	return
# 41	T294	VP	p3mpl	JNSW     	try
# 41	T297	VP	p3upl	HTWW     	hurt
# 42	T298	VP	p3upl	ZKRW     	remember
# 42	T302	Sffx	p3mpl	M
# 57	T414	NP		>BWT     	father	Whose ancestors are they? The rebellious ones from v.8 and 12?
#
#
# C78:5 Who/what: BNJ / first: BNJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 4	T27	NP		BNJ     	son
# 5	T48	NP		BNJ     	son
#
#
# C78:6 Who/what: DWR >XRWN / first: DWR >XRWN, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 4	T29	NP		DWR >XRWN     	generation
# 6	T49	VP	p3mpl	JD<W     	know
# 6	T50	NP		DWR >XRWN     	generation
#
#
# C78:43 Who/what: JHWH / first: THLWT JHWH, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 4	T31	NP		THLWT JHWH     	praise	Nested mention: (praises of (YHWH)).
# 4	T32	Sffx	p3msg	W
# 4	T34	Sffx	p3msg	W
# 4	T36	VP	p3msg	<FH     	make
# 5	T37	VP	p3msg	JQM     	arise
# 5	T41	VP	p3msg	FM     	put
# 5	T43	VP	p3msg	YWH     	command
# 7	T58	NP		>LHJM     	god(s)
# 7	T63	Sffx	p3msg	W
# 8	T75	NP		>L     	god
# 10	T83	NP		BRJT >LHJM     	covenant	Nested mention: (covenant of (God)).
# 10	T85	Sffx	p3msg	W
# 11	T90	Sffx	p3msg	W
# 11	T92	Sffx	p3msg	W
# 11	T94	VP	p3msg	HR>     	see
# 12	T97	VP	p3msg	<FH     	make
# 13	T101	VP	p3msg	BQ<     	split
# 13	T104	VP	p3msg	J<BJR     	pass
# 13	T105	VP	p3msg	JYB     	stand
# 14	T109	VP	p3msg	JNX     	lead
# 15	T114	VP	p3msg	JBQ<     	split
# 15	T117	VP	p3msg	JCQ     	give drink
# 16	T119	VP	p3msg	JWY>     	go out
# 17	T126	Sffx	p3msg	W
# 17	T128	NP		<LJWN     	upper
# 18	T131	NP		>L     	god
# 19	T139	NP		>LHJM     	god(s)
# 19	T141	VP	p3msg	JWKL     	be able
# 19	T142	NP		>L     	god
# 20	T146	VP	p3msg	HKH     	strike
# 20	T153	VP	p3msg	JWKL     	be able
# 20	T155	VP	p3msg	JKJN     	be firm
# 20	T157	Sffx	p3msg	W
# 21	T159	VP	p3msg	CM<     	hear
# 21	T160	PrNP		JHWH     	YHWH
# 21	T161	VP	p3msg	JT<BR     	be angry
# 22	T169	NP		>LHJM     	god(s)
# 22	T171	Sffx	p3msg	W
# 23	T173	VP	p3msg	JYW     	command
# 23	T177	VP	p3msg	PTX     	open
# 24	T178	VP	p3msg	JMVR     	rain
# 24	T183	VP	p3msg	NTN     	give
# 25	T189	VP	p3msg	CLX     	send
# 26	T192	VP	p3msg	JS<     	pull out
# 26	T195	VP	p3msg	JNHG     	drive
# 26	T197	Sffx	p3msg	W
# 27	T199	VP	p3msg	JMVR     	rain
# 28	T205	VP	p3msg	JPL     	fall
# 28	T207	Sffx	p3msg	W    		    	Refers to God or the people?
# 28	T209	Sffx	p3msg	W    		    	Refers to God or the people?
# 29	T214	VP	p3msg	JB>     	come
# 31	T223	NP		>P >LHJM     	nose	Nested mention: (anger of (God)).
# 31	T224	VP	p3msg	<LH     	ascend
# 31	T226	VP	p3msg	JHRG     	kill
# 31	T230	VP	p3msg	HKRJ<     	kneel
# 32	T234	Sffx	p3msg	W
# 33	T236	VP	p3msg	JKL     	be complete
# 34	T243	VP	p3msg	HRG     	kill
# 34	T244	Sffx	p3msg	HW
# 34	T241	NP		>L     	god
# 35	T249	NP		>LHJM     	god(s)
# 35	T251	NP		YWR     	rock
# 35	T252	NP		>L <LJWN     	god
# 35	T254	NP		G>L     	redeem
# 36	T255	Sffx	p3msg	HW
# 36	T261	Sffx	p3msg	W
# 37	T266	Sffx	p3msg	W
# 37	T268	Sffx	p3msg	W
# 38	T270	PPrP	p3msg	HW>     	he
# 38	T271	VP	p3msg	JKPR     	cover
# 38	T273	VP	p3msg	JCXJT     	destroy
# 38	T274	VP	p3msg	HRBH     	be many
# 38	T276	Sffx	p3msg	W
# 38	T278	VP	p3msg	J<JR     	be awake
# 38	T280	Sffx	p3msg	W
# 39	T281	VP	p3msg	JZKR     	remember
# 40	T287	Sffx	p3msg	HW
# 40	T291	Sffx	p3msg	HW
# 41	T295	NP		>L     	god
# 41	T296	NP		QDWC JFR>L     	holy	Nested mention: (holy one of (Israel)).
# 42	T299	Sffx	p3msg	W
# 42	T303	VP	p3msg	PD     	buy off
# 43	T305	VP	p3msg	FM     	put
# 43	T307	Sffx	p3msg	W
# 43	T309	Sffx	p3msg	W
# 44	T312	VP	p3msg	JHPK     	turn
# 45	T319	VP	p3msg	JCLX     	send
# 46	T326	VP	p3msg	JTN     	give
# 47	T333	VP	p3msg	JHRG     	kill
# 48	T340	VP	p3msg	JSGR     	close
# 49	T347	VP	p3msg	JCLX     	send
# 49	T350	Sffx	p3msg	W
# 50	T355	VP	p3msg	JPLS     	level
# 50	T357	Sffx	p3msg	W
# 50	T359	VP	p3msg	XFK     	withhold
# 50	T520	VP	p3msg	HSGJR     	close
# 51	T365	VP	p3msg	JK     	strike
# 52	T370	VP	p3msg	JS<     	pull out
# 52	T372	Sffx	p3msg	W
# 52	T375	VP	p3msg	JNHG     	drive
# 53	T379	VP	p3msg	JNX     	lead
# 54	T387	VP	p3msg	JBJ>     	come
# 54	T389	Sffx	p3msg	W
# 54	T392	Sffx	p3msg	W
# 55	T394	VP	p3msg	JGRC     	drive out
# 55	T399	VP	p3msg	JPJL     	fall
# 55	T401	VP	p3msg	JCKN     	dwell
# 56	T407	NP		>LHJM     	god(s)
# 56	T408	NP		<LJWN     	upper	In apposition with "God".
# 56	T409	Sffx	p3msg	W
# 58	T418	Sffx	p3msg	HW
# 58	T424	Sffx	p3msg	HW
# 59	T426	VP	p3msg	CM<     	hear
# 59	T427	NP		>LHJM     	god(s)
# 59	T428	VP	p3msg	JT<BR     	be angry
# 59	T429	VP	p3msg	JM>S     	retract
# 60	T431	VP	p3msg	JVC     	abandon
# 60	T434	VP	p3msg	CKN     	dwell
# 61	T436	VP	p3msg	JTN     	give
# 61	T438	Sffx	p3msg	W
# 61	T440	Sffx	p3msg	W
# 62	T443	VP	p3msg	JSGR     	close
# 62	T445	Sffx	p3msg	W
# 62	T447	Sffx	p3msg	W
# 62	T449	VP	p3msg	HT<BR     	be angry
# 65	T464	VP	p3msg	JQY     	awake
# 65	T466	PrNP		>DNJ     	Lord
# 66	T470	VP	p3msg	JK     	strike
# 66	T471	Sffx	p3msg	W
# 66	T474	VP	p3msg	NTN     	give
# 67	T476	VP	p3msg	JM>S     	retract
# 67	T479	VP	p3msg	BXR     	examine
# 68	T480	VP	p3msg	JBXR     	examine
# 68	T483	VP	p3msg	>HB     	love
# 69	T485	VP	p3msg	JBN     	build
# 69	T487	Sffx	p3msg	W
# 69	T490	VP	p3msg	JSD     	found
# 70	T492	VP	p3msg	JBXR     	examine
# 70	T495	Sffx	p3msg	W
# 70	T497	VP	p3msg	JQX     	take
# 71	T501	VP	p3msg	HBJ>     	come
# 71	T504	Sffx	p3msg	W
# 71	T507	Sffx	p3msg	W
#
#
# C78:13 Who/what: NPL>WTJ / first: NPL>WTJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 4	T35	NP		NPL>WTJ     	be miraculous
# 11	T91	NP		NPL>WTJ     	be miraculous
# 32	T235	NP		NPL>WTJ     	be miraculous
#
#
# C78:49 Who/what: J<QB / first: J<QB, type: PrNP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 5	T39	PrNP		J<QB     	Jacob
# 5	T42	PrNP		JFR>L     	Israel
# 21	T164	PrNP		J<QB     	Jacob
# 21	T167	PrNP		JFR>L     	Israel
# 22	T168	VP	p3upl	H>MJNW     	be firm
# 22	T170	VP	p3upl	BVXW     	trust
# 71	T503	PrNP		J<QB     	Jacob
# 71	T505	NP		<M     	people	In apposition with "Jacob".
# 71	T506	PrNP		JFR>L     	Israel
# 71	T508	NP		NXLT     	heritage	In apposition with "Israel".
# 72	T510	Sffx	p3mpl	M
# 72	T515	Sffx	p3mpl	M
#
#
# C78:12 Who/what: TWRH / first: TWRH, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 5	T40	NP		TWRH     	instruction
# 10	T84	NP		TWRT     	instruction
#
#
# C78:7 Who/what: BNJM / first: BNJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 6	T51	NP		BNJM     	son
# 6	T52	VP	p3mpl	JWLDW     	bear
# 6	T53	VP	p3mpl	JQMW     	arise
# 6	T54	VP	p3mpl	JSPRW     	count
# 6	T55	Sffx	p3mpl	HM
#
#
# C78:8 Who/what: BNJ / first: BNJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 6	T56	NP		BNJ     	son
# 7	T57	VP	p3mpl	JFJMW     	put
# 7	T59	Sffx	p3mpl	M
# 7	T61	VP	p3mpl	JCKXW     	forget
# 7	T65	VP	p3mpl	JNYRW     	watch
# 8	T66	VP	p3mpl	JHJW     	be
# 8	T68	Sffx	p3mpl	M
#
#
# C78:9 Who/what: DWR SWRR WMRH DWR / first: DWR SWRR WMRH DWR, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 8	T69	NP		DWR SWRR WMRH DWR     	generation	Seems to be one very stubborn generation, therefore one mention.
# 8	T71	VP	p3msg	HKJN     	be firm
# 8	T73	Sffx	p3msg	W
# 8	T76	Sffx	p3msg	W
#
#
# C78:10 Who/what: RWX / first: N>MNH, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 8	T74	VP	p3fsg	N>MNH     	be firm
# 8	T77	NP		RWX     	wind
#
#
# C78:11 Who/what: BNJ&>PRJM / first: BNJ&>PRJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 9	T78	NP		BNJ&>PRJM     	son	Does this refer to the rebellious generation in v.8? Nested mention: (sons of (Ephraim)).
# 9	T80	VP	p3upl	HPKW     	turn
# 10	T82	VP	p3upl	CMRW     	keep
# 10	T86	VP	p3upl	M>NW     	refuse
# 11	T88	VP	p3mpl	JCKXW     	forget
# 11	T93	Sffx	p3mpl	M
# 12	T96	Sffx	p3mpl	M
#
#
# C78:26 Who/what: MYRJM / first: >RY MYRJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 12	T99	NP		>RY MYRJM     	earth	Nested mention: (land of (Egypt)).
# 43	T306	PrNP		MYRJM     	Egypt
# 44	T314	Sffx	p3mpl	HM
# 44	T316	Sffx	p3mpl	HM
# 44	T318	VP	p3mpl	JCTJWN     	drink
# 45	T320	Sffx	p3mpl	HM
# 45	T518	Sffx	p3mpl	M
# 45	T324	Sffx	p3mpl	M
# 46	T328	Sffx	p3mpl	M
# 46	T330	Sffx	p3mpl	M
# 47	T335	Sffx	p3mpl	M
# 47	T338	Sffx	p3mpl	M
# 48	T342	Sffx	p3mpl	M
# 48	T344	Sffx	p3mpl	HM
# 49	T348	Sffx	p3mpl	M
# 50	T361	Sffx	p3mpl	M
# 50	T364	Sffx	p3mpl	M
# 51	T367	PrNP		MYRJM     	Egypt
#
#
# C78:27 Who/what: FDH&Y<N / first: FDH&Y<N, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 12	T100	NP		FDH&Y<N     	open field	Nested mention: (open field of (Zoan)).
# 43	T311	NP		FDH&Y<N     	open field	Nested mention: (open field of (Zoan)).
#
#
# C78:14 Who/what: MDBR / first: MDBR, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 15	T116	NP		MDBR     	desert
# 19	T145	NP		MDBR     	desert
# 40	T289	NP		MDBR     	desert
# 52	T377	NP		MDBR     	desert
#
#
# C78:23 Who/what: LBB / first: LBB, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 18	T133	NP		LBB     	heart
# 37	T264	NP		LB     	heart
# 37	T265	VP	p3msg	NKWN     	be firm
#
#
# C78:15 Who/what: MJM / first: JZWBW, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 20	T148	VP	p3mpl	JZWBW     	flow
# 20	T149	NP		MJM     	water
#
#
# C78:16 Who/what: NXLJM / first: NXLJM, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 20	T150	NP		NXLJM     	wadi
# 20	T151	VP	p3mpl	JCVPW     	wash off
#
#
# C78:31 Who/what: <M / first: <M, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 20	T158	NP		<M     	people
# 52	T373	NP		<M     	people
# 52	T374	Sffx	p3mpl	M
# 53	T378	Sffx	p3mpl	M
# 53	T381	VP	p3upl	PXDW     	tremble
# 53	T382	Sffx	p3mpl	HM
# 54	T386	Sffx	p3mpl	M
# 55	T395	Sffx	p3mpl	HM
# 55	T398	Sffx	p3mpl	M
# 55	T402	Sffx	p3mpl	HM
#
#
# C78:17 Who/what: >C / first: >C, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 21	T162	NP		>C     	fire
# 21	T163	VP	p3fsg	NFQH     	kindle
#
#
# C78:18 Who/what: >P / first: >P, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 21	T165	NP		>P     	nose
# 21	T166	VP	p3msg	<LH     	ascend
#
#
# C78:19 Who/what: >JC / first: >KL, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 25	T186	VP	p3msg	>KL     	eat
# 25	T187	NP		>JC     	man
#
#
# C78:37 Who/what: <Z / first: <Z, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 26	T196	NP		<Z     	power
# 61	T439	NP		<Z     	power
#
#
# C78:20 Who/what: T>WT / first: T>WT, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 29	T213	NP		T>WT     	desire
# 30	T217	NP		T>WT     	desire
#
#
# C78:22 Who/what: PJ / first: PJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 30	T222	NP		PJ     	mouth
# 36	T258	NP		PJ     	mouth
#
#
# C78:24 Who/what: >P / first: >P, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 38	T277	NP		>P     	nose
# 50	T358	NP		>P     	nose
#
#
# C78:25 Who/what: RWX / first: RWX, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 39	T284	NP		RWX     	wind
# 39	T285	VP	umsg	HWLK     	walk
# 39	T286	VP	p3msg	JCWB     	return
#
#
# C78:28 Who/what: <RB / first: <RB, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 45	T321	NP		<RB     	swarm
# 45	T322	VP	p3msg	J>KL     	eat
#
#
# C78:29 Who/what: YPRD< / first: YPRD<, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 45	T323	NP		YPRD<     	frog
# 45	T325	VP	p3fsg	TCXJT     	destroy
#
#
# C78:30 Who/what: BRD / first: BRD, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 47	T334	NP		BRD     	hail
# 48	T341	NP		BRD     	hail
#
#
# C78:32 Who/what: JM / first: KSH, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 53	T384	VP	p3msg	KSH     	cover
# 53	T385	NP		JM     	sea
#
#
# C78:33 Who/what: GBWL QDC / first: GBWL QDC, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 54	T388	NP		GBWL QDC     	boundary
# 54	T390	NP		HR&ZH     	mountain	In apposition with "the boundary of his holy land".
#
#
# C78:34 Who/what: JMJN / first: QNTH, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 54	T391	VP	p3fsg	QNTH     	buy
# 54	T393	NP		JMJN     	right-hand side
#
#
# C78:35 Who/what: JFR>L / first: CBVJ JFR>L, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 55	T404	NP		CBVJ JFR>L     	rod	Nested mention: (tribes of (Israel)). Does not seem to be the same generation as in v.21.
# 56	T405	VP	p3mpl	JNSW     	try
# 56	T406	VP	p3mpl	JMRW     	rebel
# 56	T411	VP	p3upl	CMRW     	keep
# 57	T412	VP	p3mpl	JSGW     	turn
# 57	T413	VP	p3mpl	JBGDW     	deal treacherously
# 57	T415	Sffx	p3mpl	M
# 57	T416	VP	p3upl	NHPKW     	turn
# 58	T419	VP	p3mpl	JK<JSW     	be discontent
# 58	T420	Sffx	p3mpl	M
# 58	T423	Sffx	p3mpl	HM
# 58	T425	VP	p3mpl	JQNJ>W     	be jealous
# 59	T430	PrNP		JFR>L     	Israel
# 62	T446	NP		<M     	people
# 62	T448	NP		NXLT     	heritage
# 63	T450	Sffx	p3msg	W
# 63	T454	Sffx	p3msg	W
# 64	T457	Sffx	p3msg	W
# 64	T461	Sffx	p3msg	W
#
#
# C78:36 Who/what: MCKN CLW / first: MCKN CLW, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 60	T432	NP		MCKN CLW     	dwelling-place	Nested mention: (dwelling place of (Shiloh)).
# 60	T433	NP		>HL     	tent
#
#
# C78:40 Who/what: XRB / first: XRB, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 62	T444	NP		XRB     	dagger
# 64	T459	NP		XRB     	dagger
#
#
# C78:38 Who/what: >C / first: >KLH, type: VP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 63	T452	VP	p3fsg	>KLH     	eat
# 63	T453	NP		>C     	fire
#
#
# C78:39 Who/what: BTWLTJ / first: BTWLTJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 63	T455	NP		BTWLTJ     	virgin
# 63	T456	VP	p3upl	HWLLW     	praise
#
#
# C78:41 Who/what: KHNJ / first: KHNJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 64	T458	NP		KHNJ     	priest
# 64	T460	VP	p3upl	NPLW     	fall
#
#
# C78:42 Who/what: >LMNTJ / first: >LMNTJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 64	T462	NP		>LMNTJ     	widow
# 64	T463	VP	p3fpl	TBKJNH     	weep
#
#
# C78:44 Who/what: GBWR / first: GBWR, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 65	T467	NP		GBWR     	vigorous
# 65	T468	VP	umsg	MTRWNN     	be sober
#
#
# C78:45 Who/what: YRJ / first: YRJ, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 66	T472	NP		YRJ     	adversary
# 66	T475	Sffx	p3mpl	MW
#
#
# C78:46 Who/what: CBV JHWDH / first: CBV JHWDH, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 68	T481	NP		CBV JHWDH     	rod	Nested mention: (tribe of (Judah)).
# 68	T482	NP		HR YJWN     	mountain	In apposition with "tribe of Judah".
#
#
# C78:47 Who/what: >RY / first: >RY, type: NP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 69	T489	NP		>RY     	earth
# 69	T521	Sffx	p3fsg	H
#
#
# C78:48 Who/what: DWD / first: DWD, type: PrNP
# ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 70	T493	PrNP		DWD     	David
# 70	T494	NP		<BD     	servant	In apposition with "David".
# 70	T496	Sffx	p3msg	HW
# 71	T500	Sffx	p3msg	W
# 72	T509	VP	p3msg	JR<     	pasture
# 72	T512	Sffx	p3msg	W
# 72	T514	Sffx	p3msg	W
# 72	T516	VP	p3msg	JNX     	lead
#
#
# C0 Who/what: Singletons / ----------------------------------------------------------------------
# verse	id	type	pgn	ann		gloss	note
#
# 1	T1	NP		MFKJL     	<uncertain>
# 1	T2	PrNP		>SP     	Asaph
# 1	T6	NP		TWRT     	instruction
# 1	T10	NP		>ZN     	ear
# 1	T11	NP		>MRJ&P     	word
# 2	T14	NP		MCL     	proverb
# 2	T16	NP		P     	mouth
# 2	T19	NP		QDM     	front
# 4	T33	NP		<ZWZ     	power
# 5	T38	NP		<DWT     	reminder
# 7	T60	NP		KSL     	imperturbability
# 7	T62	NP		<LLJ&>L     	deed	Nested mention: (deeds of (God)).
# 7	T64	NP		MYWTJ     	commandment
# 8	T72	NP		LB     	heart
# 9	T79	NP		NWCQJ RWMJ&QCT     	be equipped
# 9	T81	NP		JWM QRB     	day
# 11	T89	NP		<LJLWTJ     	deed
# 12	T98	NP		PL>     	miracle
# 13	T102	NP		JM     	sea
# 13	T106	NP		MJM     	water
# 13	T107	NP		ND     	barrier
# 14	T110	NP		<NN     	cloud
# 14	T111	AdvP		JWMM     	by day
# 14	T112	NP		KL&HLJLH     	whole
# 14	T113	NP		>WR >C     	light
# 15	T115	NP		YRJM     	rock
# 15	T118	NP		THMWT     	primeval ocean
# 16	T120	NP		NWZLJM     	flow
# 16	T121	NP		SL<     	rock
# 16	T122	VP	p3msg	JWRD     	descend
# 16	T70	NP		NHRWT     	stream
# 16	T123	NP		MJM     	water
# 17	T129	NP		YJH     	dry country
# 18	T135	NP		>KL     	food
# 18	T137	NP		NPC     	soul
# 19	T144	NP		CLXN     	table
# 20	T147	NP		YWR     	rock
# 20	T152	NP		LXM     	bread
# 20	T156	NP		C>R     	body
# 22	T172	NP		JCW<T     	salvation
# 23	T174	NP		CXQJM     	dust
# 23	T175	NP		M<L     	top
# 23	T176	NP		DLTJ CMJM     	door
# 24	T180	NP		MN     	manna
# 24	T182	NP		DGN&CMJM     	corn
# 25	T185	NP		LXM >BJRJM     	bread
# 25	T188	NP		YJDH     	provision
# 25	T191	NP		FB<     	satiety
# 26	T193	NP		QDJM     	east
# 26	T194	NP		CMJM     	heavens
# 26	T198	NP		TJMN     	south
# 27	T201	NP		<PR     	dust
# 27	T202	NP		C>R     	body
# 27	T203	NP		XWL JMJM     	sand
# 27	T204	NP		<WP KNP     	birds
# 28	T206	NP		QRB MXNH     	interior
# 28	T208	NP		MCKNTJ     	dwelling-place
# 30	T219	NP		>KL     	food
# 31	T228	NP		MCMNJ     	fatness
# 31	T229	NP		BXWRJ JFR>L     	young man	Nested mention: (young men of (Israel)).
# 32	T231	NP		KL&Z>T     	whole
# 33	T239	NP		JMJH     	day
# 33	T237	NP		CNWT     	year
# 36	T260	NP		LCWN     	tongue
# 37	T269	NP		BRJT     	covenant	See "God's covenant" in v.10.
# 38	T272	NP		<WN     	sin
# 38	T279	NP		KL&XMT     	whole
# 39	T282	NP		BFR     	flesh
# 40	T292	NP		JCJMWN     	wilderness
# 42	T300	NP		JD     	hand
# 42	T301	NP		JWM     	day
# 42	T304	NP		YR     	adversary
# 43	T308	NP		>TWTJ     	sign
# 43	T310	NP		MWPTJ     	sign
# 44	T313	NP		DM     	blood
# 44	T315	NP		J>RJ     	stream
# 44	T317	NP		NZLJ     	flow
# 46	T327	NP		XSJL     	cockroach
# 46	T329	NP		JBWL     	produce
# 46	T331	NP		JGJ<     	toil
# 46	T332	NP		>RBH     	locust
# 47	T336	NP		GPN     	vine
# 47	T337	NP		CQMWT     	sycamore
# 47	T339	NP		XNML     	flood
# 48	T343	NP		B<JR     	cattle
# 48	T345	NP		MQNJ     	purchase
# 48	T346	NP		RCPJM     	flame
# 49	T349	NP		XRWN >P     	anger
# 49	T351	NP		<BRH     	anger
# 49	T352	NP		Z<M     	curse
# 49	T353	NP		YRH     	distress
# 49	T354	NP		MCLXT ML>KJ R<JM     	discharge
# 50	T356	NP		NTJB     	path
# 50	T360	NP		MWT     	death
# 50	T362	NP		NPC     	soul
# 50	T363	NP		XJT     	life
# 50	T519	NP		DBR     	pest
# 51	T366	NP		KL&BKWR     	whole
# 51	T368	NP		>CJT >WNJM     	beginning
# 51	T369	NP		>HLJ&XM     	tent	Nested mention: (tents of (Ham)).
# 52	T371	NP		Y>N     	cattle
# 52	T376	NP		<DR     	flock
# 53	T380	NP		BVX     	trust
# 53	T383	NP		>WJBJ     	be hostile
# 55	T396	NP		PNJ     	face
# 55	T397	NP		GWJM     	people
# 55	T400	NP		XBL NXLH     	cord
# 55	T403	NP		>HLJ     	tent
# 56	T410	NP		<DWTJ     	reminder
# 57	T417	NP		QCT RMJH     	bow
# 58	T421	NP		BMWT     	high place
# 58	T422	NP		PSJLJ     	idol
# 60	T435	NP		>DM     	human, mankind
# 61	T437	NP		CBJ     	captive
# 61	T441	NP		TP>RT     	splendour
# 61	T442	NP		JD&YR     	hand
# 63	T451	NP		XWRJ     	young man
# 65	T465	NP		JCN     	sleeping
# 65	T469	NP		JJN     	wine
# 66	T473	NP		XRPT <WLM     	reproach
# 67	T477	NP		>HL JWSP     	tent	Nested mention: (tent of (Joseph)).
# 67	T478	prep		BCBV >PRJM     	in	Nested mention: (tribe of (Ephraim)).
# 68	T484	CP		>CR     	<relative>	Relativum refers to Judah: "which he [God] loves".
# 69	T486	NP		RMJM     	be high
# 69	T488	NP		MQDC     	sanctuary
# 69	T491	NP		<WLM     	eternity
# 70	T498	NP		MKL>T Y>N     	enclosure
# 71	T499	NP		<LWT     	nurse
# 72	T511	NP		TM LBB     	completeness
# 72	T513	NP		TBWNWT KPJ     	understanding

# %% [markdown]
# #### Verb mention '>MRTJ'

# %%
FindMention(corefs, suffix_errors, '>MRTJ')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 30:7	C30:2	VP	p1usg	>MRTJ		say
# 31:15	C31:6	VP	p1usg	>MRTJ		say
# 31:23	C31:6	VP	p1usg	>MRTJ		say
# 32:5	C32:3	VP	p1usg	>MRTJ		say
# 38:17	C38:1	VP	p1usg	>MRTJ		say
# 39:2	C39:1	VP	p1usg	>MRTJ		say
# 40:8	C40:11	VP	p1usg	>MRTJ		say
# 40:11	C40:11	VP	p1usg	>MRTJ		say
# 41:5	C41:7	VP	p1usg	>MRTJ		say
# 73:15	C73:17	VP	p1usg	>MRTJ		say
# 75:5	C75:4	VP	p1usg	>MRTJ		say
# 82:6	C82:4	VP	p1usg	>MRTJ		say
# 89:3	C89:1	VP	p1usg	>MRTJ		say
# 94:18	C94:11	VP	p1usg	>MRTJ		say
# 116:11	C116:8	VP	p1usg	>MRTJ		say
# 119:57	C119:54	VP	p1usg	>MRTJ		say
# 140:7	C140:1	VP	p1usg	>MRTJ		say
# 142:6	C142:2	VP	p1usg	>MRTJ		say
#
#
# Results:  18
# ['C30:2',
#  'C31:6',
#  'C31:6',
#  'C32:3',
#  'C38:1',
#  'C39:1',
#  'C40:11',
#  'C40:11',
#  'C41:7',
#  'C73:17',
#  'C75:4',
#  'C82:4',
#  'C89:1',
#  'C94:11',
#  'C116:8',
#  'C119:54',
#  'C140:1',
#  'C142:2']

# %%
#FindFirst(corefs, suffix_errors, 'Sffx', ['K']) # 'PPrP', >NJ'
FindWho(corefs, suffix_errors, ['>MRTJ'])
# Out:
# C39:1 Who: >MRTJ, first: >MRTJ, type: VP, corpus class: 488
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	>MRTJ     	say
# 2	VP	p1usg	>CMRH     	keep
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 2	VP	p1usg	>CMRH     	keep
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 3	VP	p1usg	N>LMTJ     	bind
# 3	VP	p1usg	HXCJTJ     	be silent
# 3	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	VP	p1usg	DBRTJ     	speak
# 4	Sffx	p1usg	J
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 5	VP	p1usg	>D<H     	know
# 5	PPrP	p1usg	>NJ     	i
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 8	VP	p1usg	QWJTJ     	wait for
# 8	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 9	Sffx	p1usg	NJ
# 9	Sffx	p1usg	NJ
# 10	VP	p1usg	N>LMTJ     	bind
# 10	VP	p1usg	>PTX     	open
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	PPrP	p1usg	>NJ     	i
# 11	VP	p1usg	KLJTJ     	be complete
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	PPrP	p1usg	>NKJ     	i
# 13	Sffx	p1usg	J
# 14	Sffx	p1usg	NJ
# 14	VP	p1usg	>BLJGH     	gleam
# 14	VP	p1usg	>LK     	walk
# 14	Sffx	p1usg	NJ
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg']
#
#
# C41:7 Who: >MRTJ, first: >NJ, type: PPrP, corpus class: 520
#
# verse	type	pgn	ann		gloss	note
# 5	PPrP	p1usg	>NJ     	i	Who is 1Csg?
# 5	VP	p1usg	>MRTJ     	say
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 5	VP	p1usg	XV>TJ     	miss
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 6	VP	p3msg	JMWT     	die
# 6	Sffx	p3msg	W
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 9	Sffx	p3msg	W
# 9	VP	p3msg	CKB     	lie down
# 9	VP	p3msg	JWSJP     	add
# 10	Sffx	p1usg	J
# 10	VP	p1usg	BVXTJ     	trust
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	NJ
# 11	Sffx	p1usg	NJ
# 11	VP	p1usg	>CLMH     	be complete
# 12	VP	p1usg	JD<TJ     	know
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 13	PPrP	p1usg	>NJ     	i
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	NJ
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p3msg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C94:11 Who: >MRTJ, first: J, type: Sffx, corpus class: 1276
#
# verse	type	pgn	ann		gloss	note
# 16	Sffx	p1usg	J    		    	Who is 1Csg?
# 16	Sffx	p1usg	J
# 17	Sffx	p1usg	J
# 17	Sffx	p1usg	J
# 18	VP	p1usg	>MRTJ     	say
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	NJ
# 19	Sffx	p1usg	J
# 19	Sffx	p1usg	J
# 19	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C140:1 Who: >MRTJ, first: NJ, type: Sffx, corpus class: 1870
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p1usg	NJ
# 2	Sffx	p1usg	NJ
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 7	VP	p1usg	>MRTJ     	say
# 7	Sffx	p1usg	J
# 7	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 13	VP	p1usg	JD<T     	know
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# Results:  4
# ['C39:1', 'C41:7', 'C94:11', 'C140:1']

# %%
FindFirst(corefs, suffix_errors, 'VP', ['>MRTJ']) # 'PPrP', >NJ'
# Out:
# C39:1 Who: >MRTJ, first: >MRTJ, type: VP, corpus class: 487
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	>MRTJ     	say
# 2	VP	p1usg	>CMRH     	keep
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 2	VP	p1usg	>CMRH     	keep
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 3	VP	p1usg	N>LMTJ     	bind
# 3	VP	p1usg	HXCJTJ     	be silent
# 3	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	VP	p1usg	DBRTJ     	speak
# 4	Sffx	p1usg	J
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 5	VP	p1usg	>D<H     	know
# 5	PPrP	p1usg	>NJ     	i
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 8	VP	p1usg	QWJTJ     	wait for
# 8	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 9	Sffx	p1usg	NJ
# 9	Sffx	p1usg	NJ
# 10	VP	p1usg	N>LMTJ     	bind
# 10	VP	p1usg	>PTX     	open
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	PPrP	p1usg	>NJ     	i
# 11	VP	p1usg	KLJTJ     	be complete
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	PPrP	p1usg	>NKJ     	i
# 13	Sffx	p1usg	J
# 14	Sffx	p1usg	NJ
# 14	VP	p1usg	>BLJGH     	gleam
# 14	VP	p1usg	>LK     	walk
# 14	Sffx	p1usg	NJ
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg']
#
#
# C116:8 Who: <BD, first: >MRTJ, type: VP, corpus class: 1600
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p1usg	>MRTJ     	say
# 11	VP	uuu	XPZJ     	hurry	Infc with PreS.
# 12	VP	p1usg	>CJB     	return
# 12	Sffx	p1usg	J
# 13	VP	p1usg	>F>     	lift
# 13	VP	p1usg	>QR>     	call
# 14	Sffx	p1usg	J
# 14	VP	p1usg	>CLM     	be complete
# 16	PPrP	p1usg	>NJ     	i
# 16	NP		<BD     	servant
# 16	PPrP	p1usg	>NJ     	i
# 16	NP		<BD     	servant
# 16	Sffx	p1usg	J
# 17	VP	p1usg	>ZBX     	slaughter
# 17	VP	p1usg	>QR>     	call
# 18	Sffx	p1usg	J
# 18	VP	p1usg	>CLM     	be complete
# Pattern:  ['VP p1usg', 'VP uuu', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'NP ', 'PPrP p1usg', 'NP ', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# Results:  2
# ['C39:1', 'C116:8']

# %%
FindClassMention(corefs, suffix_errors, '>MRTJ')
# Out:
# C30:2 Who: >RWMM, first: >RWMM, type: VP, corpus class: 328
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	>RWMM     	be high
# 2	Sffx	p1usg	NJ
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 3	Sffx	p1usg	J
# 3	VP	p1usg	CW<TJ     	cry
# 3	Sffx	p1usg	NJ
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	NJ
# 4	VP		MJWRDJ     	from	Infc with PreS.
# 7	PPrP	p1usg	>NJ     	i
# 7	VP	p1usg	>MRTJ     	say
# 7	Sffx	p1usg	J
# 7	VP	p1usg	>MWV     	totter
# 8	Sffx	p1usg	J
# 8	VP	p1usg	HJJTJ     	be
# 9	VP	p1usg	>QR>     	call
# 9	VP	p1usg	>TXNN     	favour
# 10	Sffx	p1usg	J
# 10	VP	uuu	RDTJ     	descend	Infc with PreS.
# 11	Sffx	p1usg	NJ
# 11	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	NJ
# 13	Sffx	p1usg	J
# 13	VP	p1usg	>WD     	praise
# Pattern:  ['VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP ', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP uuu', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# C31:6 Who: XSJTJ, first: XSJTJ, type: VP, corpus class: 336
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	XSJTJ     	seek refuge
# 2	VP	p1usg	>BWCH     	be ashamed
# 2	Sffx	p1usg	NJ
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	NJ
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	NJ
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	NJ
# 4	Sffx	p1usg	NJ
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 6	VP	p1usg	>PQJD     	miss
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 7	VP	p1usg	FN>TJ     	hate
# 7	PPrP	p1usg	>NJ     	i
# 7	VP	p1usg	BVXTJ     	trust
# 8	VP	p1usg	>GJLH     	rejoice
# 8	VP	p1usg	>FMXH     	rejoice
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 9	Sffx	p1usg	NJ
# 9	Sffx	p1usg	J
# 10	Sffx	p1usg	NJ
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	VP	p1usg	HJJTJ     	be
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	NJ
# 13	VP	p1usg	NCKXTJ     	forget
# 13	VP	p1usg	HJJTJ     	be
# 14	VP	p1usg	CM<TJ     	hear
# 14	Sffx	p1usg	J
# 14	Sffx	p1usg	J
# 15	PPrP	p1usg	>NJ     	i
# 15	VP	p1usg	BVXTJ     	trust
# 15	VP	p1usg	>MRTJ     	say
# 15	Sffx	p1usg	J
# 16	Sffx	p1usg	J
# 16	Sffx	p1usg	NJ
# 16	Sffx	p1usg	J
# 16	Sffx	p1usg	J
# 17	Sffx	p1usg	NJ
# 18	VP	p1usg	>BWCH     	be ashamed
# 18	VP	p1usg	QR>TJ     	call
# 22	Sffx	p1usg	J
# 23	PPrP	p1usg	>NJ     	i
# 23	VP	p1usg	>MRTJ     	say
# 23	Sffx	p1usg	J
# 23	VP	p1usg	NGRZTJ     	exterminate
# 23	Sffx	p1usg	J
# 23	VP	uuu	CW<J     	cry	Infc with PreS.
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP uuu']
#
#
# C31:6 Who: XSJTJ, first: XSJTJ, type: VP, corpus class: 337
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	XSJTJ     	seek refuge
# 2	VP	p1usg	>BWCH     	be ashamed
# 2	Sffx	p1usg	NJ
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	NJ
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	NJ
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	NJ
# 4	Sffx	p1usg	NJ
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 6	VP	p1usg	>PQJD     	miss
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 7	VP	p1usg	FN>TJ     	hate
# 7	PPrP	p1usg	>NJ     	i
# 7	VP	p1usg	BVXTJ     	trust
# 8	VP	p1usg	>GJLH     	rejoice
# 8	VP	p1usg	>FMXH     	rejoice
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 9	Sffx	p1usg	NJ
# 9	Sffx	p1usg	J
# 10	Sffx	p1usg	NJ
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	VP	p1usg	HJJTJ     	be
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	NJ
# 13	VP	p1usg	NCKXTJ     	forget
# 13	VP	p1usg	HJJTJ     	be
# 14	VP	p1usg	CM<TJ     	hear
# 14	Sffx	p1usg	J
# 14	Sffx	p1usg	J
# 15	PPrP	p1usg	>NJ     	i
# 15	VP	p1usg	BVXTJ     	trust
# 15	VP	p1usg	>MRTJ     	say
# 15	Sffx	p1usg	J
# 16	Sffx	p1usg	J
# 16	Sffx	p1usg	NJ
# 16	Sffx	p1usg	J
# 16	Sffx	p1usg	J
# 17	Sffx	p1usg	NJ
# 18	VP	p1usg	>BWCH     	be ashamed
# 18	VP	p1usg	QR>TJ     	call
# 22	Sffx	p1usg	J
# 23	PPrP	p1usg	>NJ     	i
# 23	VP	p1usg	>MRTJ     	say
# 23	Sffx	p1usg	J
# 23	VP	p1usg	NGRZTJ     	exterminate
# 23	Sffx	p1usg	J
# 23	VP	uuu	CW<J     	cry	Infc with PreS.
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP uuu']
#
#
# C32:3 Who: YDJQJM, first: HXRCTJ, type: VP, corpus class: 353
#
# verse	type	pgn	ann		gloss	note
# 3	VP	p1usg	HXRCTJ     	be deaf
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 5	VP	p1usg	>WDJ<     	know
# 5	Sffx	p1usg	J
# 5	VP	p1usg	KSJTJ     	cover
# 5	VP	p1usg	>MRTJ     	say
# 5	VP	p1usg	>WDH     	praise
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 7	Sffx	p1usg	J
# 7	Sffx	p1usg	NJ
# 7	Sffx	p1usg	NJ
# 8	Sffx	p2msg	K
# 8	Sffx	p2msg	K
# 8	VP	p2msg	TLK     	walk
# 8	Sffx	p2msg	K
# 9	VP	p2mpl	THJW     	be
# 9	Sffx	p2msg	K
# 11	VP	p2mpl	FMXW     	rejoice
# 11	VP	p2mpl	GJLW     	rejoice
# 11	NP		YDJQJM     	just
# 11	VP	p2mpl	HRNJNW     	cry of joy
# 11	NP		KL&JCRJ&LB     	whole
# Pattern:  ['VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p2msg', 'Sfx p2msg', 'VP p2msg', 'Sfx p2msg', 'VP p2mpl', 'Sfx p2msg', 'VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl', 'NP']
#
#
# C38:1 Who: N<WJTJ, first: NJ, type: Sffx, corpus class: 468
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p1usg	NJ
# 2	Sffx	p1usg	NJ
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	NJ
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 7	VP	p1usg	N<WJTJ     	do wrong
# 7	VP	p1usg	CXTJ     	bow down
# 7	VP	p1usg	HLKTJ     	walk
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 9	VP	p1usg	NPWGWTJ     	grow numb
# 9	VP	p1usg	NDKJTJ     	crush
# 9	VP	p1usg	C>GTJ     	roar
# 9	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	NJ
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 14	PPrP	p1usg	>NJ     	i
# 14	VP	p1usg	>CM<     	hear
# 15	VP	p1usg	>HJ     	be
# 16	VP	p1usg	HWXLTJ     	wait, to hope
# 16	Sffx	p1usg	J
# 17	VP	p1usg	>MRTJ     	say
# 17	Sffx	p1usg	J
# 17	Sffx	p1usg	J
# 17	Sffx	p1usg	J
# 18	PPrP	p1usg	>NJ     	i
# 18	VP	umsg	NKWN     	be firm
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	J
# 19	Sffx	p1usg	J
# 19	VP	p1usg	>GJD     	report
# 19	VP	p1usg	>D>G     	be afraid
# 19	Sffx	p1usg	J
# 20	Sffx	p1usg	J
# 20	Sffx	p1usg	J
# 21	Sffx	p1usg	NJ
# 21	VP	uuu	RDWPJ     	pursue	Infc with PreS.
# 22	Sffx	p1usg	NJ
# 22	Sffx	p1usg	J
# 22	Sffx	p1usg	NJ
# 23	Sffx	p1usg	J
# 23	Sffx	p1usg	J
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP umsg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP uuu', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C39:1 Who: >MRTJ, first: >MRTJ, type: VP, corpus class: 488
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	>MRTJ     	say
# 2	VP	p1usg	>CMRH     	keep
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 2	VP	p1usg	>CMRH     	keep
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 3	VP	p1usg	N>LMTJ     	bind
# 3	VP	p1usg	HXCJTJ     	be silent
# 3	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	VP	p1usg	DBRTJ     	speak
# 4	Sffx	p1usg	J
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 5	VP	p1usg	>D<H     	know
# 5	PPrP	p1usg	>NJ     	i
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 8	VP	p1usg	QWJTJ     	wait for
# 8	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 9	Sffx	p1usg	NJ
# 9	Sffx	p1usg	NJ
# 10	VP	p1usg	N>LMTJ     	bind
# 10	VP	p1usg	>PTX     	open
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	J
# 11	PPrP	p1usg	>NJ     	i
# 11	VP	p1usg	KLJTJ     	be complete
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	PPrP	p1usg	>NKJ     	i
# 13	Sffx	p1usg	J
# 14	Sffx	p1usg	NJ
# 14	VP	p1usg	>BLJGH     	gleam
# 14	VP	p1usg	>LK     	walk
# 14	Sffx	p1usg	NJ
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg']
#
#
# C40:11 Who: QWJTJ, first: QWJTJ, type: VP, corpus class: 499
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	QWJTJ     	wait for
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 3	Sffx	p1usg	NJ
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 6	VP	p1usg	>GJDH     	report
# 6	VP	p1usg	>DBRH     	speak
# 7	Sffx	p1usg	J
# 8	VP	p1usg	>MRTJ     	say
# 8	VP	p1usg	B>TJ     	come
# 8	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 9	VP	p1usg	XPYTJ     	desire
# 9	Sffx	p1usg	J
# 10	VP	p1usg	BFRTJ     	announce
# 10	Sffx	p1usg	J
# 10	VP	p1usg	>KL>     	restrain
# 11	VP	p1usg	KSJTJ     	cover
# 11	Sffx	p1usg	J
# 11	VP	p1usg	>MRTJ     	say
# 11	VP	p1usg	KXDTJ     	hide
# 12	Sffx	p1usg	NJ
# 12	Sffx	p1usg	NJ
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	NJ
# 13	Sffx	p1usg	J
# 13	VP	p1usg	JKLTJ     	be able
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	NJ
# 14	Sffx	p1usg	NJ
# 14	Sffx	p1usg	J
# 15	Sffx	p1usg	J
# 15	Sffx	p1usg	J
# 16	Sffx	p1usg	J
# 18	PPrP	p1usg	>NJ     	i
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	J
# Pattern:  ['VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C40:11 Who: QWJTJ, first: QWJTJ, type: VP, corpus class: 500
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	QWJTJ     	wait for
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 3	Sffx	p1usg	NJ
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 6	VP	p1usg	>GJDH     	report
# 6	VP	p1usg	>DBRH     	speak
# 7	Sffx	p1usg	J
# 8	VP	p1usg	>MRTJ     	say
# 8	VP	p1usg	B>TJ     	come
# 8	Sffx	p1usg	J
# 9	Sffx	p1usg	J
# 9	VP	p1usg	XPYTJ     	desire
# 9	Sffx	p1usg	J
# 10	VP	p1usg	BFRTJ     	announce
# 10	Sffx	p1usg	J
# 10	VP	p1usg	>KL>     	restrain
# 11	VP	p1usg	KSJTJ     	cover
# 11	Sffx	p1usg	J
# 11	VP	p1usg	>MRTJ     	say
# 11	VP	p1usg	KXDTJ     	hide
# 12	Sffx	p1usg	NJ
# 12	Sffx	p1usg	NJ
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	NJ
# 13	Sffx	p1usg	J
# 13	VP	p1usg	JKLTJ     	be able
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	NJ
# 14	Sffx	p1usg	NJ
# 14	Sffx	p1usg	J
# 15	Sffx	p1usg	J
# 15	Sffx	p1usg	J
# 16	Sffx	p1usg	J
# 18	PPrP	p1usg	>NJ     	i
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	J
# Pattern:  ['VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C41:7 Who: >MRTJ, first: >NJ, type: PPrP, corpus class: 520
#
# verse	type	pgn	ann		gloss	note
# 5	PPrP	p1usg	>NJ     	i	Who is 1Csg?
# 5	VP	p1usg	>MRTJ     	say
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 5	VP	p1usg	XV>TJ     	miss
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 6	VP	p3msg	JMWT     	die
# 6	Sffx	p3msg	W
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 9	Sffx	p3msg	W
# 9	VP	p3msg	CKB     	lie down
# 9	VP	p3msg	JWSJP     	add
# 10	Sffx	p1usg	J
# 10	VP	p1usg	BVXTJ     	trust
# 10	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 11	Sffx	p1usg	NJ
# 11	Sffx	p1usg	NJ
# 11	VP	p1usg	>CLMH     	be complete
# 12	VP	p1usg	JD<TJ     	know
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 12	Sffx	p1usg	J
# 13	PPrP	p1usg	>NJ     	i
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	J
# 13	Sffx	p1usg	NJ
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p3msg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C73:17 Who: QN>TJ, first: >NJ, type: PPrP, corpus class: 955
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	>NJ     	i
# 2	Sffx	p1usg	J
# 2	Sffx	p1usg	J
# 3	VP	p1usg	QN>TJ     	be jealous
# 3	VP	p1usg	>R>H     	see
# 13	VP	p1usg	ZKJTJ     	be clean
# 13	Sffx	p1usg	J
# 13	VP	p1usg	>RXY     	wash
# 13	Sffx	p1usg	J
# 14	VP	p1usg	>HJ     	be
# 14	Sffx	p1usg	J
# 15	VP	p1usg	>MRTJ     	say
# 15	VP	p1usg	>SPRH     	count
# 15	VP	p1usg	BGDTJ     	deal treacherously
# 16	VP	p1usg	>XCBH     	account
# 16	Sffx	p1usg	J
# 17	VP	p1usg	>BW>     	come
# 17	VP	p1usg	>BJNH     	understand
# 21	Sffx	p1usg	J
# 21	Sffx	p1usg	J
# 21	VP	p1usg	>CTWNN     	sharpen
# 22	PPrP	p1usg	>NJ     	i
# 22	VP	p1usg	>D<     	know
# 22	VP	p1usg	HJJTJ     	be
# 23	PPrP	p1usg	>NJ     	i
# 23	Sffx	p1usg	J
# 24	Sffx	p1usg	NJ
# 24	Sffx	p1usg	NJ
# 25	Sffx	p1usg	J
# 25	VP	p1usg	XPYTJ     	desire
# 26	Sffx	p1usg	J
# 26	Sffx	p1usg	J
# 26	Sffx	p1usg	J
# 26	Sffx	p1usg	J
# 28	PPrP	p1usg	>NJ     	i
# 28	Sffx	p1usg	J
# 28	VP	p1usg	CTJ     	put
# 28	Sffx	p1usg	J
# Pattern:  ['PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg']
#
#
# C75:4 Who: >LHJM, first: K, type: Sffx, corpus class: 994
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p2msg	K
# 2	NP		>LHJM     	god(s)
# 2	Sffx	p2msg	K
# 2	Sffx	p2msg	K
# 3	VP	p1usg	>QX     	take
# 3	PPrP	p1usg	>NJ     	i
# 3	VP	p1usg	>CPV     	judge
# 4	PPrP	p1usg	>NKJ     	i
# 4	VP	p1usg	TKNTJ     	estimate
# 5	VP	p1usg	>MRTJ     	say
# 8	NP		>LHJM     	god(s)
# 8	NP		CPV     	judge
# 8	VP	p3msg	JCPJL     	be low
# 8	VP	p3msg	JRJM     	be high
# 9	NP		JD&JHWH     	hand
# 9	VP	p3msg	JGR     	run
# 10	NP		>LHJ J<QB     	god(s)
# 11	VP	p1usg	>GD<     	cut off
# Pattern:  ['Sfx p2msg', 'NP', 'Sfx p2msg', 'Sfx p2msg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'NP', 'NP', 'VP p3msg', 'VP p3msg', 'NP', 'VP p3msg', 'NP', 'VP p1usg']
#
#
# C82:4 Who: >LHJM, first: >LHJM, type: NP, corpus class: 1117
#
# verse	type	pgn	ann		gloss	note
# 1	NP		>LHJM     	god(s)
# 1	VP	umsg	NYB     	stand
# 1	VP	p3msg	JCPV     	judge
# 6	PPrP	p1usg	>NJ     	i
# 6	VP	p1usg	>MRTJ     	say
# 8	VP	p2msg	QWMH     	arise
# 8	NP		>LHJM     	god(s)
# 8	VP	p2msg	CPVH     	judge
# 8	PPrP	p2msg	>TH     	you
# 8	VP	p2msg	TNXL     	take possession
# Pattern:  ['NP', 'VP umsg', 'VP p3msg', 'PPrP p1usg', 'VP p1usg', 'VP p2msg', 'NP', 'VP p2msg', 'PPrP p2msg', 'VP p2msg']
#
#
# C89:1 Who: >CJRH, first: >CJRH, type: VP, corpus class: 1182
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p1usg	>CJRH     	sing
# 2	VP	p1usg	>WDJ<     	know
# 2	Sffx	p1usg	J
# 3	VP	p1usg	>MRTJ     	say
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# C94:11 Who: >MRTJ, first: J, type: Sffx, corpus class: 1276
#
# verse	type	pgn	ann		gloss	note
# 16	Sffx	p1usg	J    		    	Who is 1Csg?
# 16	Sffx	p1usg	J
# 17	Sffx	p1usg	J
# 17	Sffx	p1usg	J
# 18	VP	p1usg	>MRTJ     	say
# 18	Sffx	p1usg	J
# 18	Sffx	p1usg	NJ
# 19	Sffx	p1usg	J
# 19	Sffx	p1usg	J
# 19	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C116:8 Who: <BD, first: >MRTJ, type: VP, corpus class: 1601
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p1usg	>MRTJ     	say
# 11	VP	uuu	XPZJ     	hurry	Infc with PreS.
# 12	VP	p1usg	>CJB     	return
# 12	Sffx	p1usg	J
# 13	VP	p1usg	>F>     	lift
# 13	VP	p1usg	>QR>     	call
# 14	Sffx	p1usg	J
# 14	VP	p1usg	>CLM     	be complete
# 16	PPrP	p1usg	>NJ     	i
# 16	NP		<BD     	servant
# 16	PPrP	p1usg	>NJ     	i
# 16	NP		<BD     	servant
# 16	Sffx	p1usg	J
# 17	VP	p1usg	>ZBX     	slaughter
# 17	VP	p1usg	>QR>     	call
# 18	Sffx	p1usg	J
# 18	VP	p1usg	>CLM     	be complete
# Pattern:  ['VP p1usg', 'VP uuu', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'NP', 'PPrP p1usg', 'NP', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# C119:54 Who: <BD, first: J, type: Sffx, corpus class: 1640
#
# verse	type	pgn	ann		gloss	note
# 5	Sffx	p1usg	J
# 6	VP	p1usg	>BWC     	be ashamed
# 6	VP	uuu	HBJV     	look at	Infc with PreO.
# 6	Sffx	p1usg	J
# 7	VP	p1usg	>WD     	praise
# 7	VP	uuu	LMD     	learn	Infc with PreO.
# 7	Sffx	p1usg	J
# 8	VP	p1usg	>CMR     	keep
# 8	Sffx	p1usg	NJ
# 10	Sffx	p1usg	J
# 10	VP	p1usg	DRCTJ     	inquire
# 10	Sffx	p1usg	NJ
# 11	Sffx	p1usg	J
# 11	VP	p1usg	YPNTJ     	hide
# 11	VP	p1usg	>XV>     	miss
# 12	Sffx	p1usg	NJ
# 13	Sffx	p1usg	J
# 13	VP	p1usg	SPRTJ     	count
# 14	VP	p1usg	FFTJ     	rejoice
# 15	VP	p1usg	>FJXH     	be concerned with
# 15	VP	p1usg	>BJVH     	look at
# 16	VP	p1usg	>CT<C<     	take delight
# 16	VP	p1usg	>CKX     	forget
# 17	NP		<BD     	servant
# 17	VP	p1usg	>XJH     	be alive
# 17	VP	p1usg	>CMRH     	keep
# 18	Sffx	p1usg	J
# 18	VP	p1usg	>BJVH     	look at
# 19	PPrP	p1usg	>NKJ     	i
# 19	Sffx	p1usg	NJ
# 20	Sffx	p1usg	J
# 22	Sffx	p1usg	J
# 22	VP	p1usg	NYRTJ     	watch
# 23	Sffx	p1usg	J
# 23	NP		<BD     	servant
# 23	VP	p3msg	JFJX     	be concerned with
# 24	Sffx	p1usg	J
# 24	Sffx	p1usg	J
# 25	Sffx	p1usg	J
# 25	Sffx	p1usg	NJ
# 26	Sffx	p1usg	J
# 26	VP	p1usg	SPRTJ     	count
# 26	Sffx	p1usg	NJ
# 26	Sffx	p1usg	NJ
# 27	Sffx	p1usg	NJ
# 27	VP	p1usg	>FJXH     	be concerned with
# 28	Sffx	p1usg	J
# 28	Sffx	p1usg	NJ
# 29	Sffx	p1usg	NJ
# 29	Sffx	p1usg	NJ
# 30	VP	p1usg	BXRTJ     	examine
# 30	VP	p1usg	CWJTJ     	place
# 31	VP	p1usg	DBQTJ     	cling, cleave to
# 31	Sffx	p1usg	NJ
# 32	VP	p1usg	>RWY     	run
# 32	Sffx	p1usg	J
# 33	Sffx	p1usg	NJ
# 33	VP	p1usg	>YRN     	watch
# 34	Sffx	p1usg	NJ
# 34	VP	p1usg	>YRH     	watch
# 34	VP	p1usg	>CMRN     	keep
# 35	Sffx	p1usg	NJ
# 35	VP	p1usg	XPYTJ     	desire
# 36	Sffx	p1usg	J
# 37	Sffx	p1usg	J
# 37	Sffx	p1usg	NJ
# 38	NP		<BD     	servant
# 39	Sffx	p1usg	J
# 39	VP	p1usg	JGRTJ     	be afraid
# 40	VP	p1usg	T>BTJ     	long for
# 40	Sffx	p1usg	NJ
# 41	Sffx	p1usg	NJ
# 42	VP	p1usg	><NH     	answer
# 42	Sffx	p1usg	J
# 42	VP	p1usg	BVXTJ     	trust
# 43	Sffx	p1usg	J
# 43	VP	p1usg	JXLTJ     	wait, to hope
# 44	VP	p1usg	>CMRH     	keep
# 45	VP	p1usg	>THLKH     	walk
# 45	VP	p1usg	DRCTJ     	inquire
# 46	VP	p1usg	>DBRH     	speak
# 46	VP	p1usg	>BWC     	be ashamed
# 47	VP	p1usg	>CT<C<     	take delight
# 47	VP	p1usg	>HBTJ     	love
# 48	VP	p1usg	>F>     	lift
# 48	Sffx	p1usg	J
# 48	VP	p1usg	>HBTJ     	love
# 48	VP	p1usg	>FJXH     	be concerned with
# 49	NP		<BD     	servant
# 49	Sffx	p1usg	NJ
# 50	Sffx	p1usg	J
# 50	Sffx	p1usg	J
# 50	Sffx	p1usg	NJ
# 51	Sffx	p1usg	NJ
# 51	VP	p1usg	NVJTJ     	extend
# 52	VP	p1usg	ZKRTJ     	remember
# 52	VP	p1usg	>TNXM     	repent, console
# 53	Sffx	p1usg	NJ
# 54	Sffx	p1usg	J
# 54	Sffx	p1usg	J
# 55	VP	p1usg	ZKRTJ     	remember
# 55	VP	p1usg	>CMRH     	keep
# 56	Sffx	p1usg	J
# 56	VP	p1usg	NYRTJ     	watch
# 57	Sffx	p1usg	J
# 57	VP	p1usg	>MRTJ     	say
# 58	VP	p1usg	XLJTJ     	become weak
# 58	Sffx	p1usg	NJ
# 59	VP	p1usg	XCBTJ     	account
# 59	Sffx	p1usg	J
# 59	VP	p1usg	>CJBH     	return
# 59	Sffx	p1usg	J
# 60	VP	p1usg	XCTJ     	make haste
# 60	VP	p1usg	HTMHMHTJ     	tarry
# 61	Sffx	p1usg	NJ
# 61	VP	p1usg	CKXTJ     	forget
# 62	VP	p1usg	>QWM     	arise
# 63	PPrP	p1usg	>NJ     	i
# 64	Sffx	p1usg	NJ
# 65	NP		<BD     	servant
# 66	Sffx	p1usg	NJ
# 66	VP	p1usg	H>MNTJ     	be firm
# 67	VP	p1usg	><NH     	be lowly
# 67	PPrP	p1usg	>NJ     	i
# 67	VP	umsg	CGG     	commit error
# 67	VP	p1usg	CMRTJ     	keep
# 68	Sffx	p1usg	NJ
# 69	Sffx	p1usg	J
# 69	PPrP	p1usg	>NJ     	i
# 69	VP	p1usg	>YR     	watch
# 70	PPrP	p1usg	>NJ     	i
# 70	VP	p1usg	C<C<TJ     	take delight
# 71	Sffx	p1usg	J
# 71	VP	p1usg	<NJTJ     	be lowly
# 71	VP	p1usg	>LMD     	learn
# 72	Sffx	p1usg	J
# 73	Sffx	p1usg	NJ
# 73	Sffx	p1usg	NJ
# 73	Sffx	p1usg	NJ
# 73	VP	p1usg	>LMDH     	learn
# 74	Sffx	p1usg	NJ
# 74	VP	p1usg	JXLTJ     	wait, to hope
# 75	VP	p1usg	JD<TJ     	know
# 75	Sffx	p1usg	NJ
# 76	Sffx	p1usg	NJ
# 76	NP		<BD     	servant
# 77	Sffx	p1usg	NJ
# 77	VP	p1usg	>XJH     	be alive
# 77	Sffx	p1usg	J
# 78	Sffx	p1usg	NJ
# 78	PPrP	p1usg	>NJ     	i
# 78	VP	p1usg	>FJX     	be concerned with
# 79	Sffx	p1usg	J
# 80	Sffx	p1usg	J
# 80	VP	p1usg	>BWC     	be ashamed
# 81	Sffx	p1usg	J
# 81	VP	p1usg	JXLTJ     	wait, to hope
# 82	Sffx	p1usg	J
# 82	Sffx	p1usg	NJ
# 83	VP	p1usg	HJJTJ     	be
# 83	VP	p1usg	CKXTJ     	forget
# 84	Sffx	p1usg	J
# 85	Sffx	p1usg	J
# 86	Sffx	p1usg	NJ
# 86	Sffx	p1usg	NJ
# 87	Sffx	p1usg	NJ
# 87	PPrP	p1usg	>NJ     	i
# 87	VP	p1usg	<ZBTJ     	leave
# 88	Sffx	p1usg	NJ
# 88	VP	p1usg	>CMRH     	keep
# 92	Sffx	p1usg	J
# 92	VP	p1usg	>BDTJ     	perish
# 92	Sffx	p1usg	J
# 93	VP	p1usg	>CKX     	forget
# 93	Sffx	p1usg	NJ
# 94	PPrP	p1usg	>NJ     	i
# 94	Sffx	p1usg	NJ
# 94	VP	p1usg	DRCTJ     	inquire
# 95	Sffx	p1usg	J
# 95	Sffx	p1usg	NJ
# 95	VP	p1usg	>TBWNN     	understand
# 96	VP	p1usg	R>JTJ     	see
# 97	VP	p1usg	>HBTJ     	love
# 97	Sffx	p1usg	J
# 98	Sffx	p1usg	J
# 98	Sffx	p1usg	NJ
# 98	Sffx	p1usg	J
# 99	Sffx	p1usg	J
# 99	VP	p1usg	HFKLTJ     	prosper
# 99	Sffx	p1usg	J
# 100	VP	p1usg	>TBWNN     	understand
# 100	VP	p1usg	NYRTJ     	watch
# 101	VP	p1usg	KL>TJ     	restrain
# 101	Sffx	p1usg	J
# 101	VP	p1usg	>CMR     	keep
# 102	VP	p1usg	SRTJ     	turn aside
# 102	Sffx	p1usg	NJ
# 103	Sffx	p1usg	J
# 103	Sffx	p1usg	J
# 104	VP	p1usg	>TBWNN     	understand
# 104	VP	p1usg	FN>TJ     	hate
# 105	Sffx	p1usg	J
# 105	Sffx	p1usg	J
# 106	VP	p1usg	NCB<TJ     	swear
# 106	VP	p1usg	>QJMH     	arise
# 107	VP	p1usg	N<NJTJ     	be lowly
# 107	Sffx	p1usg	NJ
# 108	Sffx	p1usg	J
# 108	Sffx	p1usg	NJ
# 109	Sffx	p1usg	J
# 109	Sffx	p1usg	J
# 109	VP	p1usg	CKXTJ     	forget
# 110	Sffx	p1usg	J
# 110	VP	p1usg	T<JTJ     	err
# 111	VP	p1usg	NXLTJ     	take possession
# 111	Sffx	p1usg	J
# 112	VP	p1usg	NVJTJ     	extend
# 112	Sffx	p1usg	J
# 113	VP	p1usg	FN>TJ     	hate
# 113	VP	p1usg	>HBTJ     	love
# 114	Sffx	p1usg	J
# 114	Sffx	p1usg	J
# 114	VP	p1usg	JXLTJ     	wait, to hope
# 115	Sffx	p1usg	NJ
# 115	VP	p1usg	>YRH     	watch
# 115	Sffx	p1usg	J
# 116	Sffx	p1usg	NJ
# 116	VP	p1usg	>XJH     	be alive
# 116	Sffx	p1usg	NJ
# 116	Sffx	p1usg	J
# 117	Sffx	p1usg	NJ
# 117	VP	p1usg	>WC<H     	help
# 117	VP	p1usg	>C<H     	look
# 119	VP	p1usg	>HBTJ     	love
# 120	Sffx	p1usg	J
# 120	VP	p1usg	JR>TJ     	fear
# 121	VP	p1usg	<FJTJ     	make
# 121	Sffx	p1usg	NJ
# 121	Sffx	p1usg	J
# 122	NP		<BD     	servant
# 122	Sffx	p1usg	NJ
# 123	Sffx	p1usg	J
# 124	NP		<BD     	servant
# 124	Sffx	p1usg	NJ
# 125	NP		<BD     	servant
# 125	PPrP	p1usg	>NJ     	i
# 125	Sffx	p1usg	NJ
# 125	VP	p1usg	>D<H     	know
# 127	VP	p1usg	>HBTJ     	love
# 128	VP	p1usg	JCRTJ     	be right
# 128	VP	p1usg	FN>TJ     	hate
# 129	Sffx	p1usg	J
# 131	Sffx	p1usg	J
# 131	VP	p1usg	P<RTJ     	open
# 131	VP	p1usg	>C>PH     	gasp
# 131	VP	p1usg	J>BTJ     	long
# 132	Sffx	p1usg	J
# 132	Sffx	p1usg	NJ
# 133	Sffx	p1usg	J
# 133	Sffx	p1usg	J
# 134	Sffx	p1usg	NJ
# 134	VP	p1usg	>CMRH     	keep
# 135	NP		<BD     	servant
# 135	Sffx	p1usg	NJ
# 136	Sffx	p1usg	J
# 139	Sffx	p1usg	NJ
# 139	Sffx	p1usg	J
# 139	Sffx	p1usg	J
# 140	NP		<BD     	servant
# 140	VP	p3msg	>HBH     	love
# 141	PPrP	p1usg	>NKJ     	i
# 141	VP	p1usg	CKXTJ     	forget
# 143	Sffx	p1usg	NJ
# 143	Sffx	p1usg	J
# 144	Sffx	p1usg	NJ
# 144	VP	p1usg	>XJH     	be alive
# 145	VP	p1usg	QR>TJ     	call
# 145	Sffx	p1usg	NJ
# 145	VP	p1usg	>YRH     	watch
# 146	VP	p1usg	QR>TJ     	call
# 146	Sffx	p1usg	NJ
# 146	VP	p1usg	>CMRH     	keep
# 147	VP	p1usg	QDMTJ     	be in front
# 147	VP	p1usg	>CW<H     	cry
# 147	VP	p1usg	JXLTJ     	wait, to hope
# 148	Sffx	p1usg	J
# 148	VP	uuu	FJX     	be concerned with
# 149	Sffx	p1usg	J
# 149	Sffx	p1usg	NJ
# 152	VP	p1usg	JD<TJ     	know
# 153	Sffx	p1usg	J
# 153	Sffx	p1usg	NJ
# 153	VP	p1usg	CKXTJ     	forget
# 154	Sffx	p1usg	J
# 154	Sffx	p1usg	NJ
# 154	Sffx	p1usg	NJ
# 156	Sffx	p1usg	NJ
# 157	Sffx	p1usg	J
# 157	Sffx	p1usg	J
# 157	VP	p1usg	NVJTJ     	extend
# 158	VP	p1usg	R>JTJ     	see
# 158	VP	p1usg	>TQWVVH     	loath
# 159	VP	p1usg	>HBTJ     	love
# 159	Sffx	p1usg	NJ
# 161	Sffx	p1usg	NJ
# 161	Sffx	p1usg	J
# 162	VP	umsg	FF     	rejoice
# 162	PPrP	p1usg	>NKJ     	i
# 162	PtcP		MWY>     	find
# 163	VP	p1usg	FN>TJ     	hate
# 163	VP	p1usg	>T<BH     	be abhorrent
# 163	VP	p1usg	>HBTJ     	love
# 164	VP	p1usg	HLLTJ     	praise
# 166	VP	p1usg	FBRTJ     	examine
# 166	VP	p1usg	<FJTJ     	make
# 167	Sffx	p1usg	J
# 167	VP	p1usg	>HB     	love
# 168	VP	p1usg	CMRTJ     	keep
# 168	Sffx	p1usg	J
# 169	Sffx	p1usg	J
# 169	Sffx	p1usg	NJ
# 170	Sffx	p1usg	J
# 170	Sffx	p1usg	NJ
# 171	Sffx	p1usg	J
# 171	Sffx	p1usg	NJ
# 172	Sffx	p1usg	J
# 173	Sffx	p1usg	NJ
# 173	VP	p1usg	BXRTJ     	examine
# 174	VP	p1usg	T>BTJ     	long for
# 174	Sffx	p1usg	J
# 175	Sffx	p1usg	J
# 175	Sffx	p1usg	NJ
# 176	VP	p1usg	T<JTJ     	err
# 176	NP		<BD     	servant
# 176	VP	p1usg	CKXTJ     	forget
# Pattern:  ['Sfx p1usg', 'VP p1usg', 'VP uuu', 'Sfx p1usg', 'VP p1usg', 'VP uuu', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'NP', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'NP', 'VP p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'NP', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'NP', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'PPrP p1usg', 'Sfx p1usg', 'NP', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'PPrP p1usg', 'VP umsg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'NP', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'NP', 'Sfx p1usg', 'Sfx p1usg', 'NP', 'Sfx p1usg', 'NP', 'PPrP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'NP', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'NP', 'VP p3msg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP uuu', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP umsg', 'PPrP p1usg', 'PtcP', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg' ...
#
#
# C140:1 Who: >MRTJ, first: NJ, type: Sffx, corpus class: 1870
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p1usg	NJ
# 2	Sffx	p1usg	NJ
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 7	VP	p1usg	>MRTJ     	say
# 7	Sffx	p1usg	J
# 7	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 10	Sffx	p1usg	J
# 13	VP	p1usg	JD<T     	know
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# C142:2 Who: >Z<Q, first: J, type: Sffx, corpus class: 1896
#
# verse	type	pgn	ann		gloss	note
# 2	Sffx	p1usg	J
# 2	VP	p1usg	>Z<Q     	cry
# 2	Sffx	p1usg	J
# 2	VP	p1usg	>TXNN     	favour
# 3	VP	p1usg	>CPK     	pour
# 3	Sffx	p1usg	J
# 3	Sffx	p1usg	J
# 3	VP	p1usg	>GJD     	report
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	Sffx	p1usg	J
# 4	VP	p1usg	>HLK     	walk
# 4	Sffx	p1usg	J
# 5	Sffx	p1usg	J
# 5	Sffx	p1usg	NJ
# 5	Sffx	p1usg	J
# 6	VP	p1usg	Z<QTJ     	cry
# 6	VP	p1usg	>MRTJ     	say
# 6	Sffx	p1usg	J
# 6	Sffx	p1usg	J
# 7	Sffx	p1usg	J
# 7	VP	p1usg	DLWTJ     	belittle
# 7	Sffx	p1usg	NJ
# 7	Sffx	p1usg	J
# 7	Sffx	p1usg	NJ
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# 8	Sffx	p1usg	J
# Pattern:  ['Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# Results:  16
# ['C116:8',
#  'C119:54',
#  'C140:1',
#  'C142:2',
#  'C30:2',
#  'C31:6',
#  'C32:3',
#  'C38:1',
#  'C39:1',
#  'C40:11',
#  'C41:7',
#  'C73:17',
#  'C75:4',
#  'C82:4',
#  'C89:1',
#  'C94:11']

# %% [markdown]
# ### C75:9 Who/what: NPL>WTJ / first: SPRW, type: VP

# %%
FindWho(corefs, suffix_errors, ['NPL>WTJ', 'SPRW'])
# Out:
# C75:9 Who: NPL>WTJ, first: SPRW, type: VP, corpus class: 995
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p3upl	SPRW     	count
# 2	NP		NPL>WTJ     	be miraculous
# Pattern:  ['VP p3upl', 'NP']
#
#
# C78:13 Who: NPL>WTJ, first: NPL>WTJ, type: NP, corpus class: 1041
#
# verse	type	pgn	ann		gloss	note
# 4	NP		NPL>WTJ     	be miraculous
# 11	NP		NPL>WTJ     	be miraculous
# 32	NP		NPL>WTJ     	be miraculous
# Pattern:  ['NP', 'NP', 'NP']
#
#
# C107:10 Who: NPL>WTJ, first: NPL>WTJ, type: NP, corpus class: 1484
#
# verse	type	pgn	ann		gloss	note
# 8	NP		NPL>WTJ     	be miraculous
# 15	NP		NPL>WTJ     	be miraculous
# 21	NP		NPL>WTJ     	be miraculous
# 31	NP		NPL>WTJ     	be miraculous
# Pattern:  ['NP', 'NP', 'NP', 'NP']
#
#
# Results:  3
# ['C75:9', 'C78:13', 'C107:10']

# %% [markdown]
# #### NPL>WTJ

# %%
lst = FindMention(corefs, suffix_errors, 'NPL>WTJ')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 75:2	C75:9	NP		NPL>WTJ		be miraculous
# 78:4	C78:13	NP		NPL>WTJ		be miraculous
# 78:11	C78:13	NP		NPL>WTJ		be miraculous
# 78:32	C78:13	NP		NPL>WTJ		be miraculous
# 107:8	C107:10	NP		NPL>WTJ		be miraculous
# 107:15	C107:10	NP		NPL>WTJ		be miraculous
# 107:21	C107:10	NP		NPL>WTJ		be miraculous
# 107:31	C107:10	NP		NPL>WTJ		be miraculous
# 26:7	Sing	NP		NPL>WTJ		be miraculous
# 71:17	Sing	NP		NPL>WTJ		be miraculous
# 96:3	Sing	NP		NPL>WTJ		be miraculous
# 105:5	Sing	NP		NPL>WTJ		be miraculous
# 106:7	Sing	NP		NPL>WTJ		be miraculous
# 107:24	Sing	NP		NPL>WTJ		be miraculous
# 119:27	Sing	NP		NPL>WTJ		be miraculous
#
#
# Results:  15

# %% [markdown]
# #### Notes
# Singing about wondrous deeds:
# * 96:3
# * 105:5
# * 106:7

# %% [markdown]
# #### SPRW

# %%
FindMention(corefs, suffix_errors, 'SPRW')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 44:2	C44:1	VP	p3upl	SPRW		count
# 48:13	C48:10	VP	p2mpl	SPRW		count
# 75:2	C75:9	VP	p3upl	SPRW		count
# 78:3	C78:21	VP	p3upl	SPRW		count
# 96:3	C96:2	VP	p2mpl	SPRW		count
#
#
# Results:  5
# ['C44:1', 'C48:10', 'C75:9', 'C78:21', 'C96:2']

# %%
FindClassMention(corefs, suffix_errors, 'SPRW')
# Out:
# C44:1 Who: >BWTJ, first: >BWTJ, type: NP, corpus class: 545
#
# verse	type	pgn	ann		gloss	note
# 2	NP		>BWTJ     	father
# 2	VP	p3upl	SPRW     	count
# 2	PPrP	p3mpl	HM
# 3	PPrP	p3mpl	M
# 3	PPrP	p3mpl	M
# 4	PPrP	p3mpl	M
# 4	VP	p3upl	JRCW     	trample down
# 4	PPrP	p3mpl	M
# 4	PPrP	p3mpl	MW
# 4	PPrP	p3mpl	M
# Pattern:  ['NP', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl']
#
#
# C48:10 Who: SBW, first: SBW, type: VP, corpus class: 600
#
# verse	type	pgn	ann		gloss	note
# 13	VP	p2mpl	SBW     	turn	Unclear: to whom refers 2Mpl?
# 13	VP	p2mpl	HQJPW     	go around
# 13	VP	p2mpl	SPRW     	count
# 14	VP	p2mpl	CJTW     	put
# 14	PPrP	p2mpl	KM
# 14	VP	p2mpl	PSGW     	pass between?
# 14	VP	p2mpl	TSPRW     	count
# Pattern:  ['VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'Sfx p2mpl', 'VP p2mpl', 'VP p2mpl']
#
#
# C75:9 Who: NPL>WTJ, first: SPRW, type: VP, corpus class: 995
#
# verse	type	pgn	ann		gloss	note
# 2	VP	p3upl	SPRW     	count
# 2	NP		NPL>WTJ     	be miraculous
# Pattern:  ['VP p3upl', 'NP']
#
#
# C78:21 Who: >BWTJ, first: >BWTJ, type: NP, corpus class: 1037
#
# verse	type	pgn	ann		gloss	note
# 3	NP		>BWTJ     	father	Whose fathers? Seems to be one specific group: the rebellious generation.
# 3	VP	p3upl	SPRW     	count
# 4	PPrP	p3mpl	HM
# 5	NP		>BWTJ     	father
# 5	VP	uuu	HWDJ<M     	know	Infc with PreS.
# 5	PPrP	p3mpl	HM
# 8	NP		>BWT     	father	Whose fathers? Seems to be one specific group: the rebellious generation.
# 12	NP		>BWT     	father	Whose fathers? Seems to be one specific group: the rebellious generation.
# 13	PPrP	p3mpl	M
# 14	PPrP	p3mpl	M
# 17	VP	p3mpl	JWSJPW     	add
# 18	VP	p3mpl	JNSW     	try
# 18	PPrP	p3mpl	M
# 18	PPrP	p3mpl	M
# 19	VP	p3mpl	JDBRW     	speak
# 19	VP	p3upl	>MRW     	say
# 24	PPrP	p3mpl	HM
# 24	PPrP	p3mpl	MW
# 25	PPrP	p3mpl	HM
# 27	PPrP	p3mpl	HM
# 29	VP	p3mpl	J>KLW     	eat
# 29	VP	p3mpl	JFB<W     	be sated
# 29	PPrP	p3mpl	M
# 29	PPrP	p3mpl	HM
# 30	VP	p3upl	ZRW     	turn aside
# 30	PPrP	p3mpl	M
# 30	PPrP	p3mpl	M
# 30	PPrP	p3mpl	HM
# 31	PPrP	p3mpl	HM
# 31	PPrP	p3mpl	HM
# 32	VP	p3upl	XV>W     	miss
# 32	VP	p3upl	H>MJNW     	be firm
# 33	PPrP	p3mpl	M
# 33	PPrP	p3mpl	M
# 34	PPrP	p3mpl	M
# 34	VP	p3upl	DRCW     	inquire
# 34	VP	p3upl	CBW     	return
# 34	VP	p3upl	CXRW     	look for
# 35	VP	p3mpl	JZKRW     	remember
# 35	PPrP	p3mpl	M
# 35	PPrP	p3mpl	M
# 36	VP	p3mpl	JPTW     	seduce
# 36	PPrP	p3mpl	HM
# 36	PPrP	p3mpl	M
# 36	VP	p3mpl	JKZBW     	lie
# 37	PPrP	p3mpl	M
# 37	VP	p3upl	N>MNW     	be firm
# 39	PPrP	p3mpl	HMH     	they
# 40	VP	p3mpl	JMRW     	rebel
# 40	VP	p3mpl	J<YJBW     	hurt
# 41	VP	p3mpl	JCWBW     	return
# 41	VP	p3mpl	JNSW     	try
# 41	VP	p3upl	HTWW     	hurt
# 42	VP	p3upl	ZKRW     	remember
# 42	PPrP	p3mpl	M
# 57	NP		>BWT     	father	Whose ancestors are they? The rebellious ones from v.8 and 12?
# Pattern:  ['NP', 'VP p3upl', 'Sfx p3mpl', 'NP', 'VP uuu', 'Sfx p3mpl', 'NP', 'NP', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3upl', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3upl', 'VP p3upl', 'VP p3upl', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'VP p3upl', 'PPrP p3mpl', 'VP p3mpl', 'VP p3mpl', 'VP p3mpl', 'VP p3mpl', 'VP p3upl', 'VP p3upl', 'Sfx p3mpl', 'NP']
#
#
# C96:2 Who: KL&H>RY, first: CJRW, type: VP, corpus class: 1288
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2mpl	CJRW     	sing
# 1	VP	p2mpl	CJRW     	sing
# 1	NP		KL&H>RY     	whole
# 2	VP	p2mpl	CJRW     	sing
# 2	VP	p2mpl	BRKW     	bless
# 2	VP	p2mpl	BFRW     	announce
# 3	VP	p2mpl	SPRW     	count
# 9	VP	p2mpl	HCTXWW     	bow down
# 9	VP	p2mpl	XJLW     	have labour pain, to cry
# 9	NP		KL&H>RY     	whole
# 10	VP	p2mpl	>MRW     	say
# Pattern:  ['VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl']
#
#
# Results:  5
# ['C44:1', 'C48:10', 'C75:9', 'C78:21', 'C96:2']

# %% [markdown]
# ### C75:2 Who/what: >RY WKL&JCBJ / first: NMGJM, type: VP

# %%
# >RY WKL&JCBJ
lst = FindMention(corefs, suffix_errors, 'JCBJ')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 107:10	C107:6	VP	umpl	JCBJ		sit
# 123:1	C123:2	VP	umsg	JCBJ		sit
# 24:1	Sing	VP	umpl	JCBJ		sit
# 98:7	Sing	NP		JCBJ		sit
#
#
# Results:  4

# %% [markdown]
# #### KL&H>RY

# %%
FindClassMention(corefs, suffix_errors, 'KL&H>RY')
# Out:
# C8:8 Who: KL&H>RY, first: KL&H>RY, type: NP, corpus class: 71
#
# verse	type	pgn	ann		gloss	note
# 2	NP		KL&H>RY     	whole
# 10	NP		KL&H>RY     	whole
# Pattern:  ['NP', 'NP']
#
#
# C8:8 Who: KL&H>RY, first: KL&H>RY, type: NP, corpus class: 72
#
# verse	type	pgn	ann		gloss	note
# 2	NP		KL&H>RY     	whole
# 10	NP		KL&H>RY     	whole
# Pattern:  ['NP', 'NP']
#
#
# C33:5 Who: KL&H>RY, first: JJR>W, type: VP, corpus class: 369
#
# verse	type	pgn	ann		gloss	note
# 8	VP	p3mpl	JJR>W     	fear
# 8	NP		KL&H>RY     	whole
# Pattern:  ['VP p3mpl', 'NP']
#
#
# C57:15 Who: KL&H>RY, first: KL&H>RY, type: NP, corpus class: 721
#
# verse	type	pgn	ann		gloss	note
# 6	NP		KL&H>RY     	whole
# 12	NP		KL&H>RY     	whole
# Pattern:  ['NP', 'NP']
#
#
# C57:15 Who: KL&H>RY, first: KL&H>RY, type: NP, corpus class: 722
#
# verse	type	pgn	ann		gloss	note
# 6	NP		KL&H>RY     	whole
# 12	NP		KL&H>RY     	whole
# Pattern:  ['NP', 'NP']
#
#
# C66:1 Who: KL&H>RY, first: HRJ<W, type: VP, corpus class: 819
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2mpl	HRJ<W     	shout
# 1	NP		KL&H>RY     	whole
# 2	VP	p2mpl	ZMRW     	sing
# 2	VP	p2mpl	FJMW     	put
# 3	VP	p2mpl	>MRW     	say
# 4	NP		KL&H>RY     	whole
# 4	VP	p3mpl	JCTXWW     	bow down
# 4	VP	p3mpl	JZMRW     	sing
# 4	VP	p3mpl	JZMRW     	sing
# 5	VP	p2mpl	LKW     	walk
# 5	VP	p2mpl	R>W     	see
# Pattern:  ['VP p2mpl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'NP', 'VP p3mpl', 'VP p3mpl', 'VP p3mpl', 'VP p2mpl', 'VP p2mpl']
#
#
# C66:1 Who: KL&H>RY, first: HRJ<W, type: VP, corpus class: 820
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2mpl	HRJ<W     	shout
# 1	NP		KL&H>RY     	whole
# 2	VP	p2mpl	ZMRW     	sing
# 2	VP	p2mpl	FJMW     	put
# 3	VP	p2mpl	>MRW     	say
# 4	NP		KL&H>RY     	whole
# 4	VP	p3mpl	JCTXWW     	bow down
# 4	VP	p3mpl	JZMRW     	sing
# 4	VP	p3mpl	JZMRW     	sing
# 5	VP	p2mpl	LKW     	walk
# 5	VP	p2mpl	R>W     	see
# Pattern:  ['VP p2mpl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'NP', 'VP p3mpl', 'VP p3mpl', 'VP p3mpl', 'VP p2mpl', 'VP p2mpl']
#
#
# C96:2 Who: KL&H>RY, first: CJRW, type: VP, corpus class: 1288
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2mpl	CJRW     	sing
# 1	VP	p2mpl	CJRW     	sing
# 1	NP		KL&H>RY     	whole
# 2	VP	p2mpl	CJRW     	sing
# 2	VP	p2mpl	BRKW     	bless
# 2	VP	p2mpl	BFRW     	announce
# 3	VP	p2mpl	SPRW     	count
# 9	VP	p2mpl	HCTXWW     	bow down
# 9	VP	p2mpl	XJLW     	have labour pain, to cry
# 9	NP		KL&H>RY     	whole
# 10	VP	p2mpl	>MRW     	say
# Pattern:  ['VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl']
#
#
# C96:2 Who: KL&H>RY, first: CJRW, type: VP, corpus class: 1289
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2mpl	CJRW     	sing
# 1	VP	p2mpl	CJRW     	sing
# 1	NP		KL&H>RY     	whole
# 2	VP	p2mpl	CJRW     	sing
# 2	VP	p2mpl	BRKW     	bless
# 2	VP	p2mpl	BFRW     	announce
# 3	VP	p2mpl	SPRW     	count
# 9	VP	p2mpl	HCTXWW     	bow down
# 9	VP	p2mpl	XJLW     	have labour pain, to cry
# 9	NP		KL&H>RY     	whole
# 10	VP	p2mpl	>MRW     	say
# Pattern:  ['VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl']
#
#
# C98:4 Who: KL&H>RY, first: CJRW, type: VP, corpus class: 1317
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2mpl	CJRW     	sing
# 4	VP	p2mpl	HRJ<W     	shout
# 4	NP		KL&H>RY     	whole
# 4	VP	p2mpl	PYXW     	be serene
# 4	VP	p2mpl	RNNW     	cry of joy
# 4	VP	p2mpl	ZMRW     	sing
# 5	VP	p2mpl	ZMRW     	sing
# 6	VP	p2mpl	HRJ<W     	shout
# Pattern:  ['VP p2mpl', 'VP p2mpl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl']
#
#
# C100:2 Who: KL&H>RY, first: HRJ<W, type: VP, corpus class: 1334
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p2mpl	HRJ<W     	shout
# 1	NP		KL&H>RY     	whole
# 2	VP	p2mpl	<BDW     	work, serve
# 2	VP	p2mpl	B>W     	come
# 3	VP	p2mpl	D<W     	know
# 3	PPrP	 	NW    		make	!CORRUPT ANN
# 3	PPrP	p1upl	>NXNW     	we
# 3	NP		<M     	people
# 4	VP	p2mpl	B>W     	come
# 4	VP	p2mpl	HWDW     	praise
# 4	VP	p2mpl	BRKW     	bless
# Pattern:  ['VP p2mpl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl', 'Sfx', 'PPrP p1upl', 'NP', 'VP p2mpl', 'VP p2mpl', 'VP p2mpl']
#
#
# Results:  7
# ['C100:2', 'C33:5', 'C57:15', 'C66:1', 'C8:8', 'C96:2', 'C98:4']

# %% [markdown]
# #### KL&JCBJ

# %%
FindMention(corefs, suffix_errors, 'KL&JCBJ')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
#
#
# Results:  0
# []

# %% [markdown]
# #### NMGJM

# %%
FindMention(corefs, suffix_errors, 'NMGJM')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 75:4	C75:2	VP	umpl	NMGJM		faint
#
#
# Results:  1
# ['C75:2']

# %% [markdown]
# ### C75:3 Who/what: HWLLJM / first: HWLLJM, type: NP

# %%
FindWho(corefs, suffix_errors, ['HWLLJM'])
# Out:
# C5:8 Who: HWLLJM, first: JTJYBW, type: VP, corpus class: 43
#
# verse	type	pgn	ann		gloss	note
# 6	VP	p3mpl	JTJYBW     	stand
# 6	NP		HWLLJM     	be infatuated
# Pattern:  ['VP p3mpl', 'NP']
#
#
# C75:3 Who: HWLLJM, first: HWLLJM, type: NP, corpus class: 997
#
# verse	type	pgn	ann		gloss	note
# 5	NP		HWLLJM     	be infatuated
# 5	VP	p2mpl	THLW     	be infatuated
# Pattern:  ['NP', 'VP p2mpl']
#
#
# Results:  2
# ['C5:8', 'C75:3']

# %%
FindMention(corefs, suffix_errors, 'HWLLJM')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 5:6	C5:8	NP		HWLLJM		be infatuated
# 75:5	C75:3	NP		HWLLJM		be infatuated
# 73:3	Sing	NP		HWLLJM		be infatuated
#
#
# Results:  3
# ['C5:8', 'C75:3', '73:3-Sing']

# %%
FindClassMention(corefs, suffix_errors, 'HWLLJM')
# Out:
# C5:8 Who: HWLLJM, first: JTJYBW, type: VP, corpus class: 43
#
# verse	type	pgn	ann		gloss	note
# 6	VP	p3mpl	JTJYBW     	stand
# 6	NP		HWLLJM     	be infatuated
# Pattern:  ['VP p3mpl', 'NP']
#
#
# C75:3 Who: HWLLJM, first: HWLLJM, type: NP, corpus class: 997
#
# verse	type	pgn	ann		gloss	note
# 5	NP		HWLLJM     	be infatuated
# 5	VP	p2mpl	THLW     	be infatuated
# Pattern:  ['NP', 'VP p2mpl']
#
#
# Results:  2
# ['C5:8', 'C75:3']

# %% [markdown]
# #### THLW

# %%
FindMention(corefs, suffix_errors, 'THLW')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 75:5	C75:3	VP	p2mpl	THLW		be infatuated
#
#
# Results:  1
# ['C75:3']

# %% [markdown]
# ### C75:6 Who/what: RC<JM / first: RC<JM, type: NP

# %%
FindWho(corefs, suffix_errors, ['RC<JM'])
# Out:
# C11:2 Who: RC<JM, first: RC<JM, type: NP, corpus class: 111
#
# verse	type	pgn	ann		gloss	note
# 2	NP		RC<JM     	guilty
# 2	VP	p3mpl	JDRKWN     	tread
# 2	VP	p3upl	KWNNW     	be firm
# 2	PPrP	p3mpl	M
# 5	NP		RC<     	guilty
# 6	NP		RC<JM     	guilty
# 6	PPrP	p3mpl	M
# Pattern:  ['NP', 'VP p3mpl', 'VP p3upl', 'Sfx p3mpl', 'NP', 'NP', 'Sfx p3mpl']
#
#
# C12:10 Who: RC<JM, first: RC<JM, type: NP, corpus class: 127
#
# verse	type	pgn	ann		gloss	note
# 9	NP		RC<JM     	guilty
# 9	VP	p3mpl	JTHLKWN     	walk
# Pattern:  ['NP', 'VP p3mpl']
#
#
# C28:1 Who: RC<JM, first: RC<JM, type: NP, corpus class: 316
#
# verse	type	pgn	ann		gloss	note
# 3	NP		RC<JM     	guilty
# 3	NP		P<LJ >WN     	make
# 3	VP	umpl	DBRJ     	speak
# 3	PPrP	p3mpl	HM
# 3	PPrP	p3mpl	M
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	M
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	M
# 4	PPrP	p3mpl	HM
# 5	VP	p3mpl	JBJNW     	understand
# 5	PPrP	p3mpl	M
# 5	PPrP	p3mpl	M
# Pattern:  ['NP', 'NP', 'VP umpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl']
#
#
# C31:11 Who: RC<JM, first: JBCW, type: VP, corpus class: 345
#
# verse	type	pgn	ann		gloss	note
# 18	VP	p3mpl	JBCW     	be ashamed
# 18	NP		RC<JM     	guilty
# 18	VP	p3mpl	JDMW     	rest
# Pattern:  ['VP p3mpl', 'NP', 'VP p3mpl']
#
#
# C58:2 Who: RC<JM, first: ZRW, type: VP, corpus class: 729
#
# verse	type	pgn	ann		gloss	note
# 4	VP	p3upl	ZRW     	scatter
# 4	NP		RC<JM     	guilty
# 4	VP	p3upl	T<W     	err
# 5	PPrP	p3mpl	MW
# 8	VP	p3mpl	JM>SW     	dissolve	Does the 3Mpl refer to the "lions" or to the "wicked" in v.4?
# 8	PPrP	p3mpl	MW
# 8	VP	p3msg	JDRK     	tread
# 8	PPrP	p3msg	W
# Pattern:  ['VP p3upl', 'NP', 'VP p3upl', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'VP p3msg', 'Sfx p3msg']
#
#
# C68:3 Who: RC<JM, first: J>BDW, type: VP, corpus class: 841
#
# verse	type	pgn	ann		gloss	note
# 3	VP	p3mpl	J>BDW     	perish
# 3	NP		RC<JM     	guilty
# Pattern:  ['VP p3mpl', 'NP']
#
#
# C75:6 Who: RC<JM, first: RC<JM, type: NP, corpus class: 998
#
# verse	type	pgn	ann		gloss	note
# 5	NP		RC<JM     	guilty
# 5	VP	p2mpl	TRJMW     	be high
# 6	VP	p2mpl	TRJMW     	be high
# 6	PPrP	p2mpl	KM
# 6	VP	p2mpl	TDBRW     	speak
# 9	VP	p3mpl	JMYW     	drain
# 9	VP	p3mpl	JCTW     	drink
# 9	NP		KL RC<J&>RY     	whole
# 11	NP		KL&QRNJ RC<JM     	whole
# Pattern:  ['NP', 'VP p2mpl', 'VP p2mpl', 'Sfx p2mpl', 'VP p2mpl', 'VP p3mpl', 'VP p3mpl', 'NP', 'NP']
#
#
# C92:8 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1251
#
# verse	type	pgn	ann		gloss	note
# 8	NP		RC<JM     	guilty
# 8	VP	p3mpl	JYJYW     	blossom
# 8	NP		KL&P<LJ >WN     	whole
# 8	PPrP	p3mpl	M
# Pattern:  ['NP', 'VP p3mpl', 'NP', 'Sfx p3mpl']
#
#
# C94:1 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1266
#
# verse	type	pgn	ann		gloss	note
# 3	NP		RC<JM     	guilty
# 3	NP		RC<JM     	guilty
# 3	VP	p3mpl	J<LZW     	rejoice
# Pattern:  ['NP', 'NP', 'VP p3mpl']
#
#
# C104:33 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1419
#
# verse	type	pgn	ann		gloss	note
# 35	NP		RC<JM     	guilty
# 35	PPrP	p3mpl	M
# Pattern:  ['NP', 'Sfx p3mpl']
#
#
# C119:32 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1667
#
# verse	type	pgn	ann		gloss	note
# 53	NP		RC<JM     	guilty
# 53	VP	umpl	<ZBJ     	leave
# 95	VP	p3upl	QWW     	wait for
# 95	NP		RC<JM     	guilty
# 95	VP	uuu	>BD     	perish	Infc with PreO.
# 110	VP	p3upl	NTNW     	give
# 110	NP		RC<JM     	guilty
# 155	NP		RC<JM     	guilty
# 155	VP	p3upl	DRCW     	inquire
# Pattern:  ['NP', 'VP umpl', 'VP p3upl', 'NP', 'VP uuu', 'VP p3upl', 'NP', 'NP', 'VP p3upl']
#
#
# C141:13 Who: RC<JM, first: JPLW, type: VP, corpus class: 1893
#
# verse	type	pgn	ann		gloss	note
# 10	VP	p3mpl	JPLW     	fall
# 10	PPrP	p3msg	W
# 10	NP		RC<JM     	guilty
# Pattern:  ['VP p3mpl', 'Sfx p3msg', 'NP']
#
#
# Results:  12
# ['C11:2',
#  'C12:10',
#  'C28:1',
#  'C31:11',
#  'C58:2',
#  'C68:3',
#  'C75:6',
#  'C92:8',
#  'C94:1',
#  'C104:33',
#  'C119:32',
#  'C141:13']

# %%
FindClassMention(corefs, suffix_errors, 'RC<JM')
# Out:
# C1:4 Who: <YT RC<JM, first: <YT RC<JM, type: NP, corpus class: 3
#
# verse	type	pgn	ann		gloss	note
# 1	NP		<YT RC<JM     	counsel
# 4	NP		RC<JM     	guilty
# 5	VP	p3mpl	JQMW     	arise
# 5	NP		RC<JM     	guilty
# 6	NP		DRK RC<JM     	way
# 6	VP	p3fsg	T>BD     	perish
# Pattern:  ['NP', 'NP', 'VP p3mpl', 'NP', 'NP', 'VP p3fsg']
#
#
# C1:4 Who: <YT RC<JM, first: <YT RC<JM, type: NP, corpus class: 4
#
# verse	type	pgn	ann		gloss	note
# 1	NP		<YT RC<JM     	counsel
# 4	NP		RC<JM     	guilty
# 5	VP	p3mpl	JQMW     	arise
# 5	NP		RC<JM     	guilty
# 6	NP		DRK RC<JM     	way
# 6	VP	p3fsg	T>BD     	perish
# Pattern:  ['NP', 'NP', 'VP p3mpl', 'NP', 'NP', 'VP p3fsg']
#
#
# C9:14 Who: RC<, first: RC<, type: NP, corpus class: 81
#
# verse	type	pgn	ann		gloss	note
# 6	NP		RC<     	guilty
# 6	PPrP	p3mpl	M    		    	Corefers with the "wicked": "destroy the wicked - blot out their name".
# 17	PPrP	p3msg	W
# 17	VP	umsg	NWQC     	ensnare
# 17	NP		RC<     	guilty
# 18	VP	p3mpl	JCWBW     	return
# 18	NP		RC<JM     	guilty
# Pattern:  ['NP', 'Sfx p3mpl', 'Sfx p3msg', 'VP umsg', 'NP', 'VP p3mpl', 'NP']
#
#
# C11:2 Who: RC<JM, first: RC<JM, type: NP, corpus class: 111
#
# verse	type	pgn	ann		gloss	note
# 2	NP		RC<JM     	guilty
# 2	VP	p3mpl	JDRKWN     	tread
# 2	VP	p3upl	KWNNW     	be firm
# 2	PPrP	p3mpl	M
# 5	NP		RC<     	guilty
# 6	NP		RC<JM     	guilty
# 6	PPrP	p3mpl	M
# Pattern:  ['NP', 'VP p3mpl', 'VP p3upl', 'Sfx p3mpl', 'NP', 'NP', 'Sfx p3mpl']
#
#
# C11:2 Who: RC<JM, first: RC<JM, type: NP, corpus class: 112
#
# verse	type	pgn	ann		gloss	note
# 2	NP		RC<JM     	guilty
# 2	VP	p3mpl	JDRKWN     	tread
# 2	VP	p3upl	KWNNW     	be firm
# 2	PPrP	p3mpl	M
# 5	NP		RC<     	guilty
# 6	NP		RC<JM     	guilty
# 6	PPrP	p3mpl	M
# Pattern:  ['NP', 'VP p3mpl', 'VP p3upl', 'Sfx p3mpl', 'NP', 'NP', 'Sfx p3mpl']
#
#
# C12:10 Who: RC<JM, first: RC<JM, type: NP, corpus class: 127
#
# verse	type	pgn	ann		gloss	note
# 9	NP		RC<JM     	guilty
# 9	VP	p3mpl	JTHLKWN     	walk
# Pattern:  ['NP', 'VP p3mpl']
#
#
# C28:1 Who: RC<JM, first: RC<JM, type: NP, corpus class: 316
#
# verse	type	pgn	ann		gloss	note
# 3	NP		RC<JM     	guilty
# 3	NP		P<LJ >WN     	make
# 3	VP	umpl	DBRJ     	speak
# 3	PPrP	p3mpl	HM
# 3	PPrP	p3mpl	M
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	M
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	HM
# 4	PPrP	p3mpl	M
# 4	PPrP	p3mpl	HM
# 5	VP	p3mpl	JBJNW     	understand
# 5	PPrP	p3mpl	M
# 5	PPrP	p3mpl	M
# Pattern:  ['NP', 'NP', 'VP umpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl']
#
#
# C31:11 Who: RC<JM, first: JBCW, type: VP, corpus class: 345
#
# verse	type	pgn	ann		gloss	note
# 18	VP	p3mpl	JBCW     	be ashamed
# 18	NP		RC<JM     	guilty
# 18	VP	p3mpl	JDMW     	rest
# Pattern:  ['VP p3mpl', 'NP', 'VP p3mpl']
#
#
# C37:27 Who: RC<, first: RC<, type: NP, corpus class: 444
#
# verse	type	pgn	ann		gloss	note
# 10	NP		RC<     	guilty
# 12	VP	umsg	ZMM     	ponder
# 12	NP		RC<     	guilty
# 12	VP	umsg	XRQ     	grind
# 12	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 14	VP	p3upl	PTXW     	open
# 14	NP		RC<JM     	guilty
# 14	VP	p3upl	DRKW     	tread
# 14	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 20	NP		RC<JM     	guilty
# 20	VP	p3mpl	J>BDW     	perish
# 20	NP		>JBJ JHWH     	be hostile
# 20	VP	p3upl	KLW     	be complete
# 20	VP	p3upl	KLW     	be complete
# 21	VP	umsg	LWH     	borrow
# 21	NP		RC<     	guilty
# 32	VP	umsg	YWPH     	look out
# 32	NP		RC<     	guilty
# 32	VP	umsg	MBQC     	seek
# 32	VP	uuu	HMJT     	die	Infc with PreO.
# 33	PPrP	p3msg	W
# 33	VP	uuu	HCPV     	judge	Infc with PreO.
# 34	NP		RC<JM     	guilty
# 35	NP		RC<     	guilty
# 35	VP	umsg	MT<RH     	pour out
# 36	VP	p3msg	J<BR     	pass
# 36	PPrP	p3msg	HW
# 36	VP	p3msg	NMY>     	find
# 40	NP		RC<JM     	guilty
# Pattern:  ['NP', 'VP umsg', 'NP', 'VP umsg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3upl', 'NP', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'NP', 'VP p3mpl', 'NP', 'VP p3upl', 'VP p3upl', 'VP umsg', 'NP', 'VP umsg', 'NP', 'VP umsg', 'VP uuu', 'Sfx p3msg', 'VP uuu', 'NP', 'NP', 'VP umsg', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'NP']
#
#
# C37:27 Who: RC<, first: RC<, type: NP, corpus class: 445
#
# verse	type	pgn	ann		gloss	note
# 10	NP		RC<     	guilty
# 12	VP	umsg	ZMM     	ponder
# 12	NP		RC<     	guilty
# 12	VP	umsg	XRQ     	grind
# 12	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 14	VP	p3upl	PTXW     	open
# 14	NP		RC<JM     	guilty
# 14	VP	p3upl	DRKW     	tread
# 14	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 20	NP		RC<JM     	guilty
# 20	VP	p3mpl	J>BDW     	perish
# 20	NP		>JBJ JHWH     	be hostile
# 20	VP	p3upl	KLW     	be complete
# 20	VP	p3upl	KLW     	be complete
# 21	VP	umsg	LWH     	borrow
# 21	NP		RC<     	guilty
# 32	VP	umsg	YWPH     	look out
# 32	NP		RC<     	guilty
# 32	VP	umsg	MBQC     	seek
# 32	VP	uuu	HMJT     	die	Infc with PreO.
# 33	PPrP	p3msg	W
# 33	VP	uuu	HCPV     	judge	Infc with PreO.
# 34	NP		RC<JM     	guilty
# 35	NP		RC<     	guilty
# 35	VP	umsg	MT<RH     	pour out
# 36	VP	p3msg	J<BR     	pass
# 36	PPrP	p3msg	HW
# 36	VP	p3msg	NMY>     	find
# 40	NP		RC<JM     	guilty
# Pattern:  ['NP', 'VP umsg', 'NP', 'VP umsg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3upl', 'NP', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'NP', 'VP p3mpl', 'NP', 'VP p3upl', 'VP p3upl', 'VP umsg', 'NP', 'VP umsg', 'NP', 'VP umsg', 'VP uuu', 'Sfx p3msg', 'VP uuu', 'NP', 'NP', 'VP umsg', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'NP']
#
#
# C37:27 Who: RC<, first: RC<, type: NP, corpus class: 446
#
# verse	type	pgn	ann		gloss	note
# 10	NP		RC<     	guilty
# 12	VP	umsg	ZMM     	ponder
# 12	NP		RC<     	guilty
# 12	VP	umsg	XRQ     	grind
# 12	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 14	VP	p3upl	PTXW     	open
# 14	NP		RC<JM     	guilty
# 14	VP	p3upl	DRKW     	tread
# 14	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 20	NP		RC<JM     	guilty
# 20	VP	p3mpl	J>BDW     	perish
# 20	NP		>JBJ JHWH     	be hostile
# 20	VP	p3upl	KLW     	be complete
# 20	VP	p3upl	KLW     	be complete
# 21	VP	umsg	LWH     	borrow
# 21	NP		RC<     	guilty
# 32	VP	umsg	YWPH     	look out
# 32	NP		RC<     	guilty
# 32	VP	umsg	MBQC     	seek
# 32	VP	uuu	HMJT     	die	Infc with PreO.
# 33	PPrP	p3msg	W
# 33	VP	uuu	HCPV     	judge	Infc with PreO.
# 34	NP		RC<JM     	guilty
# 35	NP		RC<     	guilty
# 35	VP	umsg	MT<RH     	pour out
# 36	VP	p3msg	J<BR     	pass
# 36	PPrP	p3msg	HW
# 36	VP	p3msg	NMY>     	find
# 40	NP		RC<JM     	guilty
# Pattern:  ['NP', 'VP umsg', 'NP', 'VP umsg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3upl', 'NP', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'NP', 'VP p3mpl', 'NP', 'VP p3upl', 'VP p3upl', 'VP umsg', 'NP', 'VP umsg', 'NP', 'VP umsg', 'VP uuu', 'Sfx p3msg', 'VP uuu', 'NP', 'NP', 'VP umsg', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'NP']
#
#
# C37:27 Who: RC<, first: RC<, type: NP, corpus class: 447
#
# verse	type	pgn	ann		gloss	note
# 10	NP		RC<     	guilty
# 12	VP	umsg	ZMM     	ponder
# 12	NP		RC<     	guilty
# 12	VP	umsg	XRQ     	grind
# 12	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 13	PPrP	p3msg	W
# 14	VP	p3upl	PTXW     	open
# 14	NP		RC<JM     	guilty
# 14	VP	p3upl	DRKW     	tread
# 14	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 15	PPrP	p3mpl	M
# 20	NP		RC<JM     	guilty
# 20	VP	p3mpl	J>BDW     	perish
# 20	NP		>JBJ JHWH     	be hostile
# 20	VP	p3upl	KLW     	be complete
# 20	VP	p3upl	KLW     	be complete
# 21	VP	umsg	LWH     	borrow
# 21	NP		RC<     	guilty
# 32	VP	umsg	YWPH     	look out
# 32	NP		RC<     	guilty
# 32	VP	umsg	MBQC     	seek
# 32	VP	uuu	HMJT     	die	Infc with PreO.
# 33	PPrP	p3msg	W
# 33	VP	uuu	HCPV     	judge	Infc with PreO.
# 34	NP		RC<JM     	guilty
# 35	NP		RC<     	guilty
# 35	VP	umsg	MT<RH     	pour out
# 36	VP	p3msg	J<BR     	pass
# 36	PPrP	p3msg	HW
# 36	VP	p3msg	NMY>     	find
# 40	NP		RC<JM     	guilty
# Pattern:  ['NP', 'VP umsg', 'NP', 'VP umsg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3upl', 'NP', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'NP', 'VP p3mpl', 'NP', 'VP p3upl', 'VP p3upl', 'VP umsg', 'NP', 'VP umsg', 'NP', 'VP umsg', 'VP uuu', 'Sfx p3msg', 'VP uuu', 'NP', 'NP', 'VP umsg', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'NP']
#
#
# C58:2 Who: RC<JM, first: ZRW, type: VP, corpus class: 729
#
# verse	type	pgn	ann		gloss	note
# 4	VP	p3upl	ZRW     	scatter
# 4	NP		RC<JM     	guilty
# 4	VP	p3upl	T<W     	err
# 5	PPrP	p3mpl	MW
# 8	VP	p3mpl	JM>SW     	dissolve	Does the 3Mpl refer to the "lions" or to the "wicked" in v.4?
# 8	PPrP	p3mpl	MW
# 8	VP	p3msg	JDRK     	tread
# 8	PPrP	p3msg	W
# Pattern:  ['VP p3upl', 'NP', 'VP p3upl', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'VP p3msg', 'Sfx p3msg']
#
#
# C68:3 Who: RC<JM, first: J>BDW, type: VP, corpus class: 841
#
# verse	type	pgn	ann		gloss	note
# 3	VP	p3mpl	J>BDW     	perish
# 3	NP		RC<JM     	guilty
# Pattern:  ['VP p3mpl', 'NP']
#
#
# C73:10 Who: CLWM RC<JM, first: CLWM RC<JM, type: NP, corpus class: 958
#
# verse	type	pgn	ann		gloss	note
# 3	NP		CLWM RC<JM     	peace
# 4	PPrP	p3mpl	M
# 4	PPrP	p3mpl	M
# 5	PPrP	p3mpl	MW
# 5	VP	p3mpl	JNG<W     	touch
# 6	PPrP	p3mpl	MW
# 6	PPrP	p3mpl	MW
# 7	PPrP	p3mpl	MW
# 8	VP	p3mpl	JMJQW     	<uncertain>
# 8	VP	p3mpl	JDBRW     	speak
# 8	VP	p3mpl	JDBRW     	speak
# 9	VP	p3upl	CTW     	put
# 9	PPrP	p3mpl	HM
# 9	PPrP	p3mpl	M
# 10	PPrP	p3mpl	MW
# 11	VP	p3upl	>MRW     	say
# 12	DPrP		>LH     	these
# 12	NP		RC<JM     	guilty
# 18	PPrP	p3mpl	MW
# 18	PPrP	p3mpl	M
# 19	VP	p3upl	HJW     	be
# 19	VP	p3upl	SPW     	end
# 19	VP	p3upl	TMW     	be complete
# 20	PPrP	p3mpl	M
# Pattern:  ['NP', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3mpl', 'VP p3mpl', 'VP p3mpl', 'VP p3upl', 'Sfx p3mpl', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3upl', 'DPrP', 'NP', 'Sfx p3mpl', 'Sfx p3mpl', 'VP p3upl', 'VP p3upl', 'VP p3upl', 'Sfx p3mpl']
#
#
# C75:6 Who: RC<JM, first: RC<JM, type: NP, corpus class: 998
#
# verse	type	pgn	ann		gloss	note
# 5	NP		RC<JM     	guilty
# 5	VP	p2mpl	TRJMW     	be high
# 6	VP	p2mpl	TRJMW     	be high
# 6	PPrP	p2mpl	KM
# 6	VP	p2mpl	TDBRW     	speak
# 9	VP	p3mpl	JMYW     	drain
# 9	VP	p3mpl	JCTW     	drink
# 9	NP		KL RC<J&>RY     	whole
# 11	NP		KL&QRNJ RC<JM     	whole
# Pattern:  ['NP', 'VP p2mpl', 'VP p2mpl', 'Sfx p2mpl', 'VP p2mpl', 'VP p3mpl', 'VP p3mpl', 'NP', 'NP']
#
#
# C92:8 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1251
#
# verse	type	pgn	ann		gloss	note
# 8	NP		RC<JM     	guilty
# 8	VP	p3mpl	JYJYW     	blossom
# 8	NP		KL&P<LJ >WN     	whole
# 8	PPrP	p3mpl	M
# Pattern:  ['NP', 'VP p3mpl', 'NP', 'Sfx p3mpl']
#
#
# C94:1 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1266
#
# verse	type	pgn	ann		gloss	note
# 3	NP		RC<JM     	guilty
# 3	NP		RC<JM     	guilty
# 3	VP	p3mpl	J<LZW     	rejoice
# Pattern:  ['NP', 'NP', 'VP p3mpl']
#
#
# C94:1 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1267
#
# verse	type	pgn	ann		gloss	note
# 3	NP		RC<JM     	guilty
# 3	NP		RC<JM     	guilty
# 3	VP	p3mpl	J<LZW     	rejoice
# Pattern:  ['NP', 'NP', 'VP p3mpl']
#
#
# C104:33 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1419
#
# verse	type	pgn	ann		gloss	note
# 35	NP		RC<JM     	guilty
# 35	PPrP	p3mpl	M
# Pattern:  ['NP', 'Sfx p3mpl']
#
#
# C119:32 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1667
#
# verse	type	pgn	ann		gloss	note
# 53	NP		RC<JM     	guilty
# 53	VP	umpl	<ZBJ     	leave
# 95	VP	p3upl	QWW     	wait for
# 95	NP		RC<JM     	guilty
# 95	VP	uuu	>BD     	perish	Infc with PreO.
# 110	VP	p3upl	NTNW     	give
# 110	NP		RC<JM     	guilty
# 155	NP		RC<JM     	guilty
# 155	VP	p3upl	DRCW     	inquire
# Pattern:  ['NP', 'VP umpl', 'VP p3upl', 'NP', 'VP uuu', 'VP p3upl', 'NP', 'NP', 'VP p3upl']
#
#
# C119:32 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1668
#
# verse	type	pgn	ann		gloss	note
# 53	NP		RC<JM     	guilty
# 53	VP	umpl	<ZBJ     	leave
# 95	VP	p3upl	QWW     	wait for
# 95	NP		RC<JM     	guilty
# 95	VP	uuu	>BD     	perish	Infc with PreO.
# 110	VP	p3upl	NTNW     	give
# 110	NP		RC<JM     	guilty
# 155	NP		RC<JM     	guilty
# 155	VP	p3upl	DRCW     	inquire
# Pattern:  ['NP', 'VP umpl', 'VP p3upl', 'NP', 'VP uuu', 'VP p3upl', 'NP', 'NP', 'VP p3upl']
#
#
# C119:32 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1669
#
# verse	type	pgn	ann		gloss	note
# 53	NP		RC<JM     	guilty
# 53	VP	umpl	<ZBJ     	leave
# 95	VP	p3upl	QWW     	wait for
# 95	NP		RC<JM     	guilty
# 95	VP	uuu	>BD     	perish	Infc with PreO.
# 110	VP	p3upl	NTNW     	give
# 110	NP		RC<JM     	guilty
# 155	NP		RC<JM     	guilty
# 155	VP	p3upl	DRCW     	inquire
# Pattern:  ['NP', 'VP umpl', 'VP p3upl', 'NP', 'VP uuu', 'VP p3upl', 'NP', 'NP', 'VP p3upl']
#
#
# C119:32 Who: RC<JM, first: RC<JM, type: NP, corpus class: 1670
#
# verse	type	pgn	ann		gloss	note
# 53	NP		RC<JM     	guilty
# 53	VP	umpl	<ZBJ     	leave
# 95	VP	p3upl	QWW     	wait for
# 95	NP		RC<JM     	guilty
# 95	VP	uuu	>BD     	perish	Infc with PreO.
# 110	VP	p3upl	NTNW     	give
# 110	NP		RC<JM     	guilty
# 155	NP		RC<JM     	guilty
# 155	VP	p3upl	DRCW     	inquire
# Pattern:  ['NP', 'VP umpl', 'VP p3upl', 'NP', 'VP uuu', 'VP p3upl', 'NP', 'NP', 'VP p3upl']
#
#
# C141:13 Who: RC<JM, first: JPLW, type: VP, corpus class: 1893
#
# verse	type	pgn	ann		gloss	note
# 10	VP	p3mpl	JPLW     	fall
# 10	PPrP	p3msg	W
# 10	NP		RC<JM     	guilty
# Pattern:  ['VP p3mpl', 'Sfx p3msg', 'NP']
#
#
# Results:  16
# ['C104:33',
#  'C119:32',
#  'C11:2',
#  'C12:10',
#  'C141:13',
#  'C1:4',
#  'C28:1',
#  'C31:11',
#  'C37:27',
#  'C58:2',
#  'C68:3',
#  'C73:10',
#  'C75:6',
#  'C92:8',
#  'C94:1',
#  'C9:14']

# %%
# First: True, False: whitespace
# Other possible searches: 'RC<JM', '>SP', 'MLK', 'TWRT', 'JHWH'

FindMention(corefs, suffix_errors, 'RC<JM')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 1:4	C1:4	NP		RC<JM		guilty
# 1:5	C1:4	NP		RC<JM		guilty
# 9:18	C9:14	NP		RC<JM		guilty
# 11:2	C11:2	NP		RC<JM		guilty
# 11:6	C11:2	NP		RC<JM		guilty
# 12:9	C12:10	NP		RC<JM		guilty
# 28:3	C28:1	NP		RC<JM		guilty
# 31:18	C31:11	NP		RC<JM		guilty
# 37:14	C37:27	NP		RC<JM		guilty
# 37:20	C37:27	NP		RC<JM		guilty
# 37:34	C37:27	NP		RC<JM		guilty
# 37:40	C37:27	NP		RC<JM		guilty
# 58:4	C58:2	NP		RC<JM		guilty
# 68:3	C68:3	NP		RC<JM		guilty
# 73:12	C73:10	NP		RC<JM		guilty
# 75:5	C75:6	NP		RC<JM		guilty
# 92:8	C92:8	NP		RC<JM		guilty
# 94:3	C94:1	NP		RC<JM		guilty
# 94:3	C94:1	NP		RC<JM		guilty
# 104:35	C104:33	NP		RC<JM		guilty
# 119:53	C119:32	NP		RC<JM		guilty
# 119:95	C119:32	NP		RC<JM		guilty
# 119:110	C119:32	NP		RC<JM		guilty
# 119:155	C119:32	NP		RC<JM		guilty
# 141:10	C141:13	NP		RC<JM		guilty
# 26:5	Sing	NP		RC<JM		guilty
# 106:18	Sing	NP		RC<JM		guilty
# 147:6	Sing	NP		RC<JM		guilty
#
#
# Results:  28
# ['C1:4',
#  'C1:4',
#  'C9:14',
#  'C11:2',
#  'C11:2',
#  'C12:10',
#  'C28:1',
#  'C31:11',
#  'C37:27',
#  'C37:27',
#  'C37:27',
#  'C37:27',
#  'C58:2',
#  'C68:3',
#  'C73:10',
#  'C75:6',
#  'C92:8',
#  'C94:1',
#  'C94:1',
#  'C104:33',
#  'C119:32',
#  'C119:32',
#  'C119:32',
#  'C119:32',
#  'C141:13',
#  '26:5-Sing',
#  '106:18-Sing',
#  '147:6-Sing']

# %% [markdown]
# ### C75:10 Who/what: QRN / first: QRN, type: NP

# %%
lst = FindMention(corefs, suffix_errors, 'QRN')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 75:5	C75:10	NP		QRN		horn
# 75:6	C75:10	NP		QRN		horn
# 89:18	C89:17	NP		QRN		horn
# 89:25	C89:23	NP		QRN		horn
# 112:9	C112:11	NP		QRN		horn
# 92:11	Sing	NP		QRN		horn
# 132:17	Sing	NP		QRN		horn
# 148:14	Sing	NP		QRN		horn
#
#
# Results:  8

# %%
FindWho(corefs, suffix_errors, ['QRN'])
# Out:
# C75:10 Who: QRN, first: QRN, type: NP, corpus class: 999
#
# verse	type	pgn	ann		gloss	note
# 5	NP		QRN     	horn
# 6	NP		QRN     	horn
# Pattern:  ['NP', 'NP']
#
#
# C89:17 Who: QRN, first: TRJM, type: VP, corpus class: 1204
#
# verse	type	pgn	ann		gloss	note
# 18	VP	p3fsg	TRJM     	be high
# 18	NP		QRN     	horn
# Pattern:  ['VP p3fsg', 'NP']
#
#
# C89:23 Who: QRN, first: TRWM, type: VP, corpus class: 1209
#
# verse	type	pgn	ann		gloss	note
# 25	VP	p3fsg	TRWM     	be high
# 25	NP		QRN     	horn
# Pattern:  ['VP p3fsg', 'NP']
#
#
# C112:11 Who: QRN, first: QRN, type: NP, corpus class: 1564
#
# verse	type	pgn	ann		gloss	note
# 9	NP		QRN     	horn
# 9	VP	p3fsg	TRWM     	be high
# Pattern:  ['NP', 'VP p3fsg']
#
#
# Results:  4
# ['C75:10', 'C89:17', 'C89:23', 'C112:11']

# %%
#FindMention(corefs, suffix_errors, 'KL&QRNJ RC<JM') Results:  0
#FindMention(corefs, suffix_errors, 'KL QRNJ RC<JM')  Results:  0
#FindMention(corefs, suffix_errors, 'QRNJ RC<JM') Results:  0
#FindMention(corefs, suffix_errors, 'QRNJ RC<') Results:  0
FindMention(corefs, suffix_errors, 'KL QRNJ RC<') #Results:  0
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
#
#
# Results:  0
# []

# %% [markdown]
# ### C75:5 Who/what: JJN / first: JJN, type: NP

# %%
FindMention(corefs, suffix_errors, 'JJN')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 75:9	C75:5	NP		JJN		wine
# 104:15	C104:10	NP		JJN		wine
# 60:5	Sing	NP		JJN		wine
# 78:65	Sing	NP		JJN		wine
#
#
# Results:  4
# ['C75:5', 'C104:10', '60:5-Sing', '78:65-Sing']

# %%
FindWho(corefs, suffix_errors, ['JJN'])
# Out:
# C75:5 Who: JJN, first: JJN, type: NP, corpus class: 1000
#
# verse	type	pgn	ann		gloss	note
# 9	NP		JJN     	wine
# 9	VP	p3msg	XMR     	cover
# 9	DPrP		ZH     	this
# 9	PPrP	p3fsg	H
# Pattern:  ['NP', 'VP p3msg', 'DPrP', 'Sfx p3fsg']
#
#
# C104:10 Who: JJN, first: JJN, type: NP, corpus class: 1399
#
# verse	type	pgn	ann		gloss	note
# 15	NP		JJN     	wine
# 15	VP	p3msg	JFMX     	rejoice
# Pattern:  ['NP', 'VP p3msg']
#
#
# Results:  2
# ['C75:5', 'C104:10']

# %% [markdown]
# #### KWS

# %%
FindMention(corefs, suffix_errors, 'KWS')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 16:5	C16:5	NP		KWS		cup	In apposition with "YHWH".
# 23:5	Sing	NP		KWS		cup
# 75:9	Sing	NP		KWS		cup
#
#
# Results:  3
# ['C16:5', '23:5-Sing', '75:9-Sing']

# %% [markdown]
# #### XMR

# %%
FindMention(corefs, suffix_errors, 'XMR')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 75:9	C75:5	VP	p3msg	XMR		cover
#
#
# Results:  1
# ['C75:5']

# %% [markdown]
# ### C75:7 Who/what: >GJD / first: >NJ, type: PPrP

# %% [markdown]
# #### Personal Pronoun >NJ

# %%
FindFirst(corefs, suffix_errors, 'PPrP', ['>NJ']) # 'PPrP', >NJ'
# Out:
# C41:7 Who: >MRTJ, first: >NJ, type: PPrP, corpus class: 519
#
# verse	type	pgn	ann		gloss	note
# 5	PPrP	p1usg	>NJ     	i	Who is 1Csg?
# 5	VP	p1usg	>MRTJ     	say
# 5	PPrP	p1usg	NJ
# 5	PPrP	p1usg	J
# 5	VP	p1usg	XV>TJ     	miss
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 6	VP	p3msg	JMWT     	die
# 6	PPrP	p3msg	W
# 8	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 9	PPrP	p3msg	W
# 9	VP	p3msg	CKB     	lie down
# 9	VP	p3msg	JWSJP     	add
# 10	PPrP	p1usg	J
# 10	VP	p1usg	BVXTJ     	trust
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	NJ
# 11	VP	p1usg	>CLMH     	be complete
# 12	VP	p1usg	JD<TJ     	know
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 13	PPrP	p1usg	>NJ     	i
# 13	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 13	PPrP	p1usg	NJ
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p3msg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C52:7 Who: BVXTJ, first: >NJ, type: PPrP, corpus class: 659
#
# verse	type	pgn	ann		gloss	note
# 10	PPrP	p1usg	>NJ     	i	Who is 1Csg?
# 10	VP	p1usg	BVXTJ     	trust
# 11	VP	p1usg	>WD     	praise
# 11	VP	p1usg	>QWH     	wait for
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg']
#
#
# C73:17 Who: QN>TJ, first: >NJ, type: PPrP, corpus class: 954
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	>NJ     	i
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 3	VP	p1usg	QN>TJ     	be jealous
# 3	VP	p1usg	>R>H     	see
# 13	VP	p1usg	ZKJTJ     	be clean
# 13	PPrP	p1usg	J
# 13	VP	p1usg	>RXY     	wash
# 13	PPrP	p1usg	J
# 14	VP	p1usg	>HJ     	be
# 14	PPrP	p1usg	J
# 15	VP	p1usg	>MRTJ     	say
# 15	VP	p1usg	>SPRH     	count
# 15	VP	p1usg	BGDTJ     	deal treacherously
# 16	VP	p1usg	>XCBH     	account
# 16	PPrP	p1usg	J
# 17	VP	p1usg	>BW>     	come
# 17	VP	p1usg	>BJNH     	understand
# 21	PPrP	p1usg	J
# 21	PPrP	p1usg	J
# 21	VP	p1usg	>CTWNN     	sharpen
# 22	PPrP	p1usg	>NJ     	i
# 22	VP	p1usg	>D<     	know
# 22	VP	p1usg	HJJTJ     	be
# 23	PPrP	p1usg	>NJ     	i
# 23	PPrP	p1usg	J
# 24	PPrP	p1usg	NJ
# 24	PPrP	p1usg	NJ
# 25	PPrP	p1usg	J
# 25	VP	p1usg	XPYTJ     	desire
# 26	PPrP	p1usg	J
# 26	PPrP	p1usg	J
# 26	PPrP	p1usg	J
# 26	PPrP	p1usg	J
# 28	PPrP	p1usg	>NJ     	i
# 28	PPrP	p1usg	J
# 28	VP	p1usg	CTJ     	put
# 28	PPrP	p1usg	J
# Pattern:  ['PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'PPrP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg']
#
#
# C75:7 Who: >GJD, first: >NJ, type: PPrP, corpus class: 1000
#
# verse	type	pgn	ann		gloss	note
# 10	PPrP	p1usg	>NJ     	i
# 10	VP	p1usg	>GJD     	report
# 10	VP	p1usg	>ZMRH     	sing
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'VP p1usg']
#
#
# C135:4 Who: JD<TJ, first: >NJ, type: PPrP, corpus class: 1808
#
# verse	type	pgn	ann		gloss	note
# 5	PPrP	p1usg	>NJ     	i
# 5	VP	p1usg	JD<TJ     	know
# Pattern:  ['PPrP p1usg', 'VP p1usg']
#
#
# Results:  5
# ['C41:7', 'C52:7', 'C73:17', 'C75:7', 'C135:4']

# %% [markdown]
# #### >GJD

# %%
FindMention(corefs, suffix_errors, '>GJD')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 38:19	C38:1	VP	p1usg	>GJD		report
# 71:17	C71:3	VP	p1usg	>GJD		report
# 71:18	C71:3	VP	p1usg	>GJD		report
# 75:10	C75:7	VP	p1usg	>GJD		report
# 142:3	C142:2	VP	p1usg	>GJD		report
#
#
# Results:  5
# ['C38:1', 'C71:3', 'C71:3', 'C75:7', 'C142:2']

# %% [markdown]
# #### >ZMRH

# %%
FindMention(corefs, suffix_errors, '>ZMRH')
# Out:
# ch:v class/sing	type	pgn	ann		gloss	note
#
# 18:50	C18:30	VP	p1usg	>ZMRH		sing
# 27:6	C27:3	VP	p1usg	>ZMRH		sing
# 57:8	C57:2	VP	p1usg	>ZMRH		sing
# 59:18	C59:3	VP	p1usg	>ZMRH		sing
# 61:9	C61:1	VP	p1usg	>ZMRH		sing
# 71:22	C71:3	VP	p1usg	>ZMRH		sing
# 71:23	C71:3	VP	p1usg	>ZMRH		sing
# 75:10	C75:7	VP	p1usg	>ZMRH		sing
# 101:1	C101:2	VP	p1usg	>ZMRH		sing
# 104:33	C104:31	VP	p1usg	>ZMRH		sing
# 108:2	C108:2	VP	p1usg	>ZMRH		sing
# 144:9	C144:1	VP	p1usg	>ZMRH		sing
# 146:2	C146:2	VP	p1usg	>ZMRH		sing
#
#
# Results:  13
# ['C18:30',
#  'C27:3',
#  'C57:2',
#  'C59:3',
#  'C61:1',
#  'C71:3',
#  'C71:3',
#  'C75:7',
#  'C101:2',
#  'C104:31',
#  'C108:2',
#  'C144:1',
#  'C146:2']

# %%
FindWho(corefs, suffix_errors, ['>GJD', '>ZMRH'])
# Out:
# C75:7 Who: >GJD, first: >NJ, type: PPrP, corpus class: 1001
#
# verse	type	pgn	ann		gloss	note
# 10	PPrP	p1usg	>NJ     	i
# 10	VP	p1usg	>GJD     	report
# 10	VP	p1usg	>ZMRH     	sing
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'VP p1usg']
#
#
# Results:  1
# ['C75:7']

# %%
FindClassMention(corefs, suffix_errors, '>GJD') #468
# Out:
# C38:1 Who: N<WJTJ, first: NJ, type: PPrP, corpus class: 468
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	NJ
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 7	VP	p1usg	N<WJTJ     	do wrong
# 7	VP	p1usg	CXTJ     	bow down
# 7	VP	p1usg	HLKTJ     	walk
# 8	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 9	VP	p1usg	NPWGWTJ     	grow numb
# 9	VP	p1usg	NDKJTJ     	crush
# 9	VP	p1usg	C>GTJ     	roar
# 9	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 11	PPrP	p1usg	J
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	J
# 11	PPrP	p1usg	J
# 11	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 14	PPrP	p1usg	>NJ     	i
# 14	VP	p1usg	>CM<     	hear
# 15	VP	p1usg	>HJ     	be
# 16	VP	p1usg	HWXLTJ     	wait, to hope
# 16	PPrP	p1usg	J
# 17	VP	p1usg	>MRTJ     	say
# 17	PPrP	p1usg	J
# 17	PPrP	p1usg	J
# 17	PPrP	p1usg	J
# 18	PPrP	p1usg	>NJ     	i
# 18	VP	umsg	NKWN     	be firm
# 18	PPrP	p1usg	J
# 18	PPrP	p1usg	J
# 19	PPrP	p1usg	J
# 19	VP	p1usg	>GJD     	report
# 19	VP	p1usg	>D>G     	be afraid
# 19	PPrP	p1usg	J
# 20	PPrP	p1usg	J
# 20	PPrP	p1usg	J
# 21	PPrP	p1usg	NJ
# 21	VP	uuu	RDWPJ     	pursue	Infc with PreS.
# 22	PPrP	p1usg	NJ
# 22	PPrP	p1usg	J
# 22	PPrP	p1usg	NJ
# 23	PPrP	p1usg	J
# 23	PPrP	p1usg	J
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP umsg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP uuu', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C71:3 Who: XSJTJ, first: XSJTJ, type: VP, corpus class: 921
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p1usg	XSJTJ     	seek refuge
# 1	VP	p1usg	>BWCH     	be ashamed
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	NJ
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 6	VP	p1usg	NSMKTJ     	support
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 7	VP	p1usg	HJJTJ     	be
# 7	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 9	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 11	PPrP	p3msg	W
# 11	PPrP	p3msg	HW
# 12	PPrP	p1usg	NJ
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 14	PPrP	p1usg	>NJ     	i
# 14	VP	p1usg	>JXL     	wait, to hope
# 14	VP	p1usg	HWSPTJ     	add
# 15	PPrP	p1usg	J
# 15	VP	p1usg	JD<TJ     	know
# 16	VP	p1usg	>BW>     	come
# 16	VP	p1usg	>ZKJR     	remember
# 17	PPrP	p1usg	NJ
# 17	PPrP	p1usg	J
# 17	VP	p1usg	>GJD     	report
# 18	PPrP	p1usg	NJ
# 18	VP	p1usg	>GJD     	report
# 20	PPrP	p1usg	NJ
# 21	PPrP	p1usg	J
# 21	PPrP	p1usg	NJ
# 22	PPrP	p1usg	>NJ     	i
# 22	VP	p1usg	>WD     	praise
# 22	PPrP	p1usg	J
# 22	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 23	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C71:3 Who: XSJTJ, first: XSJTJ, type: VP, corpus class: 922
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p1usg	XSJTJ     	seek refuge
# 1	VP	p1usg	>BWCH     	be ashamed
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	NJ
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 6	VP	p1usg	NSMKTJ     	support
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 7	VP	p1usg	HJJTJ     	be
# 7	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 9	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 11	PPrP	p3msg	W
# 11	PPrP	p3msg	HW
# 12	PPrP	p1usg	NJ
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 14	PPrP	p1usg	>NJ     	i
# 14	VP	p1usg	>JXL     	wait, to hope
# 14	VP	p1usg	HWSPTJ     	add
# 15	PPrP	p1usg	J
# 15	VP	p1usg	JD<TJ     	know
# 16	VP	p1usg	>BW>     	come
# 16	VP	p1usg	>ZKJR     	remember
# 17	PPrP	p1usg	NJ
# 17	PPrP	p1usg	J
# 17	VP	p1usg	>GJD     	report
# 18	PPrP	p1usg	NJ
# 18	VP	p1usg	>GJD     	report
# 20	PPrP	p1usg	NJ
# 21	PPrP	p1usg	J
# 21	PPrP	p1usg	NJ
# 22	PPrP	p1usg	>NJ     	i
# 22	VP	p1usg	>WD     	praise
# 22	PPrP	p1usg	J
# 22	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 23	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C75:7 Who: >GJD, first: >NJ, type: PPrP, corpus class: 1001
#
# verse	type	pgn	ann		gloss	note
# 10	PPrP	p1usg	>NJ     	i
# 10	VP	p1usg	>GJD     	report
# 10	VP	p1usg	>ZMRH     	sing
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'VP p1usg']
#
#
# C142:2 Who: >Z<Q, first: J, type: PPrP, corpus class: 1896
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	J
# 2	VP	p1usg	>Z<Q     	cry
# 2	PPrP	p1usg	J
# 2	VP	p1usg	>TXNN     	favour
# 3	VP	p1usg	>CPK     	pour
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 3	VP	p1usg	>GJD     	report
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	VP	p1usg	>HLK     	walk
# 4	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	NJ
# 5	PPrP	p1usg	J
# 6	VP	p1usg	Z<QTJ     	cry
# 6	VP	p1usg	>MRTJ     	say
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 7	PPrP	p1usg	J
# 7	VP	p1usg	DLWTJ     	belittle
# 7	PPrP	p1usg	NJ
# 7	PPrP	p1usg	J
# 7	PPrP	p1usg	NJ
# 8	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# Pattern:  ['Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# Results:  4
# ['C142:2', 'C38:1', 'C71:3', 'C75:7']

# %%
FindClassMention(corefs, suffix_errors, '>ZMRH')
# Out:
# C18:30 Who: >WD, first: NJ, type: PPrP, corpus class: 204
#
# verse	type	pgn	ann		gloss	note
# 49	PPrP	p1usg	NJ
# 50	VP	p1usg	>WD     	praise
# 50	VP	p1usg	>ZMRH     	sing
# Pattern:  ['Sfx p1usg', 'VP p1usg', 'VP p1usg']
#
#
# C27:3 Who: <BD, first: J, type: PPrP, corpus class: 298
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	>NJ     	i
# 3	VP	umsg	BWVX     	trust
# 4	VP	p1usg	C>LTJ     	ask
# 4	VP	p1usg	>BQC     	seek
# 4	VP	uuu	CBTJ     	sit	Infc with PreS.
# 4	PPrP	p1usg	J
# 5	PPrP	p1usg	NJ
# 5	PPrP	p1usg	NJ
# 5	PPrP	p1usg	NJ
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 6	VP	p1usg	>ZBXH     	slaughter
# 6	VP	p1usg	>CJRH     	sing
# 6	VP	p1usg	>ZMRH     	sing
# 7	PPrP	p1usg	J
# 7	VP	p1usg	>QR>     	call
# 7	PPrP	p1usg	NJ
# 7	PPrP	p1usg	NJ
# 8	PPrP	p1usg	J
# 8	VP	p2mpl	BQCW     	seek	Intuition: the heart (3Msg) addresses it's owner (2Msg) to seek YHWH's face.
# 8	VP	p1usg	>BQC     	seek
# 9	PPrP	p1usg	NJ
# 9	NP		<BD     	servant
# 9	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 9	PPrP	p1usg	NJ
# 9	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	NJ
# 10	PPrP	p1usg	NJ
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	J
# 12	PPrP	p1usg	NJ
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 13	VP	p1usg	H>MNTJ     	be firm
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP umsg', 'VP p1usg', 'VP p1usg', 'VP uuu', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p2mpl', 'VP p1usg', 'Sfx p1usg', 'NP', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# C57:2 Who: >XSH, first: NJ, type: PPrP, corpus class: 714
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	J
# 2	VP	p1usg	>XSH     	seek refuge
# 3	VP	p1usg	>QR>     	call
# 3	PPrP	p1usg	J
# 4	PPrP	p1usg	NJ
# 4	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	VP	p1usg	>CKBH     	lie down
# 7	PPrP	p1usg	J
# 7	PPrP	p1usg	J
# 7	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 8	VP	p1usg	>CJRH     	sing
# 8	VP	p1usg	>ZMRH     	sing
# 9	VP	p2msg	<WRH     	be awake
# 9	PPrP	p1usg	J
# 9	VP	p1usg	><JRH     	be awake
# 10	VP	p1usg	>WD     	praise
# 10	VP	p1usg	>ZMR     	sing
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p2msg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg']
#
#
# C59:3 Who: >CMRH, first: NJ, type: PPrP, corpus class: 743
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	NJ
# 3	PPrP	p1usg	NJ
# 3	PPrP	p1usg	NJ
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 10	PPrP	p3msg	W    		    	To whom does 3Msg refer?
# 10	VP	p1usg	>CMRH     	keep
# 10	PPrP	p1usg	J
# 11	PPrP	p3msg	W    		    	To whom does 3Msg refer?
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 17	PPrP	p1usg	>NJ     	i
# 17	VP	p1usg	>CJR     	sing
# 17	VP	p1usg	>RNN     	cry of joy
# 17	PPrP	p1usg	J
# 17	PPrP	p1usg	J
# 18	PPrP	p1usg	J
# 18	VP	p1usg	>ZMRH     	sing
# 18	PPrP	p1usg	J
# 18	PPrP	p1usg	J
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'VP p1usg', 'Sfx p1usg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C61:1 Who: >QR>, first: J, type: PPrP, corpus class: 765
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 3	VP	p1usg	>QR>     	call
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	NJ
# 3	PPrP	p1usg	NJ
# 4	PPrP	p1usg	J
# 5	VP	p1usg	>GWRH     	dwell
# 5	VP	p1usg	>XSH     	seek refuge
# 6	PPrP	p1usg	J
# 9	VP	p1usg	>ZMRH     	sing
# 9	VP	uuu	CLMJ     	be complete	Infc with PreS.
# 9	PPrP	p1usg	J
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP uuu', 'Sfx p1usg']
#
#
# C71:3 Who: XSJTJ, first: XSJTJ, type: VP, corpus class: 921
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p1usg	XSJTJ     	seek refuge
# 1	VP	p1usg	>BWCH     	be ashamed
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	NJ
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 6	VP	p1usg	NSMKTJ     	support
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 7	VP	p1usg	HJJTJ     	be
# 7	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 9	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 11	PPrP	p3msg	W
# 11	PPrP	p3msg	HW
# 12	PPrP	p1usg	NJ
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 14	PPrP	p1usg	>NJ     	i
# 14	VP	p1usg	>JXL     	wait, to hope
# 14	VP	p1usg	HWSPTJ     	add
# 15	PPrP	p1usg	J
# 15	VP	p1usg	JD<TJ     	know
# 16	VP	p1usg	>BW>     	come
# 16	VP	p1usg	>ZKJR     	remember
# 17	PPrP	p1usg	NJ
# 17	PPrP	p1usg	J
# 17	VP	p1usg	>GJD     	report
# 18	PPrP	p1usg	NJ
# 18	VP	p1usg	>GJD     	report
# 20	PPrP	p1usg	NJ
# 21	PPrP	p1usg	J
# 21	PPrP	p1usg	NJ
# 22	PPrP	p1usg	>NJ     	i
# 22	VP	p1usg	>WD     	praise
# 22	PPrP	p1usg	J
# 22	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 23	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C71:3 Who: XSJTJ, first: XSJTJ, type: VP, corpus class: 922
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p1usg	XSJTJ     	seek refuge
# 1	VP	p1usg	>BWCH     	be ashamed
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	NJ
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	NJ
# 3	PPrP	p1usg	J
# 3	PPrP	p1usg	J
# 4	PPrP	p1usg	J
# 4	PPrP	p1usg	NJ
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 5	PPrP	p1usg	J
# 6	VP	p1usg	NSMKTJ     	support
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	J
# 7	VP	p1usg	HJJTJ     	be
# 7	PPrP	p1usg	J
# 8	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 9	PPrP	p1usg	J
# 9	PPrP	p1usg	NJ
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 10	PPrP	p1usg	J
# 11	PPrP	p3msg	W
# 11	PPrP	p3msg	HW
# 12	PPrP	p1usg	NJ
# 12	PPrP	p1usg	J
# 12	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 13	PPrP	p1usg	J
# 14	PPrP	p1usg	>NJ     	i
# 14	VP	p1usg	>JXL     	wait, to hope
# 14	VP	p1usg	HWSPTJ     	add
# 15	PPrP	p1usg	J
# 15	VP	p1usg	JD<TJ     	know
# 16	VP	p1usg	>BW>     	come
# 16	VP	p1usg	>ZKJR     	remember
# 17	PPrP	p1usg	NJ
# 17	PPrP	p1usg	J
# 17	VP	p1usg	>GJD     	report
# 18	PPrP	p1usg	NJ
# 18	VP	p1usg	>GJD     	report
# 20	PPrP	p1usg	NJ
# 21	PPrP	p1usg	J
# 21	PPrP	p1usg	NJ
# 22	PPrP	p1usg	>NJ     	i
# 22	VP	p1usg	>WD     	praise
# 22	PPrP	p1usg	J
# 22	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 23	VP	p1usg	>ZMRH     	sing
# 23	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# 24	PPrP	p1usg	J
# Pattern:  ['VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C75:7 Who: >GJD, first: >NJ, type: PPrP, corpus class: 1001
#
# verse	type	pgn	ann		gloss	note
# 10	PPrP	p1usg	>NJ     	i
# 10	VP	p1usg	>GJD     	report
# 10	VP	p1usg	>ZMRH     	sing
# Pattern:  ['PPrP p1usg', 'VP p1usg', 'VP p1usg']
#
#
# C101:2 Who: >CJRH, first: >CJRH, type: VP, corpus class: 1336
#
# verse	type	pgn	ann		gloss	note
# 1	VP	p1usg	>CJRH     	sing
# 1	VP	p1usg	>ZMRH     	sing
# 2	VP	p1usg	>FKJLH     	prosper
# 2	PPrP	p1usg	J
# 2	VP	p1usg	>THLK     	walk
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 3	VP	p1usg	>CJT     	put
# 3	PPrP	p1usg	J
# 3	VP	p1usg	FN>TJ     	hate
# 3	PPrP	p1usg	J
# 4	PPrP	p1usg	NJ
# 4	VP	p1usg	>D<     	know
# 5	VP	p1usg	>YMJT     	be silent
# 5	VP	p1usg	>WKL     	be able
# 6	PPrP	p1usg	J    		    	The question here is if this is the same "I" as in previous verses. Seems to be God.
# 6	PPrP	p1usg	J
# 6	PPrP	p1usg	NJ
# 7	PPrP	p1usg	J    		    	Who is the "I" here?
# 7	PPrP	p1usg	J
# 8	VP	p1usg	>YMJT     	be silent
# Pattern:  ['VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg']
#
#
# C104:31 Who: >CJRH, first: J, type: PPrP, corpus class: 1388
#
# verse	type	pgn	ann		gloss	note
# 1	PPrP	p1usg	J
# 1	PPrP	p1usg	J
# 33	VP	p1usg	>CJRH     	sing
# 33	PPrP	p1usg	J
# 33	VP	p1usg	>ZMRH     	sing
# 33	PPrP	p1usg	J
# 33	PPrP	p1usg	J
# 34	PPrP	p1usg	J
# 34	PPrP	p1usg	>NKJ     	i
# 34	VP	p1usg	>FMX     	rejoice
# 35	PPrP	p1usg	J
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'PPrP p1usg', 'VP p1usg', 'Sfx p1usg']
#
#
# C108:2 Who: >CJRH, first: J, type: PPrP, corpus class: 1507
#
# verse	type	pgn	ann		gloss	note
# 2	PPrP	p1usg	J
# 2	VP	p1usg	>CJRH     	sing
# 2	VP	p1usg	>ZMRH     	sing
# 2	PPrP	p1usg	J
# 3	VP	p1usg	><JRH     	be awake
# 4	VP	p1usg	>WD     	praise
# 4	VP	p1usg	>ZMR     	sing
# 7	PPrP	p1usg	NJ
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	NJ
# Pattern:  ['Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C144:1 Who: XSJTJ, first: J, type: PPrP, corpus class: 1917
#
# verse	type	pgn	ann		gloss	note
# 1	PPrP	p1usg	J
# 1	PPrP	p1usg	J
# 1	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 2	VP	p1usg	XSJTJ     	seek refuge
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# 7	PPrP	p1usg	NJ
# 7	PPrP	p1usg	NJ
# 9	VP	p1usg	>CJRH     	sing
# 9	VP	p1usg	>ZMRH     	sing
# 11	PPrP	p1usg	NJ
# 11	PPrP	p1usg	NJ
# Pattern:  ['Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'Sfx p1usg', 'VP p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# C146:2 Who: >HLLH, first: J, type: PPrP, corpus class: 1954
#
# verse	type	pgn	ann		gloss	note
# 1	PPrP	p1usg	J
# 2	VP	p1usg	>HLLH     	praise
# 2	PPrP	p1usg	J
# 2	VP	p1usg	>ZMRH     	sing
# 2	PPrP	p1usg	J
# 2	PPrP	p1usg	J
# Pattern:  ['Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'VP p1usg', 'Sfx p1usg', 'Sfx p1usg']
#
#
# Results:  12
# ['C101:2',
#  'C104:31',
#  'C108:2',
#  'C144:1',
#  'C146:2',
#  'C18:30',
#  'C27:3',
#  'C57:2',
#  'C59:3',
#  'C61:1',
#  'C71:3',
#  'C75:7']

# %% [markdown]
# ### C75:8 Who/what: QRNWT YDJQ / first: TRWMMNH, type: VP

# %%
FindClassMention(corefs, suffix_errors, 'QRNWT YDJQ')

#C75:8 Who/what: QRNWT YDJQ / first: TRWMMNH, type: VP
# Out:
# C75:8 Who: QRNWT YDJQ, first: TRWMMNH, type: VP, corpus class: 1002
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p3fpl	TRWMMNH     	be high
# 11	NP		QRNWT YDJQ     	horn
# Pattern:  ['VP p3fpl', 'NP']
#
#
# Results:  1
# ['C75:8']

# %% [markdown]
# #### YDJQ

# %%
FindWho(corefs, suffix_errors, ['YDJQ'])
# Out:
# C5:12 Who: YDJQ, first: YDJQ, type: NP, corpus class: 47
#
# verse	type	pgn	ann		gloss	note
# 13	NP		YDJQ     	just
# 13	PPrP	p3msg	W
# Pattern:  ['NP', 'Sfx p3msg']
#
#
# C37:9 Who: YDJQ, first: YDJQ, type: NP, corpus class: 447
#
# verse	type	pgn	ann		gloss	note
# 12	NP		YDJQ     	just
# 12	PPrP	p3msg	W
# 16	NP		YDJQ     	just
# 17	NP		YDJQJM     	just
# 18	PPrP	p3mpl	M
# 19	VP	p3mpl	JBCW     	be ashamed
# 19	VP	p3mpl	JFB<W     	be sated
# Pattern:  ['NP', 'Sfx p3msg', 'NP', 'NP', 'Sfx p3mpl', 'VP p3mpl', 'VP p3mpl']
#
#
# C58:10 Who: YDJQ, first: JFMX, type: VP, corpus class: 737
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p3msg	JFMX     	rejoice
# 11	NP		YDJQ     	just
# 11	VP	p3msg	XZH     	see
# 11	PPrP	p3msg	W
# 11	VP	p3msg	JRXY     	wash
# 12	NP		YDJQ     	just
# Pattern:  ['VP p3msg', 'NP', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'NP']
#
#
# C64:9 Who: YDJQ, first: JFMX, type: VP, corpus class: 800
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p3msg	JFMX     	rejoice
# 11	NP		YDJQ     	just
# 11	VP	p3msg	XSH     	seek refuge
# Pattern:  ['VP p3msg', 'NP', 'VP p3msg']
#
#
# C72:3 Who: YDJQ, first: JPRX, type: VP, corpus class: 939
#
# verse	type	pgn	ann		gloss	note
# 7	VP	p3msg	JPRX     	sprout
# 7	PPrP	p3msg	W
# 7	NP		YDJQ     	just
# Pattern:  ['VP p3msg', 'Sfx p3msg', 'NP']
#
#
# C92:14 Who: YDJQ, first: YDJQ, type: NP, corpus class: 1257
#
# verse	type	pgn	ann		gloss	note
# 13	NP		YDJQ     	just
# 13	VP	p3msg	JPRX     	sprout
# 13	VP	p3msg	JFGH     	be great
# 14	VP	umpl	CTWLJM     	transplant
# 14	VP	p3mpl	JPRJXW     	sprout
# 15	VP	p3mpl	JNWBWN     	thrive
# 15	VP	p3mpl	JHJW     	be
# Pattern:  ['NP', 'VP p3msg', 'VP p3msg', 'VP umpl', 'VP p3mpl', 'VP p3mpl', 'VP p3mpl']
#
#
# C112:8 Who: YDJQ, first: JMWV, type: VP, corpus class: 1561
#
# verse	type	pgn	ann		gloss	note
# 6	VP	p3msg	JMWV     	totter
# 6	VP	p3msg	JHJH     	be
# 6	NP		YDJQ     	just
# 7	VP	p3msg	JJR>     	fear
# 7	PPrP	p3msg	W
# 8	PPrP	p3msg	W
# 8	VP	p3msg	JJR>     	fear
# 8	VP	p3msg	JR>H     	see
# 8	PPrP	p3msg	W
# 9	VP	p3msg	PZR     	scatter
# 9	VP	p3msg	NTN     	give
# 9	PPrP	p3msg	W
# 9	PPrP	p3msg	W
# Pattern:  ['VP p3msg', 'VP p3msg', 'NP', 'VP p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p3msg', 'Sfx p3msg']
#
#
# C141:5 Who: YDJQ, first: JHLM, type: VP, corpus class: 1886
#
# verse	type	pgn	ann		gloss	note
# 5	VP	p3msg	JHLM     	strike
# 5	NP		YDJQ     	just
# 5	VP	p3msg	JWKJX     	reprove
# Pattern:  ['VP p3msg', 'NP', 'VP p3msg']
#
#
# Results:  8
# ['C5:12', 'C37:9', 'C58:10', 'C64:9', 'C72:3', 'C92:14', 'C112:8', 'C141:5']

# %%
FindClassMention(corefs, suffix_errors, 'YDJQ')
# Out:
# C5:12 Who: YDJQ, first: YDJQ, type: NP, corpus class: 47
#
# verse	type	pgn	ann		gloss	note
# 13	NP		YDJQ     	just
# 13	PPrP	p3msg	W
# Pattern:  ['NP', 'Sfx p3msg']
#
#
# C11:3 Who: LB, first: LB, type: NP, corpus class: 112
#
# verse	type	pgn	ann		gloss	note
# 2	NP		LB     	heart
# 3	NP		YDJQ     	just
# 3	VP	p3msg	P<L     	make
# 5	NP		YDJQ     	just
# 7	NP		JCR     	right
# 7	VP	p3mpl	JXZW     	see
# Pattern:  ['NP', 'NP', 'VP p3msg', 'NP', 'NP', 'VP p3mpl']
#
#
# C11:3 Who: LB, first: LB, type: NP, corpus class: 113
#
# verse	type	pgn	ann		gloss	note
# 2	NP		LB     	heart
# 3	NP		YDJQ     	just
# 3	VP	p3msg	P<L     	make
# 5	NP		YDJQ     	just
# 7	NP		JCR     	right
# 7	VP	p3mpl	JXZW     	see
# Pattern:  ['NP', 'NP', 'VP p3msg', 'NP', 'NP', 'VP p3mpl']
#
#
# C37:9 Who: YDJQ, first: YDJQ, type: NP, corpus class: 447
#
# verse	type	pgn	ann		gloss	note
# 12	NP		YDJQ     	just
# 12	PPrP	p3msg	W
# 16	NP		YDJQ     	just
# 17	NP		YDJQJM     	just
# 18	PPrP	p3mpl	M
# 19	VP	p3mpl	JBCW     	be ashamed
# 19	VP	p3mpl	JFB<W     	be sated
# Pattern:  ['NP', 'Sfx p3msg', 'NP', 'NP', 'Sfx p3mpl', 'VP p3mpl', 'VP p3mpl']
#
#
# C37:9 Who: YDJQ, first: YDJQ, type: NP, corpus class: 448
#
# verse	type	pgn	ann		gloss	note
# 12	NP		YDJQ     	just
# 12	PPrP	p3msg	W
# 16	NP		YDJQ     	just
# 17	NP		YDJQJM     	just
# 18	PPrP	p3mpl	M
# 19	VP	p3mpl	JBCW     	be ashamed
# 19	VP	p3mpl	JFB<W     	be sated
# Pattern:  ['NP', 'Sfx p3msg', 'NP', 'NP', 'Sfx p3mpl', 'VP p3mpl', 'VP p3mpl']
#
#
# C37:22 Who: NXLT, first: NXLT, type: NP, corpus class: 452
#
# verse	type	pgn	ann		gloss	note
# 18	NP		NXLT     	heritage
# 18	VP	p3fsg	THJH     	be
# 21	VP	p3msg	JCLM     	be complete
# 21	NP		YDJQ     	just
# 21	VP	umsg	XWNN     	favour
# 21	VP	umsg	NWTN     	give
# 25	NP		YDJQ     	just
# 25	VP	umsg	N<ZB     	leave
# 25	PPrP	p3msg	W
# 26	VP	umsg	XWNN     	favour
# 26	VP	umsg	MLWH     	borrow
# 26	PPrP	p3msg	W
# 29	NP		YDJQJM     	just
# 29	VP	p3mpl	JJRCW     	trample down
# 29	VP	p3mpl	JCKNW     	dwell
# 32	NP		YDJQ     	just
# 32	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# Pattern:  ['NP', 'VP p3fsg', 'VP p3msg', 'NP', 'VP umsg', 'VP umsg', 'NP', 'VP umsg', 'Sfx p3msg', 'VP umsg', 'VP umsg', 'Sfx p3msg', 'NP', 'VP p3mpl', 'VP p3mpl', 'NP', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg']
#
#
# C37:22 Who: NXLT, first: NXLT, type: NP, corpus class: 453
#
# verse	type	pgn	ann		gloss	note
# 18	NP		NXLT     	heritage
# 18	VP	p3fsg	THJH     	be
# 21	VP	p3msg	JCLM     	be complete
# 21	NP		YDJQ     	just
# 21	VP	umsg	XWNN     	favour
# 21	VP	umsg	NWTN     	give
# 25	NP		YDJQ     	just
# 25	VP	umsg	N<ZB     	leave
# 25	PPrP	p3msg	W
# 26	VP	umsg	XWNN     	favour
# 26	VP	umsg	MLWH     	borrow
# 26	PPrP	p3msg	W
# 29	NP		YDJQJM     	just
# 29	VP	p3mpl	JJRCW     	trample down
# 29	VP	p3mpl	JCKNW     	dwell
# 32	NP		YDJQ     	just
# 32	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# Pattern:  ['NP', 'VP p3fsg', 'VP p3msg', 'NP', 'VP umsg', 'VP umsg', 'NP', 'VP umsg', 'Sfx p3msg', 'VP umsg', 'VP umsg', 'Sfx p3msg', 'NP', 'VP p3mpl', 'VP p3mpl', 'NP', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg']
#
#
# C37:22 Who: NXLT, first: NXLT, type: NP, corpus class: 454
#
# verse	type	pgn	ann		gloss	note
# 18	NP		NXLT     	heritage
# 18	VP	p3fsg	THJH     	be
# 21	VP	p3msg	JCLM     	be complete
# 21	NP		YDJQ     	just
# 21	VP	umsg	XWNN     	favour
# 21	VP	umsg	NWTN     	give
# 25	NP		YDJQ     	just
# 25	VP	umsg	N<ZB     	leave
# 25	PPrP	p3msg	W
# 26	VP	umsg	XWNN     	favour
# 26	VP	umsg	MLWH     	borrow
# 26	PPrP	p3msg	W
# 29	NP		YDJQJM     	just
# 29	VP	p3mpl	JJRCW     	trample down
# 29	VP	p3mpl	JCKNW     	dwell
# 32	NP		YDJQ     	just
# 32	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# 33	PPrP	p3msg	W
# Pattern:  ['NP', 'VP p3fsg', 'VP p3msg', 'NP', 'VP umsg', 'VP umsg', 'NP', 'VP umsg', 'Sfx p3msg', 'VP umsg', 'VP umsg', 'Sfx p3msg', 'NP', 'VP p3mpl', 'VP p3mpl', 'NP', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg', 'Sfx p3msg']
#
#
# C58:10 Who: YDJQ, first: JFMX, type: VP, corpus class: 737
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p3msg	JFMX     	rejoice
# 11	NP		YDJQ     	just
# 11	VP	p3msg	XZH     	see
# 11	PPrP	p3msg	W
# 11	VP	p3msg	JRXY     	wash
# 12	NP		YDJQ     	just
# Pattern:  ['VP p3msg', 'NP', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'NP']
#
#
# C58:10 Who: YDJQ, first: JFMX, type: VP, corpus class: 738
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p3msg	JFMX     	rejoice
# 11	NP		YDJQ     	just
# 11	VP	p3msg	XZH     	see
# 11	PPrP	p3msg	W
# 11	VP	p3msg	JRXY     	wash
# 12	NP		YDJQ     	just
# Pattern:  ['VP p3msg', 'NP', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'NP']
#
#
# C64:9 Who: YDJQ, first: JFMX, type: VP, corpus class: 800
#
# verse	type	pgn	ann		gloss	note
# 11	VP	p3msg	JFMX     	rejoice
# 11	NP		YDJQ     	just
# 11	VP	p3msg	XSH     	seek refuge
# Pattern:  ['VP p3msg', 'NP', 'VP p3msg']
#
#
# C72:3 Who: YDJQ, first: JPRX, type: VP, corpus class: 939
#
# verse	type	pgn	ann		gloss	note
# 7	VP	p3msg	JPRX     	sprout
# 7	PPrP	p3msg	W
# 7	NP		YDJQ     	just
# Pattern:  ['VP p3msg', 'Sfx p3msg', 'NP']
#
#
# C92:14 Who: YDJQ, first: YDJQ, type: NP, corpus class: 1257
#
# verse	type	pgn	ann		gloss	note
# 13	NP		YDJQ     	just
# 13	VP	p3msg	JPRX     	sprout
# 13	VP	p3msg	JFGH     	be great
# 14	VP	umpl	CTWLJM     	transplant
# 14	VP	p3mpl	JPRJXW     	sprout
# 15	VP	p3mpl	JNWBWN     	thrive
# 15	VP	p3mpl	JHJW     	be
# Pattern:  ['NP', 'VP p3msg', 'VP p3msg', 'VP umpl', 'VP p3mpl', 'VP p3mpl', 'VP p3mpl']
#
#
# C112:8 Who: YDJQ, first: JMWV, type: VP, corpus class: 1561
#
# verse	type	pgn	ann		gloss	note
# 6	VP	p3msg	JMWV     	totter
# 6	VP	p3msg	JHJH     	be
# 6	NP		YDJQ     	just
# 7	VP	p3msg	JJR>     	fear
# 7	PPrP	p3msg	W
# 8	PPrP	p3msg	W
# 8	VP	p3msg	JJR>     	fear
# 8	VP	p3msg	JR>H     	see
# 8	PPrP	p3msg	W
# 9	VP	p3msg	PZR     	scatter
# 9	VP	p3msg	NTN     	give
# 9	PPrP	p3msg	W
# 9	PPrP	p3msg	W
# Pattern:  ['VP p3msg', 'VP p3msg', 'NP', 'VP p3msg', 'Sfx p3msg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p3msg', 'VP p3msg', 'VP p3msg', 'Sfx p3msg', 'Sfx p3msg']
#
#
# C141:5 Who: YDJQ, first: JHLM, type: VP, corpus class: 1886
#
# verse	type	pgn	ann		gloss	note
# 5	VP	p3msg	JHLM     	strike
# 5	NP		YDJQ     	just
# 5	VP	p3msg	JWKJX     	reprove
# Pattern:  ['VP p3msg', 'NP', 'VP p3msg']
#
#
# Results:  10
# ['C112:8',
#  'C11:3',
#  'C141:5',
#  'C37:22',
#  'C37:9',
#  'C58:10',
#  'C5:12',
#  'C64:9',
#  'C72:3',
#  'C92:14']

# %% [markdown]
# ## 4. MiMi Coreference Data
#
# In this section the coreference data is presented that MiMi detects. First import MiMi and run the algorithm on Ps 75, then inspect the data with the two functions that are described below.

# %% [markdown]
# ### 4.1 Go MiMi
#
# Run the two cells below

# %%
from mimi import mimi

# %%
mentions, corefs, mention_stats_df, coref_stats_df, sieve_stats_df, \
                        coref_total_df, sieve_total_df = mimi(MY_BOOK, FROM_CHAPTER, TO_CHAPTER, 1)
# Out:
# Start.
#
#  Mention Parse Statistics Psalms:
#  66 phrase atoms INPUT
#  64 phrase atoms SUCCESFULLY parsed
#  +1 extra mentions SUCCESFULLY parsed from phrase atoms
#  -0 phrase atoms without mentions
#  2 phrase atom parse ERRORS
#  +0 extra mentions SUCCESFULLY parsed from phrase atom errors
#  -2 phrase atoms without mentions from phrase atom ERRORS
#  65 mention coreference input
#  96.9% parsing succes
#  3.1% parsing error
#
#  Coreference Resolution Statistics Psalms:
#  65 total input corefs
#  31 corefs RESOLVED
#  34 corefs UNRESOLVED
#  47.7% corefs RESOLVED
#  52.3% corefs UNRESOLVED
#  10 classes
#
#  Sieve Statistics Psalms:
#  1p 2p Pronoun Sieve: 3
#  Vocative Sieve: 1
#  String Sieve: 8
#  Entity Sieve: 0
#  Apposition Sieve: 0
#  Fronted Element Sieve: 0
#  Predicate Sieve: 13
#  3p Pronoun Sieve: 6
#  Total Sieves: 31
#  Total Classes: 10

# %% [raw]
# Coreference Resolution Statistics Psalms:
#  65 total input corefs
#  17 corefs RESOLVED
#  48 corefs UNRESOLVED
#  26.2% corefs RESOLVED
#  73.8% corefs UNRESOLVED
#  10 classes
#
#  Sieve Statistics Psalms:
#  Predicate Sieve: 13
#  Pronoun Sieve: 3
#  Vocative Sieve: 1
#  Apposition Sieve: 0
#  Fronted Element Sieve: 0
#  Total Sieves: 17
#  Total Classes: 10

# %% [markdown]
# ### 4.2 Descriptive Statistics

# %%
mention_stats_df
# Out:
#      book  phrase atoms  pa parsed  +m  -pa  pa errors  +m errors  -pa errors  \
# 0  Psalms            66         64   1    0          2          0           2
#
#    mentions  %parsed  %error
# 0        65     96.9     3.1

# %%
coref_stats_df
# Out:
#       chapter  input corefs  resolved  unresolved  %resolved  %unresolved  \
# 0  Psalms_075            65        31          34       47.7         52.3
#
#    classes
# 0       10

# %%
sieve_stats_df
# Out:
#       chapter  1p 2p pronoun  vocative  string  entity  apposition  \
# 0  Psalms_075              3         1       8       0           0
#
#    fronted element  predicate  3p pronoun  total sieves  classes
# 0                0         13           6            31       10

# %% [markdown]
# ### 4.3 Visualise Coreference Results
#
# The function `PrintCoref(coref)` below visualises the entities that MiMi has found in Ps 75. iMi generates 10 classes - entities - for Ps 75. The column *verse* indicates the verse in which the mention occurs; *id* the mention identification;  *mention* the mention; *txttyp* the ETCBC text type domain; *§* the paragraph number; *p*, *g* and *n* person, gender and number; *func* the function of the mention; *type* the type of the mention; and *gloss* the basic translation of the mention. If the mentions consist of more words, only the first gloss is given. For *p*, *g* and/or *n* the value 'NA' means 'Not Applicable', and the 'u' means 'unknown'. Per entity the Class or entity number is given, e.g. 'C75:1', which stands for Class 1 in Ps 75. and the identification of the class, in the case of C75:1 it is '>LHJM', God.

# %%
PrintCoref(corefs)
# Out:
# verse	id	mention	txttyp	§	p	g	n	func	type	gloss
#
# C75:1 Who: HWDJNW
# 2	T6	HWDJNW	Q	2	p1	unknown	pl	Pred	VP	praise
# 2	T9	HWDJNW	Q	2	p1	unknown	pl	Pred	VP	praise
# class:  [HWDJNW, HWDJNW]
#
#
# C75:2 Who: >RY W-KL JCBJ
# 4	T19	NMGJM	Q	2.1	unknown	m	pl	PreC	VP	faint
# 4	T20	>RY W-KL JCBJ	Q	2.1	NA	unknown	pl	Subj	NP	earth
# class:  [NMGJM, >RY W-KL JCBJ]
#
#
# C75:3 Who: TDBRW
# 5	T30	TRJMW	QQ	2.2.2	p2	m	pl	Pred	VP	be high
# 6	T32	TRJMW	QQ	2.2.2	p2	m	pl	Pred	VP	be high
# 6	T36	TDBRW	QQ	2.2.2	p2	m	pl	Pred	VP	speak
# class:  [TRJMW, TRJMW, TDBRW]
#
#
# C75:4 Who: JRJM
# 8	T44	JCPJL	Q	2.2	p3	m	sg	Pred	VP	be low
# 8	T46	JRJM	Q	2.2	p3	m	sg	Pred	VP	be high
# class:  [JCPJL, JRJM]
#
#
# C75:5 Who: JJN
# 9	T49	JJN	Q	2.2	NA	m	sg	Subj	NP	wine
# 9	T50	XMR	Q	2.2	p3	m	sg	Pred	VP	cover
# 9	T51	JGR	QN	2.2	p3	m	sg	Pred	VP	run
# class:  [JJN, XMR, JGR]
#
#
# C75:6 Who: ZH
# 8	T43	ZH	Q	2.2	NA	m	sg	Objc	DPrP	this
# 8	T45	ZH	Q	2.2	NA	m	sg	Objc	DPrP	this
# 9	T52	ZH	QN	2.2	NA	m	sg	Cmpl	DPrP	this
# class:  [ZH, ZH, ZH]
#
#
# C75:7 Who: NPL>WTJ
# 2	T12	SPRW	Q	2	p3	unknown	pl	Pred	VP	count
# 2	T13	NPL>WTJ	Q	2	unknown	f	pl	Subj	NP	be miraculous
# 4	T21	+H	Q	2.1	p3	f	sg	Subj	PPrP
# 4	T25	+H	Q	2.1	p3	f	sg	Objc	PPrP
# 9	T54	+H	Q	2.2	p3	f	sg	Objc	PPrP
# 9	T55	JMYW	Q	2.2	p3	m	pl	Pred	VP	drain
# 9	T56	JCTW	Q	2.2	p3	m	pl	Pred	VP	drink
# class:  [SPRW, NPL>WTJ, +H, +H, +H, JMYW, JCTW]
#
#
# C75:8 Who: >LHJ J<QB
# 2	T7	+K	Q	2	p2	m	sg	Cmpl	PPrP
# 2	T8	>LHJM	Q	2	NA	m	pl	Voct	NP	god(s)
# 2	T11	+K	Q	2	p2	m	sg	Subj	PPrP
# 2	T14	+K	Q	2	p2	m	sg	Subj	PPrP
# 8	T41	>LHJM	Q	2.2	NA	m	pl	Subj	NP	god(s)
# 10	T61	>LHJ J<QB	Q	2.2	NA	m	pl	Cmpl	NP	god(s)
# class:  [+K, >LHJM, +K, +K, >LHJM, >LHJ J<QB]
#
#
# C75:9 Who: >GD<
# 3	T17	>NJ	Q	2.1	p1	unknown	sg	Subj	PPrP	i
# 3	T18	>CPV	Q	2.1	p1	unknown	sg	Pred	VP	judge
# 4	T22	>NKJ	Q	2.1	p1	unknown	sg	Subj	PPrP	i
# 4	T23	TKNTJ	Q	2.1	p1	unknown	sg	Pred	VP	estimate
# 10	T57	>NJ	Q	2.2	p1	unknown	sg	Subj	PPrP	i
# 10	T58	>GJD	Q	2.2	p1	unknown	sg	Pred	VP	report
# 10	T60	>ZMRH	Q	2.2	p1	unknown	sg	Pred	VP	sing
# 11	T63	>GD<	Q	2.2	p1	unknown	sg	Pred	VP	cut off
# class:  [>NJ, >CPV, >NKJ, TKNTJ, >NJ, >GJD, >ZMRH, >GD<]
#
#
# C75:10 Who: KL QRNJ RC<JM
# 5	T31	QRN	QQ	2.2.2	NA	f	sg	Objc	NP	horn
# 6	T34	QRN	QQ	2.2.2	NA	f	sg	Objc	NP	horn
# 11	T62	KL QRNJ RC<JM	Q	2.2	NA	m	sg	Objc	NP	whole
# 11	T64	TRWMMNH	Q	2.2	p3	f	pl	Pred	VP	be high
# 11	T65	QRNWT YDJQ	Q	2.2	NA	f	pl	Subj	NP	horn
# class:  [QRN, QRN, KL QRNJ RC<JM, TRWMMNH, QRNWT YDJQ]

# %% [markdown]
# ### 4.4 Visualise Mentions or Singletons
#
# The colums below are the same as the coreference visualisation above. The column *C/S* indicates, depending on the option that has been chosen in `PrintMentions()`, whether the mention is a singleton or that it belongs to a class. To print singletons do `PrintMentions(mentions, 'singletons')`, to get an overview of the mentions give it an empty string as second argument: `PrintMentions(mentions, '')`. The function returns a pandas dataframe that can be exported.

# %%
# option 'singletons' for only singletons
sing_overview_df75 = PrintMentions(mentions, 'singletons')
# Out:
# verse	C/S	who	id	mention	txttyp	§	p	g	n	func	type	gloss
#
# 1	S1		T1	-MNYX	?	1	NA	NA	NA	PreC	NP	the
# 1	S2		T2	TCXT	Q	1	p2	m	sg	Pred	VP	destroy
# 1	S3		T3	MZMWR	?	1	NA	m	sg	PreC	NP	psalm
# 1	S4		T4	>SP	?	1	NA	m	sg	PreC	PrNP	Asaph
# 1	S5		T5	CJR	?	1	NA	m	sg	PreC	NP	song
# 2	S6		T10	CM	Q	2	NA	m	sg	Subj	NP	name
# 3	S7		T15	>QX	Q	2.1	p1	unknown	sg	Pred	VP	take
# 3	S8		T16	MW<D	Q	2.1	NA	m	sg	Objc	NP	appointment
# 4	S9		T24	<MWDJ	Q	2.1	NA	m	pl	Objc	NP	pillar
# 5	S10		T26	>MRTJ	Q	2.2	p1	unknown	sg	Pred	VP	say
# 5	S11		T27	-HWLLJM	Q	2.2	NA	NA	NA	Cmpl	NP	the
# 5	S12		T28	THLW	QQ	2.2.1	p2	m	pl	Pred	VP	be infatuated
# 5	S13		T29	-RC<JM	Q	2.2	NA	NA	NA	Cmpl	NP	the
# 6	S14		T33	-MRWM	QQ	2.2.2	NA	NA	NA	Cmpl	NP	the
# 6	S15		T35	+KM	QQ	2.2.2	p2	m	pl	Objc	PPrP
# 6	S16		T37	YW>R <TQ	QQ	2.2.2	NA	m	sg	Adju	NP	neck
# 7	S17		T38	MWY>	Q	2.2	NA	m	sg	PreC	NP	issue
# 7	S18		T39	M<RB	Q	2.2	NA	m	sg	PreC	NP	sunset
# 7	S19		T40	MDBR HRJM	Q	2.2	NA	m	sg	PreC	NP	desert
# 8	S20		T42	CPV	Q	2.2	unknown	m	sg	PreC	NP	judge
# 9	S21		T47	KWS	Q	2.2	NA	f	sg	Subj	NP	cup
# 9	S22		T48	JD JHWH	Q	2.2	NA	unknown	sg	PreC	NP	hand
# 9	S23		T53	CMRJ	Q	2.2	NA	m	pl	Objc	NP	dregs
# 10	S24		T59	<LM	Q	2.2	NA	m	sg	Time	NP	eternity

# %%
# Export as table
sing_overview_df75
# Out:
#      v   S#   id    mention txt      §        p        g   n  func  type  \
# 0    1   S1   T1      -MNYX   ?      1       NA       NA  NA  PreC    NP
# 1    1   S2   T2       TCXT   Q      1       p2        m  sg  Pred    VP
# 2    1   S3   T3      MZMWR   ?      1       NA        m  sg  PreC    NP
# 3    1   S4   T4        >SP   ?      1       NA        m  sg  PreC  PrNP
# 4    1   S5   T5        CJR   ?      1       NA        m  sg  PreC    NP
# 5    2   S6  T10         CM   Q      2       NA        m  sg  Subj    NP
# 6    3   S7  T15        >QX   Q    2.1       p1  unknown  sg  Pred    VP
# 7    3   S8  T16       MW<D   Q    2.1       NA        m  sg  Objc    NP
# 8    4   S9  T24      <MWDJ   Q    2.1       NA        m  pl  Objc    NP
# 9    5  S10  T26      >MRTJ   Q    2.2       p1  unknown  sg  Pred    VP
# 10   5  S11  T27    -HWLLJM   Q    2.2       NA       NA  NA  Cmpl    NP
# 11   5  S12  T28       THLW  QQ  2.2.1       p2        m  pl  Pred    VP
# 12   5  S13  T29     -RC<JM   Q    2.2       NA       NA  NA  Cmpl    NP
# 13   6  S14  T33      -MRWM  QQ  2.2.2       NA       NA  NA  Cmpl    NP
# 14   6  S15  T35        +KM  QQ  2.2.2       p2        m  pl  Objc  PPrP
# 15   6  S16  T37   YW>R <TQ  QQ  2.2.2       NA        m  sg  Adju    NP
# 16   7  S17  T38       MWY>   Q    2.2       NA        m  sg  PreC    NP
# 17   7  S18  T39       M<RB   Q    2.2       NA        m  sg  PreC    NP
# 18   7  S19  T40  MDBR HRJM   Q    2.2       NA        m  sg  PreC    NP
# 19   8  S20  T42        CPV   Q    2.2  unknown        m  sg  PreC    NP
# 20   9  S21  T47        KWS   Q    2.2       NA        f  sg  Subj    NP
# 21   9  S22  T48    JD JHWH   Q    2.2       NA  unknown  sg  PreC    NP
# 22   9  S23  T53       CMRJ   Q    2.2       NA        m  pl  Objc    NP
# 23  10  S24  T59        <LM   Q    2.2       NA        m  sg  Time    NP
#
#             gloss
# 0             the
# 1         destroy
# 2           psalm
# 3           Asaph
# 4            song
# 5            name
# 6            take
# 7     appointment
# 8          pillar
# 9             say
# 10            the
# 11  be infatuated
# 12            the
# 13            the
# 14
# 15           neck
# 16          issue
# 17         sunset
# 18         desert
# 19          judge
# 20            cup
# 21           hand
# 22          dregs
# 23       eternity

# %% [markdown]
# ## 5. IAA: Manual Annotations and MiMi
#
# In this section the manual annotations are presented in relation and in comparison to MiMi's results. The IAA calculations and corresponding coreference data are retrieved with function `retrieve_ann`. The IAA measures of the matched coreference pairs and corresponding annotations and MiMi's results are reported below. To give a summary, similar to the IAA analysis the column *ann_A* indicates the manual annotations by the author and column *ann_B* MiMi's results. $L$(eft) and $R$(ight) for the relative complement, $M$(iddle) for the intersection, the symmetric difference is $D$ for $\Delta$, and $d$ for $d_{c}$. The first line gives the comparison of a class with IAA measures. For example the first *C1* is **A**'s (the author's) annotation, *C2* belongs to **B** (MiMi). The second line gives the annotations of **A** in ETCBC's transcription of Biblical Hebrew, the third line gives **B**'s coreference data. The fourth and fifth lines give the specific differences (i.e. *diff*) in annotations between **A** and **B**, if they exist. The notation is: the annotator, **A** or **B**, followed by *diff*, then by a word in brackets together with an index number (all indices start at 0) that points to the word's position in **A**'s or **B**'s printed class.

# %%
path_manual = os.path.expanduser('~/Sites/brat/data/coref/Psalms/annotate/Psalms_075.ann')
path_mimi = os.path.expanduser('~/github/cmerwich/participant-analysis/iaa-ann-vs-mimi/Psalms_075.ann')

# %%
ps075_df = MakeTable('~/github/cmerwich/participant-analysis/iaa-ann-vs-mimi/Psalms_075.iaa')
ps075_df
# Out:
#    ann_A ann_B   L   M  R   D       d
# 0     C1    C1   0   2  0   0  0.0000
# 1     C2    C2   2   2  0   2  0.5000
# 2     C3    C6   2   0  3   5  1.0000
# 3     C4    C8  12   6  0  12  0.6667
# 4     C5    C5   2   2  1   3  0.6000
# 5     C6    C3   5   3  0   5  0.6250
# 6     C7    C9   0   3  5   5  0.6250
# 7     C8    C4   2   0  2   4  1.0000
# 8     C9    C7   0   2  5   5  0.7143
# 9    C10   C10   0   3  2   2  0.4000
# 10     S     S   3  16  8  11  0.4074

# %%
retrieve_ann(path_manual, path_mimi)
# Out:
# ann_A	ann_B	L	M	R	D	d
#
# ------------------------------------------------------------
# C1	C1	0	2	0	0	0.0
# ------------------------------------------------------------
# A	['HWDJNW', 'HWDJNW']
#
# B	['HWDJNW', 'HWDJNW']
#
# ------------------------------------------------------------
# C2	C2	2	2	0	2	0.5
# ------------------------------------------------------------
# A	['NMGJM', '>RY WKL&JCBJ', 'H', 'H']
#
# B	['NMGJM', '>RY W-KL JCBJ']
#
# A diff	[('>RY WKL&JCBJ', 1), ('H', 4), ('H', 5)]
#
# B diff	[('>RY W-KL JCBJ', 2)]
#
# ------------------------------------------------------------
# C3	C6	2	0	3	5	1.0
# ------------------------------------------------------------
# A	['HWLLJM', 'THLW']
#
# B	['ZH', 'ZH', 'ZH']
#
# A diff	[('HWLLJM', 0), ('THLW', 1)]
#
# B diff	[('ZH', 0), ('ZH', 1), ('ZH', 2)]
#
# ------------------------------------------------------------
# C4	C8	12	6	0	12	0.6667
# ------------------------------------------------------------
# A	['K', '>LHJM', 'K', 'K', '>QX', '>NJ', '>CPV', '>NKJ', 'TKNTJ', '>MRTJ', '>LHJM', 'CPV', 'JCPJL', 'JRJM', 'JD&JHWH', 'JGR', '>LHJ J<QB', '>GD<']
#
# B	['+K', '>LHJM', '+K', '+K', '>LHJM', '>LHJ J<QB']
#
# A diff	[('K', 0), ('K', 2), ('K', 3), ('>QX', 4), ('>NJ', 5), ('>CPV', 6), ('>NKJ', 7), ('TKNTJ', 8), ('>MRTJ', 9), ('CPV', 11), ('JCPJL', 12), ('JRJM', 13), ('JD&JHWH', 14), ('JGR', 15), ('>GD<', 17)]
#
# B diff	[('+K', 0), ('+K', 2), ('+K', 3)]
#
# ------------------------------------------------------------
# C5	C5	2	2	1	3	0.6
# ------------------------------------------------------------
# A	['JJN', 'XMR', 'ZH', 'H']
#
# B	['JJN', 'XMR', 'JGR']
#
# A diff	[('ZH', 2), ('H', 3)]
#
# B diff	[('JGR', 2)]
#
# ------------------------------------------------------------
# C6	C3	5	3	0	5	0.625
# ------------------------------------------------------------
# A	['RC<JM', 'TRJMW', 'TRJMW', 'KM', 'TDBRW', 'JMYW', 'JCTW', 'KL RC<J&>RY']
#
# B	['TRJMW', 'TRJMW', 'TDBRW']
#
# A diff	[('RC<JM', 0), ('KM', 3), ('JMYW', 5), ('JCTW', 6), ('KL RC<J&>RY', 7)]
#
# B diff	[]
#
# ------------------------------------------------------------
# C7	C9	0	3	5	5	0.625
# ------------------------------------------------------------
# A	['>NJ', '>GJD', '>ZMRH']
#
# B	['>NJ', '>CPV', '>NKJ', 'TKNTJ', '>NJ', '>GJD', '>ZMRH', '>GD<']
#
# A diff	[]
#
# B diff	[('>NJ', 0), ('>CPV', 1), ('>NKJ', 2), ('TKNTJ', 3), ('>GD<', 7)]
#
# ------------------------------------------------------------
# C8	C4	2	0	2	4	1.0
# ------------------------------------------------------------
# A	['TRWMMNH', 'QRNWT YDJQ']
#
# B	['JCPJL', 'JRJM']
#
# A diff	[('TRWMMNH', 0), ('QRNWT YDJQ', 1)]
#
# B diff	[('JCPJL', 0), ('JRJM', 1)]
#
# ------------------------------------------------------------
# C9	C7	0	2	5	5	0.7143
# ------------------------------------------------------------
# A	['SPRW', 'NPL>WTJ']
#
# B	['SPRW', 'NPL>WTJ', '+H', '+H', '+H', 'JMYW', 'JCTW']
#
# A diff	[]
#
# B diff	[('+H', 2), ('+H', 3), ('+H', 4), ('JMYW', 5), ('JCTW', 6)]
#
# ------------------------------------------------------------
# C10	C10	0	3	2	2	0.4
# ------------------------------------------------------------
# A	['QRN', 'QRN', 'KL&QRNJ RC<JM']
#
# B	['QRN', 'QRN', 'KL QRNJ RC<JM', 'TRWMMNH', 'QRNWT YDJQ']
#
# A diff	[('KL&QRNJ RC<JM', 2)]
#
# B diff	[('KL QRNJ RC<JM', 3), ('TRWMMNH', 5), ('QRNWT YDJQ', 6)]
#
# ------------------------------------------------------------
# S	S	3	16	8	11	0.4074
# ------------------------------------------------------------
# A	['MNYX', 'TCXT', 'MZMWR', '>SP', 'CJR', 'CM', 'MW<D', '<MWDJ', 'MRWM', 'YW>R <TQ', 'MWY>', 'M<RB', 'MDBR HRJM', 'ZH', 'ZH', 'KWS', 'ML> MSK', 'CMRJ', '<LM']
#
# B	['-MNYX', 'TCXT', 'MZMWR', '>SP', 'CJR', 'CM', '>QX', 'MW<D', '<MWDJ', '>MRTJ', '-HWLLJM', 'THLW', '-RC<JM', '-MRWM', '+KM', 'YW>R <TQ', 'MWY>', 'M<RB', 'MDBR HRJM', 'CPV', 'KWS', 'JD JHWH', 'CMRJ', '<LM']
#
# A diff	[('MNYX', 0), ('MRWM', 9), ('ZH', 15), ('ZH', 16), ('ML> MSK', 18)]
#
# B diff	[('-MNYX', 0), ('>QX', 7), ('>MRTJ', 10), ('-HWLLJM', 11), ('THLW', 12), ('-RC<JM', 13), ('-MRWM', 14), ('+KM', 16), ('CPV', 21), ('JD JHWH', 23)]

# %% [markdown]
# ## Exported tables

# %%
#pos_df75, 'pos_df75-corr'
#ExportToLatex(OUTPUT, 'pos_df75-corr', pos_df75, indx = True)

#pronoun_df75, 'pronoun_df75-corr'
#ExportToLatex(OUTPUT, 'pronoun_df75-corr', pronoun_df75, indx = True)

#mention_stats_df, 'mention_stats_75'
#ExportToLatex(OUTPUT, 'mention_stats_75', mention_stats_df, indx = False)

#coref_stats_df, 'coref_stats_75-corr'
#ExportToLatex(OUTPUT, 'coref_stats_75-corr', coref_stats_df, indx = False)

#sieve_stats_df, 'sieve_stats_75-corr'
#ExportToLatex(OUTPUT, 'sieve_stats_75-corr', sieve_stats_df, indx = False)

#sing_overview_df75, 'sing_overview_df75-corr'

#ps075_df, 'ps075iaa_df-corr'
#ExportToLatex(OUTPUT, 'ps075iaa_df-corr', ps075_df, indx = False)

#ExportToLatex(OUTPUT, 'pos_df75-corr', pos_df75, indx = True)

# %% [markdown]
# ### Cruft

# %% [raw]
# __author__ = 'erwich/sikkel'
#
# import os
# from sys import stderr
#
# import numpy as np
# from scipy.optimize import linear_sum_assignment
# from difflib import ndiff
#
# def error(*args, **kwargs):
#     '''
#     Prints error messages.
#     '''
#
#     print(*args, file=stderr, **kwargs)
#     exit(1)
#
# def parse_ann(annFile):
#     '''
#     Parses a plain text brat annotation file for a given repository
#     specified in `compare_ann()`, and returns an np.array of corefs and singletons
#     '''
#
#     errors = 0
#
#     results_list = []
#     t2mDict = {}
#     singletonSet = set()
#     m2wDict = {}
#     dataPartsList = []
#
#     firstChars = {'T', '#', '*'}
#     cClass = 0
#
#     with open(annFile) as fh:
#         for (i, line) in enumerate(fh):
#             epos = f'{i + 1} '
#             line = line.rstrip('\n')
#             firstChar = line[0]
#
#             if firstChar not in firstChars:
#                 error(f'{epos}Unrecognized line "{line}"')
#                 errors +=1
#                 continue
#
#             numFields = 2 if firstChar =='*' else 3
#             parts = line.split('\t')
#
#             if len(parts) != numFields:
#                 error(f'{epos}line does not have exactly {numFields} parts: "{line}"')
#                 errors += 1
#                 continue
#
#             if firstChar == 'T':
#                 (tPart, mentionStr, aWord) = parts
#                 mParts = mentionStr.split()
#                 if len(mParts) != 3:
#                     error(f'{epos}T-line mention does not have exactly 3 parts: "{line}"')
#                     errors += 1
#                     continue
#                 (mm, aStart, aEnd) = mParts
#                 aStart = int(aStart)
#                 aEnd = int(aEnd)
#
#                 t2mDict[tPart] = mentionStr
#                 singletonSet.add(mentionStr)
#                 m2wDict[mentionStr] = aWord
#
#             elif firstChar == '*':
#                 corefSets = set()
#                 (char, data) = parts
#                 dataParts = data.split()
#                 if len(dataParts) <= 1 or dataParts[0] != 'Coreference':
#                     error(f'{epos}*-line spec does not have the right parts: "{line}"')
#                     errors += 1
#                     continue
#                 cClass += 1
#                 dataPartsList.append(dataParts)
#
#         for l in dataPartsList:
#             corefSets = set()
#             for tPart in l[1:]:
#                 if tPart in corefSets:
#                     error(f'{epos}*-"{tPart} occurs in multiple classes "{corefSets[tPart]}" in "{line}"')
#                     errors += 1
#                     continue
#                 corefSets.add(t2mDict[tPart])
#                 singletonSet.discard(t2mDict[tPart])
#
#             results_list.append(corefSets)
#
#         results_list.append(singletonSet) #results_list[-1] is the singletonSet
#
#     if errors:
#         error(f'There are {errors} errors in annotation file')
#
#     results_array = np.array(results_list)
#
#     return results_array, m2wDict
#
# def ds(s1, s2):
#     '''
#     Return the L, M, R triple on which the Jaccard distance between
#     the sets s1 and s2 is based.
#     '''
#     return (len(s1 - s2), len(s1 & s2), len(s2 - s1))
#
# def match_nk(l1, l2):
#     '''
#     Return the distance between two lists of sets,
#     provided that n >= k
#     '''
#     n = len(l1)
#     k = len(l2)
#     lost = np.zeros((n, n), dtype=int)
#     held = np.zeros((n, n), dtype=tuple)
#     #held = matrix of tuples(l, m, r)
#     for i in range(n):
#         for j in range(k):
#             L, M, R = ds(l1[i], l2[j])
#             lost[i, j] = L + R
#             held[i, j] = (L, M, R)
#         for j in range(k, n):
#             L, M, R = (len(l1[i]), 0, 0) # unpaired
#             lost[i, j] = L + R
#             held[i, j] = (L, M, R)
#     rx, cx = linear_sum_assignment(lost)
#     scores = held[rx, cx]
#     return scores, rx, cx
#
# def tag(S, i):
#     '''
#     Tags the compared sets according to their types.
#     C for coreference class.
#     S for singletons.
#     '''
#
#     if i + 1 == len(S):
#         return 'S'
#     else:
#         return f'C{i+1}'
#
# def make_tags(list1, list2, rx, cx):
#     '''
#     Makes class and singleton tags per matching.
#     Returns list of tuples with two elements:
#     tag1 for list1, tag2 for list2.
#     [(tag1, tag2)]
#     '''
#     tags = []
#     n = len(list1) # array A
#     k = len(list2) # array B
#
#     for i in range(n):
#         if cx[i] < k:
#             tags.append((tag(list1, rx[i]), tag(list2, cx[i])))
#         else:
#             tags.append((tag(list1, rx[i]), '-'))
#     return tags
#
# def match(l1, l2):
#     '''
#     Returns the comparison between two sets of sets,
#     represented as lists of sets, in the form of a
#     list of matched tags, and a list of scores per coref.
#     '''
#     n = len(l1) # array A
#     k = len(l2) # array B
#     if n < k:
#         scores, rx, cx = match_nk(l2, l1)  #(b, a)
#         tags = make_tags(l2, l1, rx, cx)
#         scores = [t[::-1] for t in scores]
#         tags = [t[::-1] for t in tags]
#         #print('a < b', tags, scores, n, k)
#     else:
#         scores, rx, cx = match_nk(l1, l2)  #(a, b)
#         tags = make_tags(l1, l2, rx, cx)
#         #print(tags, scores)
#
#     return tags, scores, rx, cx
#
# def write_results(tags, scores):
#     # tags = [(), ()]
#     # scores = [(l, m, r), ()]
#     for i in range(len(tags)):
#         t = tags[i]
#         l, m, r = scores[i]
#         D = l + r
#         d = round(D / (l + m + r), 4)
#         print(t[0], t[1], l, m, r, D, d, sep='\t')
#
# def sort_this(l, dic):
#     '''
#     Sorts a list of mention strings of the form 'Mention 1 5'.
#     Sorts the end index (5), before the start index (1).
#     Returns list of sorted mention strings.
#     '''
#
#     words_list = []
#     l_2 = sorted(l, key=lambda s: int(s.split()[2]))
#     l_3 = sorted(l_2, key=lambda s: int(s.split()[1]))
#     for i in l_3:
#         words_list.append(dic[i])
#
#     return words_list
#
# def get_ndiff(A, B):
#     '''
#     Prints the difference between A's and B's annotations
#     which are contained in strings.
#     '''
#
#     diff_a = []
#     diff_b = []
#     i_A = 0
#     i_B = 0
#
#     for s in ndiff(A, B):
#
#         #if s[0]==' ': continue # ignore the common annotations of A and B
#         if s[0]=='-':
#             diff_a.append((s[2:], i_A)) # A.index(s[2:])
#             i_A += 1
#         elif s[0]=='+':
#             diff_b.append((s[2:], i_B)) # B.index(s[2:])
#             i_B += 1
#         else:
#             i_A += 1
#             i_B += 1
#
#     if diff_a == diff_b:
#         pass
#     else:
#         print('A diff', diff_a, '\n', sep='\t')
#         print('B diff', diff_b, '\n', sep='\t')
#
# def retrieve_corefs(A, B, m2wDict_A, m2wDict_B, rx, cx, tags, scores):
#     divide = '-'*60
#
#     print('ann_A','ann_B', 'L', 'M', 'R', 'D', 'd', '\n', sep='\t')
#     write_results(tags, scores)
#     print(len(rx), len(cx))
#     for i in range(len(rx)):
#     #for i in range(len(tags)):
#         print(divide)
#         #write_results(tags, scores)
#         print(divide)
#
#         coList_A = []
#         for Ae in A[rx[i]]:
#             coList_A.append(Ae)
#         A_list = sort_this(coList_A, m2wDict_A)
#         print('A', A_list, '\n', sep='\t')
#
#         coList_B = []
#         for Be in B[cx[i]]:
#             coList_B.append(Be)
#         B_list = sort_this(coList_B, m2wDict_B)
#         print('B', B_list, '\n', sep='\t')
#         get_ndiff(A_list, B_list)
#
#
# def retrieve(pathA, pathB):
#     '''
#     Executes the comparison between the brat annotation files of annotator A and B.
#     '''
#
#     annFileA = os.path.expanduser(pathA)
#     annFileB = os.path.expanduser(pathB)
#
#     results_array_A, m2wDict_A = parse_ann(annFileA)
#     results_array_B, m2wDict_B = parse_ann(annFileB)
#
#     tags, scores, rx, cx = match(results_array_A, results_array_B)
#
#     retrieve_corefs(results_array_A, results_array_B, m2wDict_A, m2wDict_B, rx, cx, tags, scores)

# %% [raw]
# c = os.path.expanduser('~/Sites/brat/data/coref/Psalms/annotate/Psalms_001.ann')
# m = os.path.expanduser('~/github/cmerwich/participant-analysis/iaa-ann-vs-mimi/Psalms_001.ann')
#
# retrieve(c, m)

# %% [raw]
# for i in uA:
#     print(divide)
#     write_results(A[i], tag(A, i), set(), '-')
#     print(divide)
#
#     coList_uA = []
#     for uAe in A[i]:
#         coList_uA.append(uAe)
#     print('unp A', sort_this(coList_uA, m2wDict_A), '\n', sep='\t')
#
# for i in uB:
#     print(divide)
#     write_results(set(), '-', B[i], tag(B, i))
#     print(divide)
#
#     coList_uB = []
#     for uBe in B[i]:
#         coList_uB.append(uBe)
#     print('unp B', sort_this(coList_uB, m2wDict_B), '\n', sep='\t')
